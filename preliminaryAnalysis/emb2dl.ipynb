# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Apr 28 17:16:19 2022

@author: iliaskaloup
"""

import tensorflow

import os, json, glob, time, sys, re
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import json
import math

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras import regularizers
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM, SimpleRNN, Bidirectional
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import Masking
from tensorflow.keras.layers import Embedding, MaxPool1D
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras import optimizers
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.layers import Bidirectional, BatchNormalization
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.initializers import glorot_uniform, RandomUniform, lecun_uniform, Constant
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.preprocessing.text import Tokenizer
from collections import OrderedDict
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D, GlobalMaxPool1D
import tensorflow.keras.backend as K

# import gensim
# from gensim import downloader as api
# from gensim.models import Word2Vec

import io
from contextlib import redirect_stdout
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
#from sklearn import metrics
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, \
roc_auc_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import scale
from sklearn.utils import shuffle
import time
import random

from transformers import GPT2Tokenizer, GPT2LMHeadModel, BertModel, BertTokenizer, AutoTokenizer, TFAutoModel, OpenAIGPTTokenizer, OpenAIGPTModel

# %%
# define seeder
seed = 123
np.random.seed(seed)
random.seed(seed)
tensorflow.random.set_seed(seed)

# %%
def readFiles(inputPath):
    suffix = ".py"        
    paths=[]
    for root, dirs, files in os.walk(inputPath):
        for file in files:
            if (file.endswith(suffix)):
                 paths.append(file)                 
    return paths

def createListOfTokens(codeFilename):
	"""
	Given a file name in the current working directory, read each line 
	and append it to a list.
	Return: the contents of the file as a list of strings
	"""
	codeLinesList = []

	with open(codeFilename, "r", encoding="utf8") as fin:
		for line in fin:
			codeLinesList.append(line)

	return codeLinesList

def listToString(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1 += ele  
    
    # return string  
    return str1 

def stringToList(string):
    codeLinesList = []
    for line in string.splitlines():
        codeLinesList.append(line)
    return codeLinesList

def remove_comments(input_str):
    
    input_str = re.sub('#.*', '', input_str)
    input_str = re.sub('""".*"""', '', input_str)          
    input_str = re.sub("'''.*'''", '', input_str)    

    doc_reg_1 = r'("""|\'\'\')([\s\S]*?)(\1\s*)(?=class)'
    doc_reg_2 = r'(\s+def\s+.*:\s*)\n(\s*"""|\s*\'\'\')([\s\S]*?)(\2[^\n\S]*)'
    input_str = re.sub(doc_reg_1, '', input_str)
    input_str = re.sub(doc_reg_2, r'\1', input_str)
    
    return input_str

def dropHeaders(lines):
    linList = []
    for line in lines:
        if not re.search('import',line):
             if not re.search('from',line):
                  linList.append(line)
    return linList

def dropBlank(tokens0):
    tokens = []
    for i in range(0, len(tokens0)):
        temp = tokens0[i]
        if temp != '':
            tokens.append(temp)
    return tokens

def tokenizeLines(codeLinesList):
	"""
	Tokenize each file line, i.e. entry of code list, based on a specified
    regex.
    ***The regex used is not applicable to every case. One needs to configure
    it based on file inputs.

	Return: list containing code tokens
	"""
    #enalaktika codeLinesList.split() gia na meinoun ta tokens mazi me to punctuation
	codeTokens = []

	for line in codeLinesList:
		templineTokens = re.split('[\.,\[\];:(\s)?\\\\!\t{}"<>+=~*&^%/|\\-\']', line)
		codeTokens.extend(templineTokens)

	return codeTokens

def dropEmpty(tokens0):
    tokens = []
    for i in range(0, len(tokens0)):
        temp = tokens0[i]
        if temp != []:
            tokens.append(temp)
    return tokens

def makeSequences(paths, inputPath, folder, label):
    allTokens = []
    for i in range(0, len(paths)):
        path = paths[i]
        
        if label == 0:
            path2 = os.path.join(inputPath, folder, path)
        elif label == 1:
            path2 = os.path.join(inputPath, folder, path)
        #tokenize source code in a list of lines
        lines0 = createListOfTokens(path2)
        
        #convert source code from list of lines to string
        stringLines = listToString(lines0)
        
        stringLinesNoDigit = re.sub(r"$\d+\W+|\b\d+\b|\W+\d+$", "<numId$>", stringLines) #replace numbers 
        
        stringLinesNoStr = re.sub(r'(["])(?:(?=(\\?))\2.)*?\1', "<strId$>", stringLinesNoDigit) #replace strings
        
        stringLinesNoChar = re.sub(r"(['])(?:(?=(\\?))\2.)*?\1", "<strId$>", stringLinesNoStr) #replace chars
        
        #remove comments from source code
        linesNoCom = remove_comments(stringLinesNoChar)
        
        #convert source code from string to list of lines
        lines = stringToList(linesNoCom)
        
        #remove headers
        lines = dropHeaders(lines)
        
        #tokenize lines to list of words
        tokens0 = tokenizeLines(lines)
        
        #remove blank lines
        tokens = dropBlank(tokens0)
        
        #add the filename info
        tokens.insert(0, path)
        #add the label info
        if (label == 1):
            tokens.insert(1, 1)
        else:
            tokens.insert(1, 0)
        
        #merged all files into one list
        allTokens.append(tokens)
        
    return allTokens

def writeSequences(inputPath, neutralPath, vulnPath):
    
    #read neutral
    neutralPath = os.path.join(inputPath, neutralPath)
    neutral = readFiles(neutralPath)

    # read vulnerable
    vulnPath = os.path.join(inputPath, vulnPath)
    vulns = readFiles(vulnPath)
    
    #parse all files
    print("Tokenization is starting...")
    
    neutralTokens = makeSequences(neutral, inputPath, neutralPath, 0)
    vulnTokens = makeSequences(vulns, inputPath, vulnPath, 1)
    
    print("Tokenization has been completed.")
    
    # merge neutral and vulns
    allTokens = neutralTokens + vulnTokens
    
    #save dataset to csv
    print("Save dataset to file...")
    
    with open("sequences.csv","w", encoding="utf8") as f:
        wr = csv.writer(f)
        wr.writerows(allTokens)
    
    print("End of Analysis.") 

    return allTokens 

def uniqueWords(data):
    allWords = []
    for i in range(len(data)):
        for j in range(0, len(data[i])):
            allWords.append(data[i][j])
    
    vc = pd.Series(allWords).value_counts()
    uniques=vc.index.values.tolist()        
    return allWords, uniques, vc

def getUniques(data):
    allWords = []
    for i in range(len(data)):
        for j in range(2, len(data[i])):
            allWords.append(data[i][j])
    
    vc = pd.Series(allWords).value_counts()
    uniques=vc.index.values.tolist()        
    return allWords, uniques, vc

def getLabels(data):
    values = []
    for i in range(len(data)):
        values.append(int(data[i][1]))
    serVal = pd.DataFrame(values)
    return serVal

def writeBow(data, filename):
    features = []
    for i in range(0, len(data)):
        line = data[i][2:]
        features.append(line)
        
    allWords, uniques, tokenFreq = uniqueWords(features)
    
    vocab = uniques #tokenFreq[tokenFreq > 1 ]
    
    labels = getLabels(data)
    
    freqs = []
    for i in range(0, len(features)):
        occ = []
        for j in range(0, len(vocab)):
            occ.append(features[i].count(vocab[j]))
        freqs.append(occ)
    
    dataset = pd.DataFrame.from_records(freqs, columns=vocab)# list of lists to dataframe
    dataset['label'] = labels
    dataset.to_csv(filename, index = None, header=True)

    return dataset

def labelFrequencies(data):
    values = []
    for i in range(len(data)):
        values.append(data[i][1])
    serVal = pd.DataFrame(values)
    return serVal

def getLengths(data):
    lens = []
    for i in range(len(data)):
        lens.append(len(data[i])-2)
    lens = pd.DataFrame(lens)
    lensFreq = lens[0].value_counts()
    lensFreq=pd.DataFrame(lensFreq)
    return lens, lensFreq
 
def getStd(len_sorted, med):
    res=0
    for i in range(len(len_sorted)):
        x = len_sorted.iloc[i,0]
        res = res + (x-med)*(x-med)
    res2 = res / len(len_sorted)
    res_final = math.sqrt(res2)
    print("stdev= ", res_final)
    return res_final
    
def average(lst):
    return sum(lst) / len(lst)

def removeSparse(data, tokens2):
    new_data = []
    for i in range(len(data)):
        new = []
        new.append(data[i][0])
        new.append(data[i][1])
        for j in range(2, len(data[i])):
            temp = data[i][j]
            if temp in tokens2:
                new.append(temp)
        new_data.append(new)
    return new_data
    
def analyzeData():
    
    inputPath = os.getcwd()
    neutralPath = "neutralPy"
    vulnPath = "vuln"
    
    
    ## data cleansing
    #data = writeSequences(inputPath, neutralPath, vulnPath)
    #print("bow")
    with open('sequences.csv', newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        data = list(reader)
    data = dropEmpty(data)
    
    #bow = writeBow(data, 'BoW_dataset.csv')
    #bow = pd.read_csv('BoW_dataset.csv', sep =',')
    
    
    ## data analysis
    allWords, uniques, tokenFreq = uniqueWords(data)
    tokenFreq = pd.DataFrame(tokenFreq)
    l = tokenFreq.index.values.tolist()
    tokenFreq.insert(0,'token', l)
    tokenFreq.rename(columns = {0: 'times'}, inplace = True)
    tokenFreq = tokenFreq.reset_index(drop=True)
    avgToken = tokenFreq['times']
    print("mean of token's appearance = ", average(avgToken))
    print("max of token's appearance = ", max(tokenFreq['times']))
    print("min of token's appearance = ", min(tokenFreq['times']))
    
    '''freqs = tokenFreq['times']
    freqs = freqs.tolist()
    freqs = pd.DataFrame(freqs)
    medFreq = freqs.median()[0]
    print("median= ", medFreq)
    stdevFreq = freqs[0].std()
    print("standard deviation = ", stdevFreq)
    # finding the 1st and 3rd quartiles
    q1 = np.quantile(freqs[0], 0.25)
    q3 = np.quantile(freqs[0], 0.75)
    # finding the iqr region
    iqr = q3-q1
    # finding upper and lower whiskers
    upper_bound = q3+(1.5*iqr)
    lower_bound = q1-(1.5*iqr)
    print(iqr, upper_bound, lower_bound)
    outliers = freqs[0][(freqs[0] <= lower_bound) | (freqs[0] >= upper_bound)]
    #print('The following are the outliers in the boxplot:{}'.format(outliers))
    split_point = len(freqs) - len(outliers)
    print("Splitting point: ", split_point)
    max_len = freqs.iloc[split_point-1,:][0]
    print("max number of occurencies selected: ", max_len)'''
    tokens2 = tokenFreq[tokenFreq['times'] > 10 ]
    new_data = removeSparse(data, tokens2["token"].tolist())
    
    #check balance
    labels = labelFrequencies(new_data)
    labelFreq = labels[0].value_counts()
    print("labels balance:\n",labelFreq)
    
    # find the length of each class file
    lens, lensFreq = getLengths(new_data)
    l = lensFreq.index.values.tolist()
    
    lensFreq.insert(0,'lengths', l)
    lensFreq.rename(columns = {0: 'times'}, inplace = True)
    lensFreq = lensFreq.reset_index(drop=True)
    #print(lensFreq)
    avgLen = average(lens.iloc[:,0])# mesos oros twn sequence lengths
    print("avg of lengths = ",avgLen)
    print("max of lengths = ", max(lens.iloc[:,0]))
    print("min of lengths = ", min(lens.iloc[:,0]))
    
    len_sorted = lens.sort_values(by=[0])
    len_sorted = len_sorted.reset_index(drop=True)
    
    med = len_sorted.median()[0]
    print("median= ", med)
    
    plt.plot(len_sorted[0])
    plt.show()
    
    stdev = len_sorted[0].std()
    print("standard deviation = ", stdev)
    
    #manual computation of st. d.
    stdev2 = getStd(len_sorted, med)
    
    split_point = med + 2*stdev
    print("median + 2*st.d= ", split_point)
    
    plt.boxplot(len_sorted[0])
    plt.show()
    
    # finding the 1st and 3rd quartiles
    q1 = np.quantile(len_sorted[0], 0.25)
    q3 = np.quantile(len_sorted[0], 0.75)
    # finding the iqr region
    iqr = q3-q1
    # finding upper and lower whiskers
    upper_bound = q3+(1.5*iqr)
    lower_bound = q1-(1.5*iqr)
    print(iqr, upper_bound, lower_bound)
    outliers = len_sorted[0][(len_sorted[0] <= lower_bound) | (len_sorted[0] >= upper_bound)]
    #print('The following are the outliers in the boxplot:{}'.format(outliers))
    split_point = len(len_sorted) - len(outliers)
    print("Splitting point: ", split_point)
    max_len = len_sorted.iloc[split_point-1,:][0]
    print("max length selected: ", max_len)
    
    #reshape dataset
    data2 = []
    for i in range(len(new_data)):
        length = len(new_data[i]) - 2
        if length <= max_len :
            data2.append(new_data[i])
    
    #save reduced dataset
    print("Save dataset to file...")
    with open("data_reduced.csv","w", encoding='utf-8') as f:
        wr = csv.writer(f)
        wr.writerows(data2)
    print("End of Analysis.")
    
    
    #reduce dataset in BERT's max lenght = 512 tokesn max per sequence
    data3 = []
    for i in range(len(new_data)):
        length = len(new_data[i]) - 2
        if length <= 510 :  # max_len=512 (510 + SEP and CLS)
            data3.append(new_data[i])
    
    #save reduced dataset
    print("Save dataset to file...")
    with open("data_reduced_bert.csv","w", encoding='utf-8') as f:
        wr = csv.writer(f)
        wr.writerows(data3)
    print("End of Analysis.")
    
    # data analysis on bert reduced set
    #check balance
    labels = labelFrequencies(data3)
    labelFreq = labels[0].value_counts()
    print("labels balance:\n",labelFreq)
    
    allWords, uniques, tokenFreq = uniqueWords(data3)
    print("vocab: ", len(uniques))
    
    # bag of words from reduced dataset
    bow_reduced = writeBow(data3, 'BoW_dataset_reduced.csv')
    #bow_reduced = pd.read_csv('BoW_dataset_reduced.csv', sep =',')
    
    return data3, bow_reduced

def recall_metric(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = (true_positives + K.epsilon()) / (possible_positives + K.epsilon())
        return recall

def precision_metric(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = (true_positives + K.epsilon()) / (predicted_positives + K.epsilon())
        return precision

def f1_metric(y_true, y_pred):

    prec = precision_metric(y_true, y_pred)
    rec = recall_metric(y_true, y_pred)
    f1 = 2*((prec*rec)/(prec+rec+K.epsilon()))
    return f1

def f2_metric(y_true, y_pred):

    prec = precision_metric(y_true, y_pred)
    rec = recall_metric(y_true, y_pred)
    f2 = 5*((prec*rec)/(4*prec+rec+K.epsilon()))
    return f2

def f2_loss(y_true, y_pred):

    y_true = tensorflow.cast(y_true, tensorflow.float32)
    tp = K.sum(K.cast(y_true*y_pred, 'float'), axis=0)
    #tn = K.sum(K.cast((1-y_true)*(1-y_pred), 'float'), axis=0)
    fp = K.sum(K.cast((1-y_true)*y_pred, 'float'), axis=0)
    fn = K.sum(K.cast(y_true*(1-y_pred), 'float'), axis=0)

    p = tp / (tp + fp + K.epsilon())
    r = tp / (tp + fn + K.epsilon())

    f2 = 5*p*r / (4*p+r+K.epsilon())
    f2 = tensorflow.where(tensorflow.math.is_nan(f2), tensorflow.zeros_like(f2), f2)
    
    return 1 - K.mean(f2)


def buildBiLstm(max_len, top_words, dim, seed, embedding_matrix):
    model = Sequential()
    #model.add(Embedding(input_dim=top_words+1, output_dim=dim, input_length=None, mask_zero=True))
    model.add(Embedding(input_dim=top_words, output_dim=dim, input_length=None, weights=[embedding_matrix], mask_zero=True, trainable=False))
    #model.add(SimpleRNN(300, dropout=0.3, stateful=False))
    #model.add(LSTM(100, dropout=0.2, return_sequences=True, stateful=False))
    model.add(Bidirectional(LSTM(100, dropout=0.2, return_sequences=True, stateful=False)))
    model.add(Bidirectional(LSTM(100, dropout=0.2, stateful=False)))
    #model.add(LSTM(100, dropout=0.2, stateful=False))
    #model.add(Activation('relu')) #dropout=0.2, recurrent_dropout=0.2, kernel_constraint=max_norm(3), bias_constraint=max_norm(3)
    #model.add(BatchNormalization(momentum=0.0))
    model.add(Dense(1,activation='sigmoid'))
    #model.compile(loss=f2_loss, optimizer='adam', metrics=[f2_metric])
    model.compile(loss="binary_crossentropy", optimizer='adam', metrics=[f2_metric])
    return model

def buildLstm(max_len, top_words, dim, seed, embedding_matrix):
    model = Sequential()
    #model.add(Embedding(input_dim=top_words+1, output_dim=dim, input_length=None, mask_zero=True))
    model.add(Embedding(input_dim=top_words, output_dim=dim, input_length=None, weights=[embedding_matrix], mask_zero=True, trainable=False))
    #model.add(SimpleRNN(300, dropout=0.3, stateful=False))
    model.add(LSTM(100, dropout=0.2, return_sequences=True, stateful=False))
    #model.add(Bidirectional(LSTM(300, dropout=0.3, stateful=False)))
    model.add(LSTM(100, dropout=0.2, stateful=False))
    #model.add(Activation('relu')) #dropout=0.2, recurrent_dropout=0.2, kernel_constraint=max_norm(3), bias_constraint=max_norm(3)
    #model.add(BatchNormalization(momentum=0.0))
    model.add(Dense(1,activation='sigmoid'))
    #model.compile(loss=f2_loss, optimizer='adam', metrics=[f2_metric])
    model.compile(loss="binary_crossentropy", optimizer='adam', metrics=[f2_metric])
    return model

def buildCnn(max_len, top_words, dim, seed, embedding_matrix):
    cnn_model = Sequential()
    cnn_model.add(Embedding(top_words, dim, input_length=None, weights=[embedding_matrix], mask_zero=True, trainable=False))
    cnn_model.add(Conv1D(filters = 128, kernel_size = 5, activation = 'relu'))
    '''cnn_model.add(MaxPooling1D(pool_size = 5))
    cnn_model.add(Conv1D(filters = 128, kernel_size = 5, activation = 'relu'))
    cnn_model.add(MaxPooling1D(pool_size = 5))
    cnn_model.add(Conv1D(filters = 128, kernel_size = 5, activation = 'relu'))'''
    cnn_model.add(GlobalMaxPool1D())
    #cnn_model.add(Dense(units = 128, activation = 'relu'))
    cnn_model.add(Dense(units = 1, activation = 'sigmoid'))
    #cnn_model.compile(loss=f2_loss, optimizer='adam', metrics=[f2_metric])
    cnn_model.compile(loss="binary_crossentropy", optimizer = "adam") # "binary_crossentropy" # f2_loss
    return cnn_model

# %%
# Read pythonvp directory and construct train and test csv files.
def extract_tokens_from_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        try:
            content = file.read()
            tokens = content.split()  # Split content into words
            return ','.join(tokens)
        except:
            return ""

def create_csv(directory, output_csv):
    with open(output_csv, 'w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(['File', 'Tokens'])

        for root, _, files in os.walk(directory):
            for file in files:
                file_path = os.path.join(root, file)
                tokens = extract_tokens_from_file(file_path)
                csv_writer.writerow([file_path, tokens])

def add_label_to_csv(input_csv, label_value, output_csv):
    df = pd.read_csv(input_csv)
    df['Label'] = label_value
    df.to_csv(output_csv, index=False)

def concatenate_csvs(csv1, csv2, output_csv):
    df1 = pd.read_csv(csv1)
    df2 = pd.read_csv(csv2)
    merged_df = pd.concat([df1, df2], ignore_index=True)
    merged_df.to_csv(output_csv, index=False)

base_directory = 'pythonvp'
train_val_clean_csv = 'train_val_clean.csv'
train_val_vuln_csv = 'train_val_vuln.csv'
test_clean_csv = 'test_clean.csv'
test_vuln_csv = 'test_vuln.csv'
test_clean_labeled_csv = 'test_clean_labeled.csv'
test_vuln_labeled_csv = 'test_vuln_labeled.csv'
train_val_clean_labeled_csv = 'train_val_clean_labeled.csv'
train_val_vuln_labeled_csv = 'train_val_vuln_labeled.csv'
train_val_merged_csv = 'train_val_merged.csv'
test_merged_csv = 'test_merged.csv'

train_val_clean_dir = os.path.join(base_directory, 'train_val', 'clean')
train_val_vuln_dir = os.path.join(base_directory, 'train_val', 'vuln')
test_clean_dir = os.path.join(base_directory, 'test', 'clean')
test_vuln_dir = os.path.join(base_directory, 'test', 'vuln')

create_csv(train_val_clean_dir, train_val_clean_csv)
create_csv(train_val_vuln_dir, train_val_vuln_csv)
create_csv(test_clean_dir, test_clean_csv)
create_csv(test_vuln_dir, test_vuln_csv)

# Add label column with value 0 to test_clean_csv
add_label_to_csv(train_val_clean_csv, 0, train_val_clean_labeled_csv)

# Add label column with value 1 to test_vuln_csv
add_label_to_csv(train_val_vuln_csv, 1, train_val_vuln_labeled_csv)

# Add label column with value 0 to test_clean_csv
add_label_to_csv(test_clean_csv, 0, test_clean_labeled_csv)

# Add label column with value 1 to test_vuln_csv
add_label_to_csv(test_vuln_csv, 1, test_vuln_labeled_csv)

concatenate_csvs(train_val_clean_labeled_csv, train_val_vuln_labeled_csv, train_val_merged_csv)
concatenate_csvs(test_clean_labeled_csv, test_vuln_labeled_csv, test_merged_csv)

# %%
with open(train_val_merged_csv, newline='', encoding='utf-8') as f:
    reader = csv.reader(f)
    data = list(reader)
data = data[1:]

train_data = []
for i in range(0, len(data)):
    d = data[i]
    new_row = [d[0]]
    input_string = d[1]
    string_list = input_string.split(',')
    new_row.extend(string_list)
    new_row.append(d[2]) 
    train_data.append(new_row)



with open(test_merged_csv, newline='', encoding='utf-8') as f:
    reader = csv.reader(f)
    data = list(reader)
data = data[1:]

test_data = []
for i in range(0, len(data)):
    d = data[i]
    new_row = [d[0]]
    input_string = d[1]
    string_list = input_string.split(',')
    new_row.extend(string_list)
    new_row.append(d[2]) 
    test_data.append(new_row)
test_data

train_len = len(train_data)
train_data.extend(test_data)

all_data = []
for inner_list in train_data:
    last_element = inner_list.pop() 
    inner_list.insert(1, last_element)
    all_data.append(inner_list)

# %%
# deep learning
lines = []
for i in range(0, len(all_data)):
    line = all_data[i][2:]
    lows = [w.lower() for w in line]
    lines.append(lows)

lens, lensFreq = getLengths(lines)
max_len = max(lens[0]) + 2

labels = getLabels(all_data)
max_len
# Out:
# 510

# %%
for i in range(0, len(all_data)):
    if all_data[i][1] == '1':
        print(all_data[i][0])
# Out:
# pythonvp\train_val\vuln\_0x0F-python-object_relational_mapping_1-filter_states_2190.py
# pythonvp\train_val\vuln\_0x0F-python-object_relational_mapping_10-model_state_my_get_2056.py
# pythonvp\train_val\vuln\_0x0F-python-object_relational_mapping_3-my_safe_filter_states_2042.py
# pythonvp\train_val\vuln\_2016_13_solve_1112.py
# pythonvp\train_val\vuln\_3-back-end_codes_tournament_tournament_2186.py
# pythonvp\train_val\vuln\_acedu_hwmllib_618.py
# pythonvp\train_val\vuln\_addons_point_of_sale_wizard_pos_close_statement_1582.py
# pythonvp\train_val\vuln\_addons_point_of_sale_wizard_pos_close_statement_1586.py
# pythonvp\train_val\vuln\_addons_point_of_sale_wizard_pos_close_statement_1590.py
# pythonvp\train_val\vuln\_addons_point_of_sale_wizard_pos_close_statement_1594.py
# pythonvp\train_val\vuln\_addons_point_of_sale_wizard_pos_close_statement_1600.py
# pythonvp\train_val\vuln\_addons_point_of_sale_wizard_pos_open_statement_1584.py
# pythonvp\train_val\vuln\_addons_point_of_sale_wizard_pos_open_statement_1588.py
# pythonvp\train_val\vuln\_addons_point_of_sale_wizard_pos_open_statement_1592.py
# pythonvp\train_val\vuln\_addons_point_of_sale_wizard_pos_open_statement_1602.py
# pythonvp\train_val\vuln\_AddScoresToDatabase_2338.py
# pythonvp\train_val\vuln\_adhocracy_lib_xsrf_2832.py
# pythonvp\train_val\vuln\_adhocracy_lib_xsrf_2838.py
# pythonvp\train_val\vuln\_adhocracy_model_openid_2834.py
# pythonvp\train_val\vuln\_adhocracy_model_openid_2840.py
# pythonvp\train_val\vuln\_admin_300.py
# pythonvp\train_val\vuln\_aeoid_handlers_2650.py
# pythonvp\train_val\vuln\_ajar_196.py
# pythonvp\train_val\vuln\_ampy_netevmon_2324.py
# pythonvp\train_val\vuln\_answerQuestions_2408.py
# pythonvp\train_val\vuln\_apis_admins_2480.py
# pythonvp\train_val\vuln\_apis_login_2482.py
# pythonvp\train_val\vuln\_apis_users_2486.py
# pythonvp\train_val\vuln\_API_api_3098.py
# pythonvp\train_val\vuln\_API_api_3100.py
# pythonvp\train_val\vuln\_api_app_admin_examtype_408.py
# pythonvp\train_val\vuln\_api_app_admin_office_410.py
# pythonvp\train_val\vuln\_api_app_resources_bookings_exam_exam_list_412.py
# pythonvp\train_val\vuln\_api_blueprints_locations_controllers_2334.py
# pythonvp\train_val\vuln\_api_blueprints_locations_controllers_2412.py
# pythonvp\train_val\vuln\_aplus_api___init___1480.py
# pythonvp\train_val\vuln\_aplus_settings_1482.py
# pythonvp\train_val\vuln\_appengine_cr-buildbucket_handlers_3058.py
# pythonvp\train_val\vuln\_appengine_machine_provider_handlers_frontend_2760.py
# pythonvp\train_val\vuln\_appengine_swarming_swarming_bot_api_bot_test_2746.py
# pythonvp\train_val\vuln\_appengine_swarming_swarming_bot_api_bot_test_2798.py
# pythonvp\train_val\vuln\_appengine_swarming_swarming_bot___main___2742.py
# pythonvp\train_val\vuln\_appengine_swarming_swarming_bot___main___2794.py
# pythonvp\train_val\vuln\_application_issues_views_1700.py
# pythonvp\train_val\vuln\_application_people_views_1702.py
# pythonvp\train_val\vuln\_apps_domain_views_660.py
# pythonvp\train_val\vuln\_apps_filehash_views_662.py
# pythonvp\train_val\vuln\_apps_ip_views_666.py
# pythonvp\train_val\vuln\_apps_migrations_0001_initial_1484.py
# pythonvp\train_val\vuln\_apps_templatetags_apps_1486.py
# pythonvp\train_val\vuln\_apps_threat_hunter_views_670.py
# pythonvp\train_val\vuln\_apps_twitter_views_672.py
# pythonvp\train_val\vuln\_apps_url_forms_676.py
# pythonvp\train_val\vuln\_apps_users_tests_390.py
# pythonvp\train_val\vuln\_apps_users_tests_394.py
# pythonvp\train_val\vuln\_apps_users_tests_396.py
# pythonvp\train_val\vuln\_apps_users_tests_398.py
# pythonvp\train_val\vuln\_apps_users_tests_400.py
# pythonvp\train_val\vuln\_apps_users_tests_402.py
# pythonvp\train_val\vuln\_app_1654.py
# pythonvp\train_val\vuln\_app_1852.py
# pythonvp\train_val\vuln\_app_2262.py
# pythonvp\train_val\vuln\_app_2330.py
# pythonvp\train_val\vuln\_app_2332.py
# pythonvp\train_val\vuln\_app_2388.py
# pythonvp\train_val\vuln\_app_2454.py
# pythonvp\train_val\vuln\_app_2602.py
# pythonvp\train_val\vuln\_app_2608.py
# pythonvp\train_val\vuln\_app_2854.py
# pythonvp\train_val\vuln\_app_access_3020.py
# pythonvp\train_val\vuln\_app_admin_api_keys_2652.py
# pythonvp\train_val\vuln\_app_api_common_1126.py
# pythonvp\train_val\vuln\_app_api_common_1132.py
# pythonvp\train_val\vuln\_app_api_songs_2372.py
# pythonvp\train_val\vuln\_app_api_urls_1118.py
# pythonvp\train_val\vuln\_app_api_urls_1124.py
# pythonvp\train_val\vuln\_app_api_urls_1130.py
# pythonvp\train_val\vuln\_app_api_urls_1136.py
# pythonvp\train_val\vuln\_app_auth_test_test_model_1814.py
# pythonvp\train_val\vuln\_app_comments_api_v1_view_1816.py
# pythonvp\train_val\vuln\_app_config_3120.py
# pythonvp\train_val\vuln\_app_Index_views_3176.py
# pythonvp\train_val\vuln\_app_migrations_db_1818.py
# pythonvp\train_val\vuln\_app_models_sql_books_2204.py
# pythonvp\train_val\vuln\_App_Server_2312.py
# pythonvp\train_val\vuln\_app_soc_modules_gsoc_tasks_program_freezer_2850.py
# pythonvp\train_val\vuln\_app_soc_modules_gsoc_tasks_program_freezer_2852.py
# pythonvp\train_val\vuln\_app_urls_2654.py
# pythonvp\train_val\vuln\_app_utils_216.py
# pythonvp\train_val\vuln\_app_v2_models_base_model_2160.py
# pythonvp\train_val\vuln\_app_v2_models_base_model_2162.py
# pythonvp\train_val\vuln\_app_views_218.py
# pythonvp\train_val\vuln\_app___init___1808.py
# pythonvp\train_val\vuln\_authorization_permissions_1488.py
# pythonvp\train_val\vuln\_awx_main_models_credential_injectors_318.py
# pythonvp\train_val\vuln\_awx_main_scheduler_dag_simple_314.py
# pythonvp\train_val\vuln\_awx_main_scheduler_dag_workflow_316.py
# pythonvp\train_val\vuln\_backend_base_2814.py
# pythonvp\train_val\vuln\_backend_models_commands_292.py
# pythonvp\train_val\vuln\_backend_transactions_TransactionConnector_2078.py
# pythonvp\train_val\vuln\_backend_transactions_TransactionConnector_2080.py
# pythonvp\train_val\vuln\_backend_transactions_TransactionConnector_2082.py
# pythonvp\train_val\vuln\_bag_web_pyramid_angular_csrf_2816.py
# pythonvp\train_val\vuln\_bases_createcfbase_2044.py
# pythonvp\train_val\vuln\_bases_createuserbase_2046.py
# pythonvp\train_val\vuln\_base_crapo_workflow_mixins_crapo_readonly_view_mixin_1780.py
# pythonvp\train_val\vuln\_base_crapo_workflow_models_business_object_1782.py
# pythonvp\train_val\vuln\_base_crapo_workflow_models_state_1784.py
# pythonvp\train_val\vuln\_beamr_cli_264.py
# pythonvp\train_val\vuln\_beamr_debug_266.py
# pythonvp\train_val\vuln\_beamr_lexers_document_274.py
# pythonvp\train_val\vuln\_beamr_lexers_slide_278.py
# pythonvp\train_val\vuln\_beamr_parsers_document_280.py
# pythonvp\train_val\vuln\_beamr_parsers_image_282.py
# pythonvp\train_val\vuln\_beamr_parsers_slide_284.py
# pythonvp\train_val\vuln\_benchmarkSpider_benchmarkSpider_generator_594.py
# pythonvp\train_val\vuln\_benchmark_core_1390.py
# pythonvp\train_val\vuln\_benchmark_core_1422.py
# pythonvp\train_val\vuln\_benwaonline_auth_views_486.py
# pythonvp\train_val\vuln\_benwaonline_blueprints_benwaonline_488.py
# pythonvp\train_val\vuln\_benwaonline_gallery_views_490.py
# pythonvp\train_val\vuln\_benwaonline___init___484.py
# pythonvp\train_val\vuln\_blueprints_database_2264.py
# pythonvp\train_val\vuln\_blueprints_forum_2266.py
# pythonvp\train_val\vuln\_blueprints_post_2268.py
# pythonvp\train_val\vuln\_blueprints_user_2272.py
# pythonvp\train_val\vuln\_book_rides_book_rides_2126.py
# pythonvp\train_val\vuln\_bot_2314.py
# pythonvp\train_val\vuln\_bot_326.py
# pythonvp\train_val\vuln\_bot_334.py
# pythonvp\train_val\vuln\_brewdiedb_1620.py
# pythonvp\train_val\vuln\_bzs_core_1452.py
# pythonvp\train_val\vuln\_bzs_module_error404_1454.py
# pythonvp\train_val\vuln\_bzs_module_home_1458.py
# pythonvp\train_val\vuln\_c3shop_frontpage_management_mediatools_media_actions_3144.py
# pythonvp\train_val\vuln\_cauldron_session_buffering_612.py
# pythonvp\train_val\vuln\_cauldron_session_report_614.py
# pythonvp\train_val\vuln\_CE_settings_3134.py
# pythonvp\train_val\vuln\_cf_dir_2360.py
# pythonvp\train_val\vuln\_cgi_common_1630.py
# pythonvp\train_val\vuln\_cgi_common_1636.py
# pythonvp\train_val\vuln\_cgi_create_game_1632.py
# pythonvp\train_val\vuln\_cgi_create_game_1638.py
# pythonvp\train_val\vuln\_cgi_move_1634.py
# pythonvp\train_val\vuln\_CheckAndPostForSeriesSubmissions_2340.py
# pythonvp\train_val\vuln\_checker_dns_check_88.py
# pythonvp\train_val\vuln\_checker_ssh_check_90.py
# pythonvp\train_val\vuln\_cheshire3_sql_resultSetStore_2012.py
# pythonvp\train_val\vuln\_chippyRuxpin_1218.py
# pythonvp\train_val\vuln\_cinder_volume_drivers_san_san_110.py
# pythonvp\train_val\vuln\_cinder_volume_drivers_san_san_122.py
# pythonvp\train_val\vuln\_cinder_volume_drivers_san_san_134.py
# pythonvp\train_val\vuln\_cinder_volume_drivers_san_san_146.py
# pythonvp\train_val\vuln\_cinder_volume_drivers_san_san_98.py
# pythonvp\train_val\vuln\_circuits_web_dispatchers_dispatcher_850.py
# pythonvp\train_val\vuln\_ckanext_data_qld_commands_718.py
# pythonvp\train_val\vuln\_ckan_models_package_1436.py
# pythonvp\train_val\vuln\_ckan_models_package_1438.py
# pythonvp\train_val\vuln\_ckan_models_package_1440.py
# pythonvp\train_val\vuln\_ckan_models_package_1442.py
# pythonvp\train_val\vuln\_client_tests_net_utils_2752.py
# pythonvp\train_val\vuln\_client_tests_net_utils_2804.py
# pythonvp\train_val\vuln\_cmds_remindme_1738.py
# pythonvp\train_val\vuln\_cmstestsuite_web_AWSRequests_3030.py
# pythonvp\train_val\vuln\_cmstestsuite_web_AWSRequests_3040.py
# pythonvp\train_val\vuln\_coalib_misc_Shell_160.py
# pythonvp\train_val\vuln\_coalib_misc_Shell_172.py
# pythonvp\train_val\vuln\_coalib_misc_Shell_180.py
# pythonvp\train_val\vuln\_coalib_misc_Shell_184.py
# pythonvp\train_val\vuln\_coalib_misc_Shell_192.py
# pythonvp\train_val\vuln\_coalib_tests_bearlib_abstractions_LintTest_162.py
# pythonvp\train_val\vuln\_coalib_tests_bearlib_abstractions_LintTest_174.py
# pythonvp\train_val\vuln\_coalib_tests_misc_ShellTest_164.py
# pythonvp\train_val\vuln\_coalib_tests_misc_ShellTest_176.py
# pythonvp\train_val\vuln\_coalib_tests_misc_ShellTest_188.py
# pythonvp\train_val\vuln\_codewatch_file_walker_1156.py
# pythonvp\train_val\vuln\_cogs_database_158.py
# pythonvp\train_val\vuln\_cogs_dictionaries_wordnik_64.py
# pythonvp\train_val\vuln\_comics-app_comics_1734.py
# pythonvp\train_val\vuln\_comics-app_utils_1736.py
# pythonvp\train_val\vuln\_comics_check_comics_2008.py
# pythonvp\train_val\vuln\_common_json_schema_2604.py
# pythonvp\train_val\vuln\_common_src_stack_command_stack_commands_list_storage_controller___init___32.py
# pythonvp\train_val\vuln\_common_src_stack_command_stack_commands_list_storage_partition___init___34.py
# pythonvp\train_val\vuln\_common_src_stack_command_stack_commands_list_storage_partition___init___38.py
# pythonvp\train_val\vuln\_common_src_stack_command_stack_commands_set_attr_doc___init___42.py
# pythonvp\train_val\vuln\_common___init___2582.py
# pythonvp\train_val\vuln\_config_492.py
# pythonvp\train_val\vuln\_constants_2034.py
# pythonvp\train_val\vuln\_content_xss_3166.py
# pythonvp\train_val\vuln\_controllers_fit_event_controller_730.py
# pythonvp\train_val\vuln\_controller_api_tests_test_api_middleware_2908.py
# pythonvp\train_val\vuln\_controller_api_tests_test_api_middleware_2934.py
# pythonvp\train_val\vuln\_controller_api_tests_test_auth_2886.py
# pythonvp\train_val\vuln\_controller_api_tests_test_auth_2912.py
# pythonvp\train_val\vuln\_controller_api_tests_test_key_2896.py
# pythonvp\train_val\vuln\_controller_api_tests_test_key_2922.py
# pythonvp\train_val\vuln\_controller_api_tests_test_key_2948.py
# pythonvp\train_val\vuln\_controller_deis_settings_2906.py
# pythonvp\train_val\vuln\_controller_deis_settings_2932.py
# pythonvp\train_val\vuln\_controller_deis_settings_2958.py
# pythonvp\train_val\vuln\_core_logger_2624.py
# pythonvp\train_val\vuln\_core_options_2626.py
# pythonvp\train_val\vuln\_cornice_tests_test_validation_2702.py
# pythonvp\train_val\vuln\_cornice_validators_2704.py
# pythonvp\train_val\vuln\_course_cache_menu_1490.py
# pythonvp\train_val\vuln\_course_migrations_0001_initial_1492.py
# pythonvp\train_val\vuln\_course_migrations_0005_auto_20150625_1835_1494.py
# pythonvp\train_val\vuln\_course_migrations_0011_auto_20151215_1133_1498.py
# pythonvp\train_val\vuln\_course_migrations_0021_auto_20160726_1209_1500.py
# pythonvp\train_val\vuln\_course_migrations_0025_auto_20160728_1139_1502.py
# pythonvp\train_val\vuln\_course_migrations_0029_usertags_1504.py
# pythonvp\train_val\vuln\_course_permissions_1506.py
# pythonvp\train_val\vuln\_crapo_tests_models_crm_stage_1776.py
# pythonvp\train_val\vuln\_crapo_tests_models_crm_stage_1786.py
# pythonvp\train_val\vuln\_crapo_tests_models_crm_stage_1790.py
# pythonvp\train_val\vuln\_crapo_tests_models_crm_stage_1792.py
# pythonvp\train_val\vuln\_CreateTableFromDatabase_2342.py
# pythonvp\train_val\vuln\_crimemap_2128.py
# pythonvp\train_val\vuln\_crimemap_2362.py
# pythonvp\train_val\vuln\_crimemap_dbhelper_1664.py
# pythonvp\train_val\vuln\_crm_phonecall_models_crm_lead_1844.py
# pythonvp\train_val\vuln\_crm_phonecall_report_crm_phonecall_report_1846.py
# pythonvp\train_val\vuln\_cuckoo_web_controllers_analysis_export_export_804.py
# pythonvp\train_val\vuln\_cuckoo_web_controllers_analysis_export_export_812.py
# pythonvp\train_val\vuln\_cuckoo_web_controllers_submission_api_810.py
# pythonvp\train_val\vuln\_cuckoo_web_controllers_submission_api_828.py
# pythonvp\train_val\vuln\_cuckoo_web_controllers_submission_api_834.py
# pythonvp\train_val\vuln\_curtin_deps___init___72.py
# pythonvp\train_val\vuln\_custodia_store_etcdstore_852.py
# pythonvp\train_val\vuln\_custodia_store_etcdstore_870.py
# pythonvp\train_val\vuln\_custodia_store_etcdstore_872.py
# pythonvp\train_val\vuln\_dashboard_admin_508.py
# pythonvp\train_val\vuln\_dashboard_models_data_group_532.py
# pythonvp\train_val\vuln\_dashboard_models_extracted_functional_use_536.py
# pythonvp\train_val\vuln\_dashboard_models_extracted_list_presence_538.py
# pythonvp\train_val\vuln\_dashboard_models_extracted_text_540.py
# pythonvp\train_val\vuln\_dashboard_models_ingredient_542.py
# pythonvp\train_val\vuln\_dashboard_models_PUC_520.py
# pythonvp\train_val\vuln\_dashboard_models_PUC_526.py
# pythonvp\train_val\vuln\_dashboard_models_qa_notes_544.py
# pythonvp\train_val\vuln\_dashboard_models_raw_chem_546.py
# pythonvp\train_val\vuln\_dashboard_models_script_548.py
# pythonvp\train_val\vuln\_dashboard_models_taxonomy_550.py
# pythonvp\train_val\vuln\_dashboard_settings_3158.py
# pythonvp\train_val\vuln\_dashboard_tests_functional_test_dashboard_522.py
# pythonvp\train_val\vuln\_dashboard_tests_functional_test_dashboard_552.py
# pythonvp\train_val\vuln\_dashboard_tests_functional_test_extracted_qa_558.py
# pythonvp\train_val\vuln\_dashboard_tests_functional_test_faceted_search_560.py
# pythonvp\train_val\vuln\_dashboard_tests_integration_test_user_experience_566.py
# pythonvp\train_val\vuln\_dashboard_tests_unit_test_extracted_text_570.py
# pythonvp\train_val\vuln\_dashboard_tests_unit_test_habits_n_practices_572.py
# pythonvp\train_val\vuln\_dashboard_views_dashboard_574.py
# pythonvp\train_val\vuln\_dashboard_views_data_document_576.py
# pythonvp\train_val\vuln\_dashboard_views_get_data_516.py
# pythonvp\train_val\vuln\_dashboard_views_get_data_582.py
# pythonvp\train_val\vuln\_dashboard_views_habits_n_practices_584.py
# pythonvp\train_val\vuln\_data-ingester_timescale_poster_timescale_poster_2068.py
# pythonvp\train_val\vuln\_databaseConnectivity_databaseController_2102.py
# pythonvp\train_val\vuln\_database_1726.py
# pythonvp\train_val\vuln\_database_2384.py
# pythonvp\train_val\vuln\_database_2386.py
# pythonvp\train_val\vuln\_database_2988.py
# pythonvp\train_val\vuln\_database_mysql_2296.py
# pythonvp\train_val\vuln\_database_setup_494.py
# pythonvp\train_val\vuln\_dataduct_steps_scripts_sql_runner_2138.py
# pythonvp\train_val\vuln\_dataduct_steps_scripts_sql_runner_2140.py
# pythonvp\train_val\vuln\_dbhelper_1666.py
# pythonvp\train_val\vuln\_dbhelper_1686.py
# pythonvp\train_val\vuln\_dbhelper_1722.py
# pythonvp\train_val\vuln\_dbhelper_1940.py
# pythonvp\train_val\vuln\_dbhelper_1946.py
# pythonvp\train_val\vuln\_dbhelper_1960.py
# pythonvp\train_val\vuln\_dbhelper_2070.py
# pythonvp\train_val\vuln\_dbhelper_2130.py
# pythonvp\train_val\vuln\_dbhelper_2356.py
# pythonvp\train_val\vuln\_dbhelper_2364.py
# pythonvp\train_val\vuln\_dbhelper_2518.py
# pythonvp\train_val\vuln\_dbhelper_2596.py
# pythonvp\train_val\vuln\_db_1974.py
# pythonvp\train_val\vuln\_db_2178.py
# pythonvp\train_val\vuln\_db_2306.py
# pythonvp\train_val\vuln\_db_dao_1626.py
# pythonvp\train_val\vuln\_db_dbase_2344.py
# pythonvp\train_val\vuln\_db_dbase_2346.py
# pythonvp\train_val\vuln\_db_dbase_2348.py
# pythonvp\train_val\vuln\_db_db_processor_mysql_1628.py
# pythonvp\train_val\vuln\_db_helper_2316.py
# pythonvp\train_val\vuln\_dciagent_plugins_ansibleplugin_1258.py
# pythonvp\train_val\vuln\_deposit_1908.py
# pythonvp\train_val\vuln\_deviations_migrations_0001_initial_1510.py
# pythonvp\train_val\vuln\_diploma_grade_1512.py
# pythonvp\train_val\vuln\_diploma_migrations_0001_initial_1514.py
# pythonvp\train_val\vuln\_diploma_templatetags_diploma_1516.py
# pythonvp\train_val\vuln\_director_projects_source_forms_990.py
# pythonvp\train_val\vuln\_discord_service_336.py
# pythonvp\train_val\vuln\_django_apogee_views_rest_2374.py
# pythonvp\train_val\vuln\_django_contrib_postgres_fields_hstore_2448.py
# pythonvp\train_val\vuln\_django_contrib_postgres_fields_jsonb_2450.py
# pythonvp\train_val\vuln\_django_views_static_376.py
# pythonvp\train_val\vuln\_django_views_static_378.py
# pythonvp\train_val\vuln\_django_views_static_382.py
# pythonvp\train_val\vuln\_django_views_static_384.py
# pythonvp\train_val\vuln\_django_views_static_682.py
# pythonvp\train_val\vuln\_docker_app_1796.py
# pythonvp\train_val\vuln\_earth_enterprise_src_server_wsgi_wms_ogc_gee_maps_server_handler_714.py
# pythonvp\train_val\vuln\_edit_course_templatetags_editcourse_1518.py
# pythonvp\train_val\vuln\_emonitor_devices_fake_2194.py
# pythonvp\train_val\vuln\_emonitor_devices_generic_2196.py
# pythonvp\train_val\vuln\_emonitor_run_2198.py
# pythonvp\train_val\vuln\_engineauth_middleware_688.py
# pythonvp\train_val\vuln\_entry_2114.py
# pythonvp\train_val\vuln\_erpnext_hr_report_employee_leave_balance_employee_leave_balance_2490.py
# pythonvp\train_val\vuln\_erpnext_hr_report_employee_leave_balance_employee_leave_balance_2496.py
# pythonvp\train_val\vuln\_erpnext_hr_report_employee_leave_balance_employee_leave_balance_2502.py
# pythonvp\train_val\vuln\_erpnext_stock_report_inactive_items_inactive_items_2492.py
# pythonvp\train_val\vuln\_erpnext_stock_report_inactive_items_inactive_items_2498.py
# pythonvp\train_val\vuln\_erpnext_stock_report_inactive_items_inactive_items_2504.py
# pythonvp\train_val\vuln\_erpnext_stock_report_inactive_items_inactive_items_2508.py
# pythonvp\train_val\vuln\_erpnext_stock_report_inactive_items_inactive_items_2510.py
# pythonvp\train_val\vuln\_erpnext_templates_utils_1828.py
# pythonvp\train_val\vuln\_erpnext_templates_utils_1830.py
# pythonvp\train_val\vuln\_erpnext_templates_utils_2488.py
# pythonvp\train_val\vuln\_erpnext_templates_utils_2494.py
# pythonvp\train_val\vuln\_erpnext_templates_utils_2500.py
# pythonvp\train_val\vuln\_everest_repositories_state_1044.py
# pythonvp\train_val\vuln\_everest_tests_test_memory_cache_1046.py
# pythonvp\train_val\vuln\_everest_tests_test_traversalpath_1048.py
# pythonvp\train_val\vuln\_everest_traversalpath_1052.py
# pythonvp\train_val\vuln\_evproxy_1398.py
# pythonvp\train_val\vuln\_examples_sql_statements_1472.py
# pythonvp\train_val\vuln\_executionpath_1104.py
# pythonvp\train_val\vuln\_exercise_migrations_0005_auto_20150625_1821_1526.py
# pythonvp\train_val\vuln\_exercise_migrations_0007_auto_20150625_1835_1528.py
# pythonvp\train_val\vuln\_exercise_migrations_0011_auto_20151218_0857_1530.py
# pythonvp\train_val\vuln\_exercise_migrations_0014_ltiexercise_1532.py
# pythonvp\train_val\vuln\_exercise_migrations_0015_auto_20160124_2139_1534.py
# pythonvp\train_val\vuln\_experimental_python_buford_model_applicant_1618.py
# pythonvp\train_val\vuln\_experimental_python_buford_model_visitor_1616.py
# pythonvp\train_val\vuln\_external_services_migrations_0001_initial_1540.py
# pythonvp\train_val\vuln\_external_services_migrations_0002_auto_20150427_1717_1542.py
# pythonvp\train_val\vuln\_flaskr_flaskr_flaskr2_2144.py
# pythonvp\train_val\vuln\_flask_appbuilder_urltools_1742.py
# pythonvp\train_val\vuln\_flask_appbuilder_urltools_1746.py
# pythonvp\train_val\vuln\_flask_appbuilder_urltools_1750.py
# pythonvp\train_val\vuln\_flask_appbuilder_urltools_1754.py
# pythonvp\train_val\vuln\_flask_appbuilder_urltools_1758.py
# pythonvp\train_val\vuln\_flask_flask_mysql_users_mysqlconnection_2614.py
# pythonvp\train_val\vuln\_flask_flask_mysql_users_server_2616.py
# pythonvp\train_val\vuln\_flex_core_1240.py
# pythonvp\train_val\vuln\_flowerytrails_1062.py
# pythonvp\train_val\vuln\_forumdb_1672.py
# pythonvp\train_val\vuln\_forum_forumdb_1980.py
# pythonvp\train_val\vuln\_frappe_desk_search_2422.py
# pythonvp\train_val\vuln\_frappe_desk_search_2428.py
# pythonvp\train_val\vuln\_frappe_tests_test_db_query_2420.py
# pythonvp\train_val\vuln\_frappe_tests_test_db_query_2426.py
# pythonvp\train_val\vuln\_freemail_views_3018.py
# pythonvp\train_val\vuln\_freepbx_wav_to_mp3_converter_1668.py
# pythonvp\train_val\vuln\_funding_views_608.py
# pythonvp\train_val\vuln\_gallery_gallery_918.py
# pythonvp\train_val\vuln\_gamechange___init___3016.py
# pythonvp\train_val\vuln\_gateway_code_utils_cli_serial_redirection_440.py
# pythonvp\train_val\vuln\_getAlcohol_2060.py
# pythonvp\train_val\vuln\_get_historical_data_1684.py
# pythonvp\train_val\vuln\_Get_the_machine_learning_basics_Classification_Template_classification_template_1252.py
# pythonvp\train_val\vuln\_Get_the_machine_learning_basics_Data_Preprocessing_Template_data_preprocessing_template_1254.py
# pythonvp\train_val\vuln\_grab-monorail_2622.py
# pythonvp\train_val\vuln\_grapher_2206.py
# pythonvp\train_val\vuln\_Gui_3024.py
# pythonvp\train_val\vuln\_handlers_password_2818.py
# pythonvp\train_val\vuln\_handlers_register_2820.py
# pythonvp\train_val\vuln\_handlers_upload_2822.py
# pythonvp\train_val\vuln\_harnesses_host_controller_build_pab_client_3082.py
# pythonvp\train_val\vuln\_harnesses_host_controller_build_pab_client_3086.py
# pythonvp\train_val\vuln\_harnesses_host_controller_build_pab_client_test_3084.py
# pythonvp\train_val\vuln\_harnesses_host_controller_build_pab_client_test_3088.py
# pythonvp\train_val\vuln\_hybrid_package_info_1142.py
# pythonvp\train_val\vuln\_hybrid_package_info_1144.py
# pythonvp\train_val\vuln\_hybrid_package_info_796.py
# pythonvp\train_val\vuln\_impl_902.py
# pythonvp\train_val\vuln\_in-class_15 SQL and the Django ORM_example vulnerable application_sio_views_1962.py
# pythonvp\train_val\vuln\_in-class_15 SQL and the Django ORM_example vulnerable application_webapps_settings_1964.py
# pythonvp\train_val\vuln\_inheritance_migrations_0001_initial_1546.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_config_1182.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_config_1192.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_config_1202.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_config_2628.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_config_2638.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_contrib_orcid_1194.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_contrib_orcid_1204.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_contrib_orcid_2630.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_contrib_orcid_2640.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_views_client_1200.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_views_client_1210.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_views_client_2636.py
# pythonvp\train_val\vuln\_invenio_modules_oauthclient_views_client_2646.py
# pythonvp\train_val\vuln\_ipvc_branch_994.py
# pythonvp\train_val\vuln\_items_2990.py
# pythonvp\train_val\vuln\_jsHELL_3150.py
# pythonvp\train_val\vuln\_JSHUtil_IORedirect_506.py
# pythonvp\train_val\vuln\_jupyter_notebook_config_2664.py
# pythonvp\train_val\vuln\_jupyter_notebook_config_2666.py
# pythonvp\train_val\vuln\_kameleon_model_fields_charField_1914.py
# pythonvp\train_val\vuln\_kameleon_model_fields_floatField_1916.py
# pythonvp\train_val\vuln\_kameleon_model_fields_integerField_1920.py
# pythonvp\train_val\vuln\_kameleon_model_fields_jsonField_1922.py
# pythonvp\train_val\vuln\_kameleon_model_fields_primaryKeyField_1924.py
# pythonvp\train_val\vuln\_kameleon_model_fields_timestampField_1926.py
# pythonvp\train_val\vuln\_kameleon_model_query_insertQuery_1928.py
# pythonvp\train_val\vuln\_kameleon_model_query_updateQuery_1930.py
# pythonvp\train_val\vuln\_keepassgtk_unlock_database_656.py
# pythonvp\train_val\vuln\_keyInventoryScripts_orderFill_2464.py
# pythonvp\train_val\vuln\_keyInventoryScripts_resupply_2466.py
# pythonvp\train_val\vuln\_kijiji_repost_headless___main___2670.py
# pythonvp\train_val\vuln\_klassifikation_rest_oio_rest_1576.py
# pythonvp\train_val\vuln\_knowyourgov_routes___init___616.py
# pythonvp\train_val\vuln\_kuaidi100_1942.py
# pythonvp\train_val\vuln\_landingpage_2172.py
# pythonvp\train_val\vuln\_libcms_cms_scanner_core_1894.py
# pythonvp\train_val\vuln\_libcms_scanners_cms_scanner_1896.py
# pythonvp\train_val\vuln\_libcms_scanners_cms_scanner_1902.py
# pythonvp\train_val\vuln\_libcms_scanners_wordpress_1898.py
# pythonvp\train_val\vuln\_libcms_scanners_wordpress_1904.py
# pythonvp\train_val\vuln\_libsalesforce_query_construct_2588.py
# pythonvp\train_val\vuln\_libsalesforce_query_interface_2590.py
# pythonvp\train_val\vuln\_libsalesforce_query_spy_2594.py
# pythonvp\train_val\vuln\_lib_ansible_inventory_group_780.py
# pythonvp\train_val\vuln\_lib_ansible_inventory_group_784.py
# pythonvp\train_val\vuln\_lib_ansible_inventory_group_788.py
# pythonvp\train_val\vuln\_lib_ansible_inventory_host_782.py
# pythonvp\train_val\vuln\_lib_ansible_inventory_host_790.py
# pythonvp\train_val\vuln\_lib_ansible_inventory_host_794.py
# pythonvp\train_val\vuln\_lib_email_messages_1548.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_CommandRegistry_1350.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_CommandRegistry_1368.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Install_1334.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Install_1352.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Install_1370.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Mount_1336.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Mount_1354.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Mount_1372.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Preinstall_1338.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Preinstall_1356.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Preinstall_1374.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Start_1340.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Start_1358.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Start_1376.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Umount_1344.py
# pythonvp\train_val\vuln\_lib_Shine_Commands_Umount_1380.py
# pythonvp\train_val\vuln\_lib_Shine_Controller_1346.py
# pythonvp\train_val\vuln\_lib_Shine_Controller_1364.py
# pythonvp\train_val\vuln\_lib_Shine_Controller_1382.py
# pythonvp\train_val\vuln\_lib_Shine_Lustre_Actions_Proxies_FSProxyAction_1348.py
# pythonvp\train_val\vuln\_lib_Shine_Lustre_Actions_Proxies_FSProxyAction_1366.py
# pythonvp\train_val\vuln\_lib_Shine_Lustre_Actions_Proxies_FSProxyAction_1384.py
# pythonvp\train_val\vuln\_lib_wzrpc_wzhandler_1400.py
# pythonvp\train_val\vuln\_lib__sublime_836.py
# pythonvp\train_val\vuln\_ljbq___init___2468.py
# pythonvp\train_val\vuln\_logAnalyzerDb_2170.py
# pythonvp\train_val\vuln\_login_2006.py
# pythonvp\train_val\vuln\_log_tables_242.py
# pythonvp\train_val\vuln\_log_tables_370.py
# pythonvp\train_val\vuln\_lore___init___1448.py
# pythonvp\train_val\vuln\_main_726.py
# pythonvp\train_val\vuln\_mdta_apps_testcases_tasks_1028.py
# pythonvp\train_val\vuln\_mdta_apps_testcases_views_1032.py
# pythonvp\train_val\vuln\_MessageHandler_2028.py
# pythonvp\train_val\vuln\_MiddleKit_Run_MySQLObjectStore_1678.py
# pythonvp\train_val\vuln\_MiddleKit_Run_PostgreSQLObjectStore_1680.py
# pythonvp\train_val\vuln\_MiddleKit_Run_SQLiteObjectStore_1682.py
# pythonvp\train_val\vuln\_models_comment_3136.py
# pythonvp\train_val\vuln\_models_engine_db_storage_2182.py
# pythonvp\train_val\vuln\_models_fit_event_732.py
# pythonvp\train_val\vuln\_models_fit_partner_734.py
# pythonvp\train_val\vuln\_Models_user_2458.py
# pythonvp\train_val\vuln\_model_2116.py
# pythonvp\train_val\vuln\_modoboa_core_views_base_452.py
# pythonvp\train_val\vuln\_modoboa_core_views_base_454.py
# pythonvp\train_val\vuln\_modules_ActiveScan_xss_3126.py
# pythonvp\train_val\vuln\_modules_comment_1708.py
# pythonvp\train_val\vuln\_modules_post_1710.py
# pythonvp\train_val\vuln\_modules_qdb_302.py
# pythonvp\train_val\vuln\_modules_sql_1712.py
# pythonvp\train_val\vuln\_modules_users_1714.py
# pythonvp\train_val\vuln\_modules_xss_3090.py
# pythonvp\train_val\vuln\_modules_xss_3092.py
# pythonvp\train_val\vuln\_modules_xss_3094.py
# pythonvp\train_val\vuln\_modules_xss_3096.py
# pythonvp\train_val\vuln\_mozilla_django_oidc_views_386.py
# pythonvp\train_val\vuln\_mozilla_django_oidc_views_388.py
# pythonvp\train_val\vuln\_munin-node_868.py
# pythonvp\train_val\vuln\_myapp_2118.py
# pythonvp\train_val\vuln\_mysite_app_routes_1892.py
# pythonvp\train_val\vuln\_mysite_core_common_utils_632.py
# pythonvp\train_val\vuln\_mysite_core_tests_utils_634.py
# pythonvp\train_val\vuln\_mysite_ctms_models_638.py
# pythonvp\train_val\vuln\_mysite_ct_management_commands_onboarding_preprocess_636.py
# pythonvp\train_val\vuln\_MySQLDatabase_2478.py
# pythonvp\train_val\vuln\_naclass_2210.py
# pythonvp\train_val\vuln\_natas17_1956.py
# pythonvp\train_val\vuln\_neres_session_3070.py
# pythonvp\train_val\vuln\_nestedfacts_904.py
# pythonvp\train_val\vuln\_network_920.py
# pythonvp\train_val\vuln\_news_data_analysis_1676.py
# pythonvp\train_val\vuln\_news_migrations_0001_initial_1550.py
# pythonvp\train_val\vuln\_news_templatetags_news_1552.py
# pythonvp\train_val\vuln\_notebook_files_handlers_3060.py
# pythonvp\train_val\vuln\_notification_cache_1554.py
# pythonvp\train_val\vuln\_notification_migrations_0002_auto_20160912_1341_1558.py
# pythonvp\train_val\vuln\_occi_http_content_json_2860.py
# pythonvp\train_val\vuln\_odin_traversal_1036.py
# pythonvp\train_val\vuln\_ooiservices_model_adaptor_postgres_2390.py
# pythonvp\train_val\vuln\_ooiservices_model_adaptor_postgres_2396.py
# pythonvp\train_val\vuln\_ooiservices_model_adaptor_sqlite_2392.py
# pythonvp\train_val\vuln\_ooiservices_model_adaptor_sqlite_2398.py
# pythonvp\train_val\vuln\_ooiservices_model_sqlmodel_2394.py
# pythonvp\train_val\vuln\_ooiservices_model_sqlmodel_2400.py
# pythonvp\train_val\vuln\_opennode_oms_endpoint_ssh_completion_cmds_974.py
# pythonvp\train_val\vuln\_opennode_oms_endpoint_ssh_protocol_976.py
# pythonvp\train_val\vuln\_opennode_oms_model_traversal_986.py
# pythonvp\train_val\vuln\_opennode_oms_tests_test_completion_978.py
# pythonvp\train_val\vuln\_openqml-sf_openqml_sf_fock_1318.py
# pythonvp\train_val\vuln\_openqml-sf_openqml_sf_gaussian_1320.py
# pythonvp\train_val\vuln\_openqml_device_1322.py
# pythonvp\train_val\vuln\_orm_cloud_database_adapters_lucene_parser_lucene_parser_2578.py
# pythonvp\train_val\vuln\_orm_cloud_database_adapters_ms_sql_adapter_2580.py
# pythonvp\train_val\vuln\_os-x-config_standard_tweaks_install_mac_tweaks_44.py
# pythonvp\train_val\vuln\_os-x-config_standard_tweaks_tweaks_46.py
# pythonvp\train_val\vuln\_ouchallenge_itemPrices_views_2410.py
# pythonvp\train_val\vuln\_pages_api_submissions_2842.py
# pythonvp\train_val\vuln\_pages_api_surveys_2844.py
# pythonvp\train_val\vuln\_pages_context_processors_2180.py
# pythonvp\train_val\vuln\_Parser_1850.py
# pythonvp\train_val\vuln\_parser_2158.py
# pythonvp\train_val\vuln\_password_2094.py
# pythonvp\train_val\vuln\_password_2096.py
# pythonvp\train_val\vuln\_password_2098.py
# pythonvp\train_val\vuln\_path_traversal_992.py
# pythonvp\train_val\vuln\_pautomate_common_git_86.py
# pythonvp\train_val\vuln\_payloads_inject_1460.py
# pythonvp\train_val\vuln\_payloads_inject_1464.py
# pythonvp\train_val\vuln\_payloads_test_inject_1466.py
# pythonvp\train_val\vuln\_payloads_test_inject_1470.py
# pythonvp\train_val\vuln\_personalise_serverwithflask_2084.py
# pythonvp\train_val\vuln\_pg2nosql_PostgresNoSQLClient_2378.py
# pythonvp\train_val\vuln\_pg2nosql_PostgresNoSQLTable_2380.py
# pythonvp\train_val\vuln\_playlist_playlist_repository_1646.py
# pythonvp\train_val\vuln\_plugins_poll_1988.py
# pythonvp\train_val\vuln\_plugins_vote_1986.py
# pythonvp\train_val\vuln\_plugin_handlers_go_anagonda_context_gometalinter_838.py
# pythonvp\train_val\vuln\_plugin_handlers_go_commands_autocomplete_840.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_close_statement_2212.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_close_statement_2218.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_close_statement_2224.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_close_statement_2236.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_close_statement_2242.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_close_statement_2254.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_open_statement_2220.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_open_statement_2226.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_open_statement_2232.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_open_statement_2238.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_open_statement_2244.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_open_statement_2250.py
# pythonvp\train_val\vuln\_point_of_sale_wizard_pos_open_statement_2256.py
# pythonvp\train_val\vuln\_pontoon_batch_views_3178.py
# pythonvp\train_val\vuln\_postgres_import_assets_1856.py
# pythonvp\train_val\vuln\_postgres_import_assets_1866.py
# pythonvp\train_val\vuln\_postgres_import_assets_1876.py
# pythonvp\train_val\vuln\_postgres_import_holders_1858.py
# pythonvp\train_val\vuln\_postgres_import_holders_1868.py
# pythonvp\train_val\vuln\_postgres_import_holders_1878.py
# pythonvp\train_val\vuln\_postgres_import_markets_1860.py
# pythonvp\train_val\vuln\_postgres_import_markets_1880.py
# pythonvp\train_val\vuln\_postgres_import_realtime_ops_1862.py
# pythonvp\train_val\vuln\_postgres_import_realtime_ops_1882.py
# pythonvp\train_val\vuln\_postgres_import_referrers_1864.py
# pythonvp\train_val\vuln\_postgres_import_referrers_1874.py
# pythonvp\train_val\vuln\_postgres_import_referrers_1884.py
# pythonvp\train_val\vuln\_process_signup_validate_1622.py
# pythonvp\train_val\vuln\_process_signup_validate_1624.py
# pythonvp\train_val\vuln\_product_autoload_models_product_1840.py
# pythonvp\train_val\vuln\_ptvsd___main___1244.py
# pythonvp\train_val\vuln\_public_html_cgi-bin_delete_1760.py
# pythonvp\train_val\vuln\_public_html_cgi-bin_insert_1762.py
# pythonvp\train_val\vuln\_public_html_cgi-bin_update_1766.py
# pythonvp\train_val\vuln\_pykeg_src_pykeg_web_middleware_2994.py
# pythonvp\train_val\vuln\_pykeg_src_pykeg_web_middleware_2998.py
# pythonvp\train_val\vuln\_pyMetricServer_handler_metric_1976.py
# pythonvp\train_val\vuln\_pyMetricServer_system_database_1978.py
# pythonvp\train_val\vuln\_pyshacl_constraints_constraint_component_1010.py
# pythonvp\train_val\vuln\_pyshacl_constraints_value_constraints_1012.py
# pythonvp\train_val\vuln\_pyshacl_constraints___init___1008.py
# pythonvp\train_val\vuln\_pyshacl_validate_1016.py
# pythonvp\train_val\vuln\_PythonCode_Ballance_938.py
# pythonvp\train_val\vuln\_PythonCode_PIDControllerModule_932.py
# pythonvp\train_val\vuln\_PythonCode_PIDControllerModule_942.py
# pythonvp\train_val\vuln\_PythonCode_ServoControllerModule_946.py
# pythonvp\train_val\vuln\_PythonCode_test_950.py
# pythonvp\train_val\vuln\_python_ray_import_thread_456.py
# pythonvp\train_val\vuln\_python_ray_import_thread_470.py
# pythonvp\train_val\vuln\_python_ray_log_monitor_458.py
# pythonvp\train_val\vuln\_python_ray_log_monitor_472.py
# pythonvp\train_val\vuln\_python_ycm_client_base_request_1224.py
# pythonvp\train_val\vuln\_python_ycm_client_base_request_1228.py
# pythonvp\train_val\vuln\_python_ycm_client_base_request_1236.py
# pythonvp\train_val\vuln\_pyweb_pyweb_add_content_886.py
# pythonvp\train_val\vuln\_r2_r2_controllers_meetupscontroller_2966.py
# pythonvp\train_val\vuln\_r2_r2_controllers_meetupscontroller_2972.py
# pythonvp\train_val\vuln\_r2_r2_controllers_meetupscontroller_2978.py
# pythonvp\train_val\vuln\_r2_r2_controllers_meetupscontroller_2986.py
# pythonvp\train_val\vuln\_raut2webstr-import-paths_1160.py
# pythonvp\train_val\vuln\_readthedocs_search_faceted_search_706.py
# pythonvp\train_val\vuln\_readthedocs_search_tests_test_xss_708.py
# pythonvp\train_val\vuln\_realpal_apps_chat_api_600.py
# pythonvp\train_val\vuln\_realpal_apps_chat_serializers_602.py
# pythonvp\train_val\vuln\_realpal_apps_chat_urls_604.py
# pythonvp\train_val\vuln\_realpal_apps_users_tests_test_views_606.py
# pythonvp\train_val\vuln\_reddytt_1250.py
# pythonvp\train_val\vuln\_redirects_django_views_622.py
# pythonvp\train_val\vuln\_redirects_tests_test_integration_624.py
# pythonvp\train_val\vuln\_RedmineProject_Mysql_1838.py
# pythonvp\train_val\vuln\_relational-databases_forum_db_2026.py
# pythonvp\train_val\vuln\_report_2176.py
# pythonvp\train_val\vuln\_rest_1612.py
# pythonvp\train_val\vuln\_roboRescueFinal_1056.py
# pythonvp\train_val\vuln\_Routes_jogging_results_1608.py
# pythonvp\train_val\vuln\_runner_src_resultdir_892.py
# pythonvp\train_val\vuln\_run_1806.py
# pythonvp\train_val\vuln\_saker_fuzzers_code_4.py
# pythonvp\train_val\vuln\_saker_fuzzers_xss_0.py
# pythonvp\train_val\vuln\_salt_modules_disk_14.py
# pythonvp\train_val\vuln\_salt_modules_disk_304.py
# pythonvp\train_val\vuln\_salt_modules_disk_306.py
# pythonvp\train_val\vuln\_salt_modules_disk_308.py
# pythonvp\train_val\vuln\_schoolcms_handler___init___2776.py
# pythonvp\train_val\vuln\_schoolcms_handler___init___2808.py
# pythonvp\train_val\vuln\_schoolcms___init___2774.py
# pythonvp\train_val\vuln\_schoolcms___init___2806.py
# pythonvp\train_val\vuln\_scoring_engine_polling_poll_rdp_92.py
# pythonvp\train_val\vuln\_scraper_scraper_exporters_1842.py
# pythonvp\train_val\vuln\_screendoor_forms_696.py
# pythonvp\train_val\vuln\_screendoor_urls_698.py
# pythonvp\train_val\vuln\_screendoor_views_694.py
# pythonvp\train_val\vuln\_scripts_ansible-role-requirements-editor_888.py
# pythonvp\train_val\vuln\_scripts_createMockDatabase_1688.py
# pythonvp\train_val\vuln\_scripts_get_role_version_890.py
# pythonvp\train_val\vuln\_sdow_database_1690.py
# pythonvp\train_val\vuln\_seagull_routes_app_880.py
# pythonvp\train_val\vuln\_seagull_routes_gallery_882.py
# pythonvp\train_val\vuln\_search_1820.py
# pythonvp\train_val\vuln\_selenium_test_grader_exercises_views_1562.py
# pythonvp\train_val\vuln\_server_2076.py
# pythonvp\train_val\vuln\_server_2086.py
# pythonvp\train_val\vuln\_server_2812.py
# pythonvp\train_val\vuln\_Server_backend_database_2002.py
# pythonvp\train_val\vuln\_Server_chew_snap_server_2350.py
# pythonvp\train_val\vuln\_server_extensions_sqlite_conn_2168.py
# pythonvp\train_val\vuln\_server_functions_badWords_1656.py
# pythonvp\train_val\vuln\_server_mainController_2104.py
# pythonvp\train_val\vuln\_server_models_postgis_message_1428.py
# pythonvp\train_val\vuln\_Server_model_48.py
# pythonvp\train_val\vuln\_Server_model_50.py
# pythonvp\train_val\vuln\_server_orig_2088.py
# pythonvp\train_val\vuln\_server_services_stats_service_1432.py
# pythonvp\train_val\vuln\_server_ygoons_modules_user_follow_suggest_2524.py
# pythonvp\train_val\vuln\_server_ygoons_modules_user_follow_suggest_2526.py
# pythonvp\train_val\vuln\_server_ygoons_modules_user_follow_suggest_2528.py
# pythonvp\train_val\vuln\_server_ygoons_modules_user_follow_suggest_2530.py
# pythonvp\train_val\vuln\_service_pixelated_resources_login_resource_2674.py
# pythonvp\train_val\vuln\_service_pixelated_resources_login_resource_2688.py
# pythonvp\train_val\vuln\_service_pixelated_resources_root_resource_2676.py
# pythonvp\train_val\vuln\_service_pixelated_resources_root_resource_2686.py
# pythonvp\train_val\vuln\_service_pixelated_resources_root_resource_2700.py
# pythonvp\train_val\vuln\_service_test_functional_features_environment_2684.py
# pythonvp\train_val\vuln\_service_test_functional_features_environment_2698.py
# pythonvp\train_val\vuln\_service_test_support_test_helper_2680.py
# pythonvp\train_val\vuln\_service_test_support_test_helper_2694.py
# pythonvp\train_val\vuln\_service_test_unit_resources_test_root_resource_2682.py
# pythonvp\train_val\vuln\_service_test_unit_resources_test_root_resource_2696.py
# pythonvp\train_val\vuln\_setup_1002.py
# pythonvp\train_val\vuln\_setup_1968.py
# pythonvp\train_val\vuln\_setup_2014.py
# pythonvp\train_val\vuln\_setup_2326.py
# pythonvp\train_val\vuln\_setup_2668.py
# pythonvp\train_val\vuln\_setup_2874.py
# pythonvp\train_val\vuln\_setup_2878.py
# pythonvp\train_val\vuln\_setup_3062.py
# pythonvp\train_val\vuln\_setup_3110.py
# pythonvp\train_val\vuln\_shotserver_shotserver04_common_granular_update_2016.py
# pythonvp\train_val\vuln\_shotserver_shotserver04_common_granular_update_2018.py
# pythonvp\train_val\vuln\_shotserver_shotserver04_common_granular_update_2020.py
# pythonvp\train_val\vuln\_shotserver_shotserver04_common_granular_update_2022.py
# pythonvp\train_val\vuln\_shotserver_shotserver04_common_granular_update_2024.py
# pythonvp\train_val\vuln\_Shoveller-Cloud_1064.py
# pythonvp\train_val\vuln\_SimpleBlogServer_3076.py
# pythonvp\train_val\vuln\_simulation_922.py
# pythonvp\train_val\vuln\_site-root__2366.py_ctrl_admin_user_console_2366.py
# pythonvp\train_val\vuln\_slash_core_local_config_952.py
# pythonvp\train_val\vuln\_slash_core_local_config_954.py
# pythonvp\train_val\vuln\_SmallProjects_Define_define_328.py
# pythonvp\train_val\vuln\_socialsystem_core_views_3132.py
# pythonvp\train_val\vuln\_sopel_modules_karma_karma_2368.py
# pythonvp\train_val\vuln\_sopel_modules_karma_karma_2370.py
# pythonvp\train_val\vuln\_soscollector_clusters_kubernetes_54.py
# pythonvp\train_val\vuln\_soscollector_clusters_ovirt_56.py
# pythonvp\train_val\vuln\_spyder_plugins_editor_lsp_manager_864.py
# pythonvp\train_val\vuln\_sqli_checker_2192.py
# pythonvp\train_val\vuln\_sqli_union_lab_1_1950.py
# pythonvp\train_val\vuln\_sqli_union_lab_2_1948.py
# pythonvp\train_val\vuln\_sqli_union_lab_4_1952.py
# pythonvp\train_val\vuln\_SQLTest_2154.py
# pythonvp\train_val\vuln\_squiggle_xss_app_squiggle_patch_main_views_3152.py
# pythonvp\train_val\vuln\_src_allmydata_client_2876.py
# pythonvp\train_val\vuln\_src_allmydata_client_2880.py
# pythonvp\train_val\vuln\_src_allmydata_client_3064.py
# pythonvp\train_val\vuln\_src_api_views_map_2336.py
# pythonvp\train_val\vuln\_src_appengine_handlers_login_3118.py
# pythonvp\train_val\vuln\_SRC_APPLICATION-SOURCE-CODE_server_2030.py
# pythonvp\train_val\vuln\_src_app_2536.py
# pythonvp\train_val\vuln\_src_app_2556.py
# pythonvp\train_val\vuln\_src_client_2108.py
# pythonvp\train_val\vuln\_src_controllers_api_1888.py
# pythonvp\train_val\vuln\_src_dbnav_wrapper_1408.py
# pythonvp\train_val\vuln\_src_dev_arm_Gic_320.py
# pythonvp\train_val\vuln\_src_dev_arm_Gic_322.py
# pythonvp\train_val\vuln\_src_eduid_webapp_authn_acs_actions_646.py
# pythonvp\train_val\vuln\_src_main_python_monitoring_config_generator_MonitoringConfigGenerator_1214.py
# pythonvp\train_val\vuln\_src_main_python_monitoring_config_generator_yaml_tools_readers_1212.py
# pythonvp\train_val\vuln\_src_manage_test_2960.py
# pythonvp\train_val\vuln\_src_merge_db_1966.py
# pythonvp\train_val\vuln\_src_mmw_apps_home_urls_500.py
# pythonvp\train_val\vuln\_src_models_mysql_1890.py
# pythonvp\train_val\vuln\_src_modules_AuthManager_routes_2538.py
# pythonvp\train_val\vuln\_src_modules_AuthManager_routes_2552.py
# pythonvp\train_val\vuln\_src_modules_database_2548.py
# pythonvp\train_val\vuln\_src_modules_database_2562.py
# pythonvp\train_val\vuln\_src_modules_json_schemas_2560.py
# pythonvp\train_val\vuln\_src_modules_json_schemas_2564.py
# pythonvp\train_val\vuln\_src_modules_MessagesManager_api_db_methods_2540.py
# pythonvp\train_val\vuln\_src_modules_MessagesManager_routes_2542.py
# pythonvp\train_val\vuln\_src_modules_ProfileManager_api_db_methods_2544.py
# pythonvp\train_val\vuln\_src_modules_ProfileManager_api_db_methods_2554.py
# pythonvp\train_val\vuln\_src_modules_ProfileManager_api_db_methods_2558.py
# pythonvp\train_val\vuln\_src_modules_ProfileManager_routes_2546.py
# pythonvp\train_val\vuln\_src_pdm_workqueue_Worker_232.py
# pythonvp\train_val\vuln\_src_presetquery_1836.py
# pythonvp\train_val\vuln\_src_pybind_mgr_dashboard_controllers_nfsganesha_692.py
# pythonvp\train_val\vuln\_src_python_pants_backend_graph_info_tasks_cloc_340.py
# pythonvp\train_val\vuln\_src_python_pants_backend_jvm_tasks_jvm_compile_javac_javac_compile_346.py
# pythonvp\train_val\vuln\_src_python_pants_backend_python_register_354.py
# pythonvp\train_val\vuln\_src_python_pants_backend_python_subsystems_python_native_code_358.py
# pythonvp\train_val\vuln\_src_veil_development_browser_browser_2764.py
# pythonvp\train_val\vuln\_src_veil_frontend_web_xsrf_xsrf_2772.py
# pythonvp\train_val\vuln\_src_veil_frontend_web___init___2768.py
# pythonvp\train_val\vuln\_tests3_testutils_898.py
# pythonvp\train_val\vuln\_tests_core_test_load_source_1242.py
# pythonvp\train_val\vuln\_tests_graph_test_860.py
# pythonvp\train_val\vuln\_tests_lib_mock_android_device_224.py
# pythonvp\train_val\vuln\_tests_misc_ShellTest_182.py
# pythonvp\train_val\vuln\_tests_misc_ShellTest_194.py
# pythonvp\train_val\vuln\_tests_net_utils_2824.py
# pythonvp\train_val\vuln\_tests_net_utils_2826.py
# pythonvp\train_val\vuln\_tests_net_utils_2828.py
# pythonvp\train_val\vuln\_tests_net_utils_3074.py
# pythonvp\train_val\vuln\_tests_post_steps_test_dns_80.py
# pythonvp\train_val\vuln\_tests_post_steps_test_logs_84.py
# pythonvp\train_val\vuln\_tests_resources_1038.py
# pythonvp\train_val\vuln\_tests_tests_2550.py
# pythonvp\train_val\vuln\_tests_test_bw2_disclosure_818.py
# pythonvp\train_val\vuln\_tests_test_file_walker_1158.py
# pythonvp\train_val\vuln\_Tests_test_jogging_results_1610.py
# pythonvp\train_val\vuln\_Tests_test_jogging_results_2462.py
# pythonvp\train_val\vuln\_tests_test_traversal_1040.py
# pythonvp\train_val\vuln\_tests_test_views_2300.py
# pythonvp\train_val\vuln\_tests_test_xsrftool_2658.py
# pythonvp\train_val\vuln\_tests_views_view_tests_base_2660.py
# pythonvp\train_val\vuln\_test_test_facts_906.py
# pythonvp\train_val\vuln\_test_undead_996.py
# pythonvp\train_val\vuln\_TexDBook_src_python_core_db_loader_658.py
# pythonvp\train_val\vuln\_timer_1944.py
# pythonvp\train_val\vuln\_timf_api_views_1716.py
# pythonvp\train_val\vuln\_titlebot_2648.py
# pythonvp\train_val\vuln\_todo_cli_74.py
# pythonvp\train_val\vuln\_todo_cli_helpers_76.py
# pythonvp\train_val\vuln\_todo_cli_helpers_78.py
# pythonvp\train_val\vuln\_tools_open_redirect_448.py
# pythonvp\train_val\vuln\_tool_experiment_2302.py
# pythonvp\train_val\vuln\_tornado_route_2856.py
# pythonvp\train_val\vuln\_tournament_1718.py
# pythonvp\train_val\vuln\_tournament_1720.py
# pythonvp\train_val\vuln\_tournament_1984.py
# pythonvp\train_val\vuln\_tournament_2066.py
# pythonvp\train_val\vuln\_tournament_2092.py
# pythonvp\train_val\vuln\_traverse_1152.py
# pythonvp\train_val\vuln\_Trialwebsite_app_app_18.py
# pythonvp\train_val\vuln\_TriblerGUI_event_request_manager_2290.py
# pythonvp\train_val\vuln\_TriblerGUI_widgets_tablecontentmodel_2292.py
# pythonvp\train_val\vuln\_Tribler_community_gigachannel_community_2288.py
# pythonvp\train_val\vuln\_Tribler_Core_Notifier_2280.py
# pythonvp\train_val\vuln\_Tribler_Test_Community_gigachannel_test_community_2282.py
# pythonvp\train_val\vuln\_Tribler_Test_Core_Modules_RestApi_test_events_endpoint_2284.py
# pythonvp\train_val\vuln\_Tribler_Test_Core_Utilities_test_utilities_2286.py
# pythonvp\train_val\vuln\_turq_editor_912.py
# pythonvp\train_val\vuln\_turq_editor_914.py
# pythonvp\train_val\vuln\_twitterBot_2064.py
# pythonvp\train_val\vuln\_unsafe_db_note_2610.py
# pythonvp\train_val\vuln\_unsafe_notes_2612.py
# pythonvp\train_val\vuln\_urtext_1154.py
# pythonvp\train_val\vuln\_userprofile_migrations_0001_initial_1568.py
# pythonvp\train_val\vuln\_userprofile_viewbase_1570.py
# pythonvp\train_val\vuln\_userprofile_views_1572.py
# pythonvp\train_val\vuln\_user_2308.py
# pythonvp\train_val\vuln\_utils_autoban_20.py
# pythonvp\train_val\vuln\_utils_autoban_22.py
# pythonvp\train_val\vuln\_utils_autoban_24.py
# pythonvp\train_val\vuln\_utils_autoban_26.py
# pythonvp\train_val\vuln\_utils_make_eb_config_3162.py
# pythonvp\train_val\vuln\_util_database_1614.py
# pythonvp\train_val\vuln\_vagrant_forum_forumdb_1692.py
# pythonvp\train_val\vuln\_vagrant_forum_forumdb_1704.py
# pythonvp\train_val\vuln\_vagrant_forum_forumdb_2000.py
# pythonvp\train_val\vuln\_vagrant_forum_forumdb_2166.py
# pythonvp\train_val\vuln\_vagrant_news_report_2122.py
# pythonvp\train_val\vuln\_vcstool_commands_command_874.py
# pythonvp\train_val\vuln\_vcstool_executor_878.py
# pythonvp\train_val\vuln\_video_video_repository_1648.py
# pythonvp\train_val\vuln\_visbrain_io_path_858.py
# pythonvp\train_val\vuln\_Volume_1-Supervised_Deep_Learning_Part_1-Artificial_Neural_Networks-ANN_Section_4-Building_an_ANN_ann_1256.py
# pythonvp\train_val\vuln\_weather_app_2352.py
# pythonvp\train_val\vuln\_Web-app_User_1834.py
# pythonvp\train_val\vuln\_webapp_2846.py
# pythonvp\train_val\vuln\_webapp_cve_1694.py
# pythonvp\train_val\vuln\_webapp_errata_1696.py
# pythonvp\train_val\vuln\_website_karakara___init___962.py
# pythonvp\train_val\vuln\_web_app_app_2184.py
# pythonvp\train_val\vuln\_web_server_2054.py
# pythonvp\train_val\vuln\_Week_9_sql_manager_2090.py
# pythonvp\train_val\vuln\_wiki_forms_744.py
# pythonvp\train_val\vuln\_wordpressauthenticator_wordpressauthenticator_1970.py
# pythonvp\train_val\vuln\_WRT_update_ip_2534.py
# pythonvp\train_val\vuln\_xss_3168.py
# pythonvp\train_val\vuln\_xss_3170.py
# pythonvp\train_val\vuln\_xss_3172.py
# pythonvp\train_val\vuln\_zeromail_2320.py
# pythonvp\train_val\vuln\_zhihu_login_3078.py
# pythonvp\train_val\vuln\_ZMSItem_820.py
# pythonvp\train_val\vuln\_ZMSItem_822.py
# pythonvp\test\vuln\_0x0F-python-object_relational_mapping_5-filter_cities_2310.py
# pythonvp\test\vuln\_addons_point_of_sale_wizard_pos_open_statement_1596.py
# pythonvp\test\vuln\_ao_crm_helpdesk_problem_track_reports_qc_problem_track_report_1798.py
# pythonvp\test\vuln\_apis_spaces_2484.py
# pythonvp\test\vuln\_apps_ip_forms_664.py
# pythonvp\test\vuln\_apps_twitter_hunter_views_674.py
# pythonvp\test\vuln\_apps_users_tests_392.py
# pythonvp\test\vuln\_app_answers_api_v1_view_1810.py
# pythonvp\test\vuln\_app_api_common_1114.py
# pythonvp\test\vuln\_app_api_common_1120.py
# pythonvp\test\vuln\_app_auth_api_v1_view_1812.py
# pythonvp\test\vuln\_app_auth_views_406.py
# pythonvp\test\vuln\_beamr_interpreters_config_268.py
# pythonvp\test\vuln\_beamr_lexers_generic_276.py
# pythonvp\test\vuln\_benchmarkSpider_benchmarkSpider_open_redirect_596.py
# pythonvp\test\vuln\_benchmark_cli_1388.py
# pythonvp\test\vuln\_benchmark_cli_1420.py
# pythonvp\test\vuln\_beta_database_2100.py
# pythonvp\test\vuln\_bing_desktop_update_1886.py
# pythonvp\test\vuln\_blueprints_thread_2270.py
# pythonvp\test\vuln\_BT_all_path_1004.py
# pythonvp\test\vuln\_callisto_core_delivery_view_partials_702.py
# pythonvp\test\vuln\_cauldron_runner_python_file_610.py
# pythonvp\test\vuln\_cgi_move_1640.py
# pythonvp\test\vuln\_ckanext_data_qld_commands_716.py
# pythonvp\test\vuln\_ckan_models_package_1444.py
# pythonvp\test\vuln\_classic_2120.py
# pythonvp\test\vuln\_cmstestsuite_web_AWSRequests_3050.py
# pythonvp\test\vuln\_coalib_misc_Shell_168.py
# pythonvp\test\vuln\_coalib_tests_bearlib_abstractions_LintTest_186.py
# pythonvp\test\vuln\_common_src_stack_command_stack_commands_remove_storage_partition___init___40.py
# pythonvp\test\vuln\_content_xss_3164.py
# pythonvp\test\vuln\_controller_api_tests_test_api_middleware_2882.py
# pythonvp\test\vuln\_controller_api_tests_test_auth_2938.py
# pythonvp\test\vuln\_course_migrations_0006_auto_20150721_1152_1496.py
# pythonvp\test\vuln\_crapo_tests_models_crm_stage_1788.py
# pythonvp\test\vuln\_createDB_checkdb_1954.py
# pythonvp\test\vuln\_cuckoo_web_controllers_submission_api_802.py
# pythonvp\test\vuln\_dashboard_admin_510.py
# pythonvp\test\vuln\_dashboard_internet_nl_dashboard_admin_3156.py
# pythonvp\test\vuln\_dashboard_models_data_document_530.py
# pythonvp\test\vuln\_dashboard_models_extracted_chemical_534.py
# pythonvp\test\vuln\_dashboard_models___init___528.py
# pythonvp\test\vuln\_dashboard_tests_loader_568.py
# pythonvp\test\vuln\_dashboard_views_dashboard_524.py
# pythonvp\test\vuln\_dashboard_views_data_document_588.py
# pythonvp\test\vuln\_dashboard_views_data_source_580.py
# pythonvp\test\vuln\_Databases_Contacts2_2456.py
# pythonvp\test\vuln\_database_1854.py
# pythonvp\test\vuln\_database_2382.py
# pythonvp\test\vuln\_dbhelper_1802.py
# pythonvp\test\vuln\_db_tools_2470.py
# pythonvp\test\vuln\_DefinitelyNotTwitter_admin_2516.py
# pythonvp\test\vuln\_django_views_static_380.py
# pythonvp\test\vuln\_django_views_static_684.py
# pythonvp\test\vuln\_django_views_static_686.py
# pythonvp\test\vuln\_draw_1098.py
# pythonvp\test\vuln\_emp_utils_1000.py
# pythonvp\test\vuln\_erpnext_ebay_ebay_active_listings_1804.py
# pythonvp\test\vuln\_erpnext_hr_report_employee_leave_balance_employee_leave_balance_2506.py
# pythonvp\test\vuln\_examples_sql_statements_1476.py
# pythonvp\test\vuln\_external_services_migrations_0005_auto_20160829_1344_1544.py
# pythonvp\test\vuln\_extraschool_presta_stat_2618.py
# pythonvp\test\vuln\_gitmate_settings_498.py
# pythonvp\test\vuln\_httpverbs_1054.py
# pythonvp\test\vuln\_hubblestack_extmods_grains_custom_grains_pillar_94.py
# pythonvp\test\vuln\_integration-tests_test_extensions_678.py
# pythonvp\test\vuln\_invenio_modules_oauthclient_contrib_orcid_1184.py
# pythonvp\test\vuln\_invenio_modules_oauthclient_views_client_1190.py
# pythonvp\test\vuln\_invenio_records_admin_3138.py
# pythonvp\test\vuln\_isort_hooks_374.py
# pythonvp\test\vuln\_jupyterlab_sql_executor_2568.py
# pythonvp\test\vuln\_kameleon_model_fields_booleanField_1912.py
# pythonvp\test\vuln\_kameleon_model_fields_foreignKeyField_1918.py
# pythonvp\test\vuln\_lastReplied_2062.py
# pythonvp\test\vuln\_libcms_cms_scanner_core_1900.py
# pythonvp\test\vuln\_libsalesforce_query_manager_2592.py
# pythonvp\test\vuln\_libsalesforce_query___init___2586.py
# pythonvp\test\vuln\_lib_ansible_inventory_group_792.py
# pythonvp\test\vuln\_lib_ansible_inventory_host_786.py
# pythonvp\test\vuln\_lib_Shine_Commands_CommandRegistry_1332.py
# pythonvp\test\vuln\_lib_Shine_Commands_Umount_1362.py
# pythonvp\test\vuln\_lmfdb_zeros_first_firstzeros_1794.py
# pythonvp\test\vuln\_log_tables_254.py
# pythonvp\test\vuln\_metrics_Network_network_metrics_2328.py
# pythonvp\test\vuln\_mobly_controllers_android_device_lib_adb_220.py
# pythonvp\test\vuln\_Models_user_1606.py
# pythonvp\test\vuln\_mysite_core_common_onboarding_630.py
# pythonvp\test\vuln\_notification_migrations_0001_initial_1556.py
# pythonvp\test\vuln\_notification_migrations_0003_auto_20160914_1051_1560.py
# pythonvp\test\vuln\_nrf24_nrf24_1674.py
# pythonvp\test\vuln\_opennode_oms_endpoint_httprest_base_980.py
# pythonvp\test\vuln\_openstack_dashboard_dashboards_identity_mappings_tables_3056.py
# pythonvp\test\vuln\_orm_cloud_database_adapters_database_adapter_2576.py
# pythonvp\test\vuln\_payloads_sqli_1462.py
# pythonvp\test\vuln\_payloads_sqli_1468.py
# pythonvp\test\vuln\_photogpsbot_db_connector_1770.py
# pythonvp\test\vuln\_plugins_database_2152.py
# pythonvp\test\vuln\_plugins_networks_1386.py
# pythonvp\test\vuln\_plugins_vote_1982.py
# pythonvp\test\vuln\_point_of_sale_wizard_pos_close_statement_2230.py
# pythonvp\test\vuln\_point_of_sale_wizard_pos_close_statement_2248.py
# pythonvp\test\vuln\_point_of_sale_wizard_pos_open_statement_2214.py
# pythonvp\test\vuln\_postgres_import_markets_1870.py
# pythonvp\test\vuln\_postgres_import_realtime_ops_1872.py
# pythonvp\test\vuln\_posts_views_736.py
# pythonvp\test\vuln\_process_data_2038.py
# pythonvp\test\vuln\_public_html_cgi-bin_select_1764.py
# pythonvp\test\vuln\_pyshortcuts_job_JobTableActions_2522.py
# pythonvp\test\vuln\_PythonCode_Ballance_928.py
# pythonvp\test\vuln\_PythonCode_ServoControllerModule_936.py
# pythonvp\test\vuln\_PythonCode_TensorflowProcessingModule_948.py
# pythonvp\test\vuln\_python_ycm_client_base_request_1220.py
# pythonvp\test\vuln\_python_ycm_client_base_request_1232.py
# pythonvp\test\vuln\_readthedocs_search_tests_test_xss_710.py
# pythonvp\test\vuln\_redirects_urls_626.py
# pythonvp\test\vuln\_reframe_frontend_dependency_854.py
# pythonvp\test\vuln\_resources_users_2606.py
# pythonvp\test\vuln\_reviewus_db_2050.py
# pythonvp\test\vuln\_Routes_jogging_results_2460.py
# pythonvp\test\vuln\_rsynco_libs_ssh_916.py
# pythonvp\test\vuln\_saker_fuzzers_xss_2.py
# pythonvp\test\vuln\_salt_modules_disk_16.py
# pythonvp\test\vuln\_Scripts_Controller_2134.py
# pythonvp\test\vuln\_server_ygoons_modules_user_follow_suggest_2532.py
# pythonvp\test\vuln\_service_pixelated_resources_root_resource_2690.py
# pythonvp\test\vuln\_shibboleth_login_tests_1564.py
# pythonvp\test\vuln\_sql_demo_2004.py
# pythonvp\test\vuln\_src_auth_2106.py
# pythonvp\test\vuln\_src_cli_tests_PhobosDSSTest_2572.py
# pythonvp\test\vuln\_src_dev_arm_Gic_324.py
# pythonvp\test\vuln\_src_modules_json_validator_2566.py
# pythonvp\test\vuln\_src_python_pants_backend_jvm_subsystems_scala_platform_342.py
# pythonvp\test\vuln\_src_python_pants_backend_jvm_subsystems_zinc_344.py
# pythonvp\test\vuln\_src_python_pants_backend_python_rules_python_test_runner_356.py
# pythonvp\test\vuln\_src_Shortener_Project_urls_740.py
# pythonvp\test\vuln\_src_user_2142.py
# pythonvp\test\vuln\_src_util_68.py
# pythonvp\test\vuln\_src_veil_frontend_web_website_launcher_2766.py
# pythonvp\test\vuln\_src_veil_frontend_web_xsrf___init___2770.py
# pythonvp\test\vuln\_syscall_number_syscall_number_330.py
# pythonvp\test\vuln\_tests_misc_ShellTest_170.py
# pythonvp\test\vuln\_tests_post_steps_test_liveness_82.py
# pythonvp\test\vuln\_tests_test_admin_3140.py
# pythonvp\test\vuln\_threshold_migrations_0001_initial_1566.py
# pythonvp\test\vuln\_undead_998.py
# pythonvp\test\vuln\_utils_user_funcs_1732.py
# pythonvp\test\vuln\_vcstool_crawler_876.py
# pythonvp\test\vuln\_wiki_crawler_1108.py
# pythonvp\test\vuln\___manifest___728.py

# %%
for i in range(0, len(all_data)):
    if all_data[i][1] == '0':
        print(all_data[i][0])
# Out:
# pythonvp\train_val\clean\0001_initial.py
# pythonvp\train_val\clean\0001_not_initial.py
# pythonvp\train_val\clean\0001_setup_extensions.py
# pythonvp\train_val\clean\0002_a2.py
# pythonvp\train_val\clean\0002_add-webhook.py
# pythonvp\train_val\clean\0002_add_book.py
# pythonvp\train_val\clean\0002_add_importedfile_model.py
# pythonvp\train_val\clean\0002_alter_domain_unique.py
# pythonvp\train_val\clean\0002_alter_id.py
# pythonvp\train_val\clean\0002_auto_20170614_1741.py
# pythonvp\train_val\clean\0002_build_command_initial.py
# pythonvp\train_val\clean\0002_c2.py
# pythonvp\train_val\clean\0002_delete_post.py
# pythonvp\train_val\clean\0002_increase_max_length.py
# pythonvp\train_val\clean\0002_initial.py
# pythonvp\train_val\clean\0002_logentry_remove_auto_add.py
# pythonvp\train_val\clean\0002_remove_content_type_name.py
# pythonvp\train_val\clean\0002_remove_ipaddressfield_ip.py
# pythonvp\train_val\clean\0002_rename_last_4_digits.py
# pythonvp\train_val\clean\0002_settings_sync_assignees.py
# pythonvp\train_val\clean\0003_a3.py
# pythonvp\train_val\clean\0003_add-cold-storage.py
# pythonvp\train_val\clean\0003_add_banned_status.py
# pythonvp\train_val\clean\0003_add_default_redirect_http_status_to_302.py
# pythonvp\train_val\clean\0003_alter_user_email_max_length.py
# pythonvp\train_val\clean\0003_auto_20170608_1631.py
# pythonvp\train_val\clean\0003_auto_20170615_1300.py
# pythonvp\train_val\clean\0003_auto_20170622_1148.py
# pythonvp\train_val\clean\0003_auto_20170622_1158.py
# pythonvp\train_val\clean\0003_auto_20171205_2009.py
# pythonvp\train_val\clean\0003_b3.py
# pythonvp\train_val\clean\0003_migrate_total_results_null_values.py
# pythonvp\train_val\clean\0003_post.py
# pythonvp\train_val\clean\0003_project_cdn_enabled.py
# pythonvp\train_val\clean\0003_team_auto_join_email_users.py
# pythonvp\train_val\clean\0003_third.py
# pythonvp\train_val\clean\0003_update_ordering.py
# pythonvp\train_val\clean\0004_a4.py
# pythonvp\train_val\clean\0004_add-apiversion-proxy-model.py
# pythonvp\train_val\clean\0004_add_vat_id.py
# pythonvp\train_val\clean\0004_auto_20170214_1029.py
# pythonvp\train_val\clean\0004_auto_20170622_1158.py
# pythonvp\train_val\clean\0004_auto_20171212_1236.py
# pythonvp\train_val\clean\0004_change_ip_field_type.py
# pythonvp\train_val\clean\0004_denormalize-from-url.py
# pythonvp\train_val\clean\0004_drop_github_and_bitbucket_models.py
# pythonvp\train_val\clean\0004_empty_spots.py
# pythonvp\train_val\clean\0004_processingnode_max_images.py
# pythonvp\train_val\clean\0005_alter_user_last_login_null.py
# pythonvp\train_val\clean\0005_auto_20170222_1618.py
# pythonvp\train_val\clean\0005_auto_20170716_1155.py
# pythonvp\train_val\clean\0005_auto_20180128_1250.py
# pythonvp\train_val\clean\0005_change_default_integration_secret.py
# pythonvp\train_val\clean\0005_historicalorganization_historicalteam.py
# pythonvp\train_val\clean\0005_htmlfile-sphinx-domain-integration.py
# pythonvp\train_val\clean\0005_migrate-old-passwords.py
# pythonvp\train_val\clean\0005_migrate_ip_field_values.py
# pythonvp\train_val\clean\0005_remove-version-alias.py
# pythonvp\train_val\clean\0005_remove_settings_blacklisted_labels.py
# pythonvp\train_val\clean\0005_settings_size_scheme.py
# pythonvp\train_val\clean\0006_add_assets_cleaned.py
# pythonvp\train_val\clean\0006_auto_20171205_2009.py
# pythonvp\train_val\clean\0006_remove_plugin_active.py
# pythonvp\train_val\clean\0006_remove_userprofile_allow_email.py
# pythonvp\train_val\clean\0006_require_contenttypes_0002.py
# pythonvp\train_val\clean\0006_set-default-value-provider-data.py
# pythonvp\train_val\clean\0006_settings_label_texts_as_keywords.py
# pythonvp\train_val\clean\0007_add-automation-rules.py
# pythonvp\train_val\clean\0007_add_extra_history_fields.py
# pythonvp\train_val\clean\0007_auto_20171205_2009.py
# pythonvp\train_val\clean\0007_update-provider-data.py
# pythonvp\train_val\clean\0008_alter_user_username_max_length.py
# pythonvp\train_val\clean\0008_preset.py
# pythonvp\train_val\clean\0009_add_domain_field.py
# pythonvp\train_val\clean\0009_auto_20170721_1332.py
# pythonvp\train_val\clean\0009_auto_20180221_0403.py
# pythonvp\train_val\clean\0009_historicaluserprofile.py
# pythonvp\train_val\clean\0009_migrate_headers_data.py
# pythonvp\train_val\clean\0010_add-description-field-to-automation-rule.py
# pythonvp\train_val\clean\0010_auto_20170725_1324.py
# pythonvp\train_val\clean\0010_auto_20170923_1158.py
# pythonvp\train_val\clean\0010_auto_20180221_0403.py
# pythonvp\train_val\clean\0010_index_full_name.py
# pythonvp\train_val\clean\0010_remove_old_jsonfields.py
# pythonvp\train_val\clean\0011_add_default_branch.py
# pythonvp\train_val\clean\0011_alter_historicaluser_first_name.py
# pythonvp\train_val\clean\0011_auto_20171109_1237.py
# pythonvp\train_val\clean\0011_delete-url.py
# pythonvp\train_val\clean\0011_repository_org.py
# pythonvp\train_val\clean\0011_version-media-availability.py
# pythonvp\train_val\clean\0012_add-predefined-match-arg-field.py
# pythonvp\train_val\clean\0012_create_new_table_for_remote_organization_normalization.py
# pythonvp\train_val\clean\0012_proper-name-for-install-project.py
# pythonvp\train_val\clean\0012_public_task_uuids.py
# pythonvp\train_val\clean\0012_repository_identifier.py
# pythonvp\train_val\clean\0013_create_new_table_for_remote_repository_normalization.py
# pythonvp\train_val\clean\0013_public_task_uuids.py
# pythonvp\train_val\clean\0013_version_documentation_type.py
# pythonvp\train_val\clean\0014_add-state-tracking.py
# pythonvp\train_val\clean\0014_public_task_uuids.py
# pythonvp\train_val\clean\0014_remove_remoterepository_project.py
# pythonvp\train_val\clean\0015_public_task_uuids.py
# pythonvp\train_val\clean\0016_build-queue-name.py
# pythonvp\train_val\clean\0016_public_task_uuids.py
# pythonvp\train_val\clean\0017_builds_deterministic_order_index.py
# pythonvp\train_val\clean\0017_installation_admins.py
# pythonvp\train_val\clean\0018_auto_20180311_1028.py
# pythonvp\train_val\clean\0018_fix-translation-model.py
# pythonvp\train_val\clean\0019_add-features.py
# pythonvp\train_val\clean\0019_remove_task_processing_lock.py
# pythonvp\train_val\clean\0020_auto_20180130_0748.py
# pythonvp\train_val\clean\0020_plugindatum.py
# pythonvp\train_val\clean\0021_auto_20180726_1746.py
# pythonvp\train_val\clean\0021_make_hidden_field_not_null.py
# pythonvp\train_val\clean\0022_add-alias-slug.py
# pythonvp\train_val\clean\0022_auto_20181205_1644.py
# pythonvp\train_val\clean\0022_convert_plugins_field_to_array_of_charfields.py
# pythonvp\train_val\clean\0022_migrate_protected_versions.py
# pythonvp\train_val\clean\0023_add_status_code.py
# pythonvp\train_val\clean\0023_destroy_repository_plugins_table_and_rename.py
# pythonvp\train_val\clean\0023_task_running_progress.py
# pythonvp\train_val\clean\0024_delete_plugin_model.py
# pythonvp\train_val\clean\0026_add_hide_version_automation_rule.py
# pythonvp\train_val\clean\0027_remove_json_with_html_feature.py
# pythonvp\train_val\clean\0028_add_delete_version_action.py
# pythonvp\train_val\clean\0028_remove_comments_and_update_old_migration.py
# pythonvp\train_val\clean\0030_add_automation_rule_matches.py
# pythonvp\train_val\clean\0030_change-max-length-project-slug.py
# pythonvp\train_val\clean\0031_add_modified_date_importedfile.py
# pythonvp\train_val\clean\0031_add_version_fields_to_build.py
# pythonvp\train_val\clean\0032_increase_webhook_maxsize.py
# pythonvp\train_val\clean\0033_dont_cascade_delete_builds.py
# pythonvp\train_val\clean\0036_remove-auto-doctype.py
# pythonvp\train_val\clean\0037_add_htmlfile.py
# pythonvp\train_val\clean\0037_alter_build_cold_storage.py
# pythonvp\train_val\clean\0038_add_new_jsonfields.py
# pythonvp\train_val\clean\0039_migrate_config_data.py
# pythonvp\train_val\clean\0039_update-doctype-helptext.py
# pythonvp\train_val\clean\0041_index-repo-field.py
# pythonvp\train_val\clean\0042_version_state.py
# pythonvp\train_val\clean\0045_project_max_concurrent_builds.py
# pythonvp\train_val\clean\0046_domain_hsts_fields.py
# pythonvp\train_val\clean\0048_remove_version_privacy_field.py
# pythonvp\train_val\clean\0049_add_external_build_enabled.py
# pythonvp\train_val\clean\0052_migrate_null_external_builds_field.py
# pythonvp\train_val\clean\0053_make_external_builds_field_not_null.py
# pythonvp\train_val\clean\0054_urlconf_blank.py
# pythonvp\train_val\clean\0055_change_help_text_description.py
# pythonvp\train_val\clean\0056_add_disable_analytics.py
# pythonvp\train_val\clean\0057_add_page_rank.py
# pythonvp\train_val\clean\0058_update_timestamp_fields.py
# pythonvp\train_val\clean\0060_make_rank_not_null.py
# pythonvp\train_val\clean\0062_add_ssl_status.py
# pythonvp\train_val\clean\0064_add_feature_future_default_true.py
# pythonvp\train_val\clean\0065_add_feature_future_default_true.py
# pythonvp\train_val\clean\0066_make_imported_file_slug_nullable.py
# pythonvp\train_val\clean\0068_remove_slug_field.py
# pythonvp\train_val\clean\0070_make_md5_field_nullable.py
# pythonvp\train_val\clean\0072_remove_md5_field.py
# pythonvp\train_val\clean\0073_remove_protected_privacy_level.py
# pythonvp\train_val\clean\0076_project_remote_repository.py
# pythonvp\train_val\clean\0078_add_external_builds_privacy_level_field.py
# pythonvp\train_val\clean\0079_httpheader.py
# pythonvp\train_val\clean\0083_init_generic_webhooks.py
# pythonvp\train_val\clean\0085_subscribe_old_webhooks_to_events.py
# pythonvp\train_val\clean\0087_use_booleanfield_null.py
# pythonvp\train_val\clean\1_auto.py
# pythonvp\train_val\clean\1_isolate.py
# pythonvp\train_val\clean\1_squashed_2.py
# pythonvp\train_val\clean\2_auto.py
# pythonvp\train_val\clean\3_squashed_5.py
# pythonvp\train_val\clean\4_auto.py
# pythonvp\train_val\clean\5_auto.py
# pythonvp\train_val\clean\a10.py
# pythonvp\train_val\clean\AbstractMemory.py
# pythonvp\train_val\clean\account_analytic_balance_report.py
# pythonvp\train_val\clean\account_analytic_cost_ledger_for_journal_report.py
# pythonvp\train_val\clean\account_analytic_default.py
# pythonvp\train_val\clean\account_analytic_entries_report.py
# pythonvp\train_val\clean\account_analytic_inverted_balance_report.py
# pythonvp\train_val\clean\account_analytic_journal_report.py
# pythonvp\train_val\clean\account_asset_report.py
# pythonvp\train_val\clean\account_budget_analytic.py
# pythonvp\train_val\clean\account_budget_crossovered_summary_report.py
# pythonvp\train_val\clean\account_central_journal.py
# pythonvp\train_val\clean\account_change_currency.py
# pythonvp\train_val\clean\account_chart.py
# pythonvp\train_val\clean\account_crossovered_analytic.py
# pythonvp\train_val\clean\account_followup_report.py
# pythonvp\train_val\clean\account_journal.py
# pythonvp\train_val\clean\account_journal_select.py
# pythonvp\train_val\clean\account_move_line_reconcile_select.py
# pythonvp\train_val\clean\account_move_line_select.py
# pythonvp\train_val\clean\account_open_closed_fiscalyear.py
# pythonvp\train_val\clean\account_payment_order.py
# pythonvp\train_val\clean\account_period_close.py
# pythonvp\train_val\clean\account_print_invoice.py
# pythonvp\train_val\clean\account_print_overdue.py
# pythonvp\train_val\clean\account_reconcile_partner_process.py
# pythonvp\train_val\clean\account_report_central_journal.py
# pythonvp\train_val\clean\account_report_common_journal.py
# pythonvp\train_val\clean\account_report_common_partner.py
# pythonvp\train_val\clean\account_report_company.py
# pythonvp\train_val\clean\account_report_general_journal.py
# pythonvp\train_val\clean\account_report_general_ledger.py
# pythonvp\train_val\clean\account_report_partner_balance.py
# pythonvp\train_val\clean\account_report_partner_ledger.py
# pythonvp\train_val\clean\account_statement_from_invoice.py
# pythonvp\train_val\clean\account_subscription_generate.py
# pythonvp\train_val\clean\account_treasury_report.py
# pythonvp\train_val\clean\account_unreconcile.py
# pythonvp\train_val\clean\account_use_model.py
# pythonvp\train_val\clean\account_validate_account_move.py
# pythonvp\train_val\clean\account_voucher.py
# pythonvp\train_val\clean\accumulation.py
# pythonvp\train_val\clean\aci_epg_monitoring_policy.py
# pythonvp\train_val\clean\aci_interface_policy_fc.py
# pythonvp\train_val\clean\aci_interface_policy_leaf_profile.py
# pythonvp\train_val\clean\aci_interface_policy_mcp.py
# pythonvp\train_val\clean\ACPI.py
# pythonvp\train_val\clean\acquirer.py
# pythonvp\train_val\clean\acquisition_task_pb2.py
# pythonvp\train_val\clean\actionable.py
# pythonvp\train_val\clean\ActionDeclAST.py
# pythonvp\train_val\clean\actions.py
# pythonvp\train_val\clean\action_write_locks.py
# pythonvp\train_val\clean\acute_eval_blueprint.py
# pythonvp\train_val\clean\acute_eval_builder.py
# pythonvp\train_val\clean\adapter.py
# pythonvp\train_val\clean\adapters.py
# pythonvp\train_val\clean\addition.py
# pythonvp\train_val\clean\addresses.py
# pythonvp\train_val\clean\add_host.py
# pythonvp\train_val\clean\adhoc.py
# pythonvp\train_val\clean\admin.py
# pythonvp\train_val\clean\admin_static.py
# pythonvp\train_val\clean\aggregates.py
# pythonvp\train_val\clean\aiohttp_client.py
# pythonvp\train_val\clean\airbrake_deployment.py
# pythonvp\train_val\clean\aireos.py
# pythonvp\train_val\clean\aladdin_connect.py
# pythonvp\train_val\clean\alarmdotcom.py
# pythonvp\train_val\clean\alice.py
# pythonvp\train_val\clean\all_closed_cashbox_of_the_day.py
# pythonvp\train_val\clean\all_input.py
# pythonvp\train_val\clean\AlphaISA.py
# pythonvp\train_val\clean\AlphaTLB.py
# pythonvp\train_val\clean\alpha_generic.py
# pythonvp\train_val\clean\alternate_urls.py
# pythonvp\train_val\clean\AMD_Base_Constructor.py
# pythonvp\train_val\clean\analytic_journal.py
# pythonvp\train_val\clean\analytic_user_function.py
# pythonvp\train_val\clean\andp.py
# pythonvp\train_val\clean\annotated_tag_function.py
# pythonvp\train_val\clean\another_good_module.py
# pythonvp\train_val\clean\anquanbao.py
# pythonvp\train_val\clean\ansi.py
# pythonvp\train_val\clean\ansible_doc.py
# pythonvp\train_val\clean\ansible_tower.py
# pythonvp\train_val\clean\ansible_util.py
# pythonvp\train_val\clean\any_test_pb2.py
# pythonvp\train_val\clean\aos.py
# pythonvp\train_val\clean\api.py
# pythonvp\train_val\clean\appendnullbyte.py
# pythonvp\train_val\clean\appengine_memcache.py
# pythonvp\train_val\clean\apps.py
# pythonvp\train_val\clean\app_engine.py
# pythonvp\train_val\clean\apt_rpm.py
# pythonvp\train_val\clean\arest.py
# pythonvp\train_val\clean\args.py
# pythonvp\train_val\clean\arm-ccregs.py
# pythonvp\train_val\clean\arm-gicv2-banked-regs.py
# pythonvp\train_val\clean\arm-hdlcd-upgrade.py
# pythonvp\train_val\clean\arm-miscreg-teehbr.py
# pythonvp\train_val\clean\arm-sysreg-mapping-ns.py
# pythonvp\train_val\clean\ArmSemihosting.py
# pythonvp\train_val\clean\ArmSystem.py
# pythonvp\train_val\clean\ArmTLB.py
# pythonvp\train_val\clean\ArmV8KvmCPU.py
# pythonvp\train_val\clean\arm_generic.py
# pythonvp\train_val\clean\article.py
# pythonvp\train_val\clean\article_actions.py
# pythonvp\train_val\clean\aruba.py
# pythonvp\train_val\clean\aruba_module.py
# pythonvp\train_val\clean\assert.py
# pythonvp\train_val\clean\assertion_report.py
# pythonvp\train_val\clean\asuswrt.py
# pythonvp\train_val\clean\AsyncFirstExamples.py
# pythonvp\train_val\clean\asyncqlio.py
# pythonvp\train_val\clean\async_status.py
# pythonvp\train_val\clean\async_test.py
# pythonvp\train_val\clean\at.py
# pythonvp\train_val\clean\AtomicSimpleCPU.py
# pythonvp\train_val\clean\atomic_host.py
# pythonvp\train_val\clean\atomic_image.py
# pythonvp\train_val\clean\attendance_errors.py
# pythonvp\train_val\clean\attribute.py
# pythonvp\train_val\clean\audittrail_view_log.py
# pythonvp\train_val\clean\aurora.py
# pythonvp\train_val\clean\auth.py
# pythonvp\train_val\clean\authenticators.py
# pythonvp\train_val\clean\authorizer.py
# pythonvp\train_val\clean\auth_oauth.py
# pythonvp\train_val\clean\auto.py
# pythonvp\train_val\clean\automated_expanded_attention_1024.py
# pythonvp\train_val\clean\automation.py
# pythonvp\train_val\clean\auto_stub.py
# pythonvp\train_val\clean\available_holidays.py
# pythonvp\train_val\clean\avi_actiongroupconfig.py
# pythonvp\train_val\clean\avi_alertemailconfig.py
# pythonvp\train_val\clean\avi_alertscriptconfig.py
# pythonvp\train_val\clean\avi_alertsyslogconfig.py
# pythonvp\train_val\clean\avi_api_version.py
# pythonvp\train_val\clean\avi_autoscalelaunchconfig.py
# pythonvp\train_val\clean\avi_certificatemanagementprofile.py
# pythonvp\train_val\clean\avi_clusterclouddetails.py
# pythonvp\train_val\clean\avi_gslbhealthmonitor.py
# pythonvp\train_val\clean\avi_ipaddrgroup.py
# pythonvp\train_val\clean\avi_l4policyset.py
# pythonvp\train_val\clean\avi_network.py
# pythonvp\train_val\clean\avi_networkprofile.py
# pythonvp\train_val\clean\avi_networksecuritypolicy.py
# pythonvp\train_val\clean\avi_poolgroup.py
# pythonvp\train_val\clean\avi_seproperties.py
# pythonvp\train_val\clean\avi_stringgroup.py
# pythonvp\train_val\clean\avi_useraccount.py
# pythonvp\train_val\clean\avi_vsdatascriptset.py
# pythonvp\train_val\clean\avi_vsvip.py
# pythonvp\train_val\clean\avi_wafpolicy.py
# pythonvp\train_val\clean\avi_wafprofile.py
# pythonvp\train_val\clean\avi_webhook.py
# pythonvp\train_val\clean\aws.py
# pythonvp\train_val\clean\aws_account_attribute.py
# pythonvp\train_val\clean\aws_caller_facts.py
# pythonvp\train_val\clean\aws_credentials.py
# pythonvp\train_val\clean\aws_lambda.py
# pythonvp\train_val\clean\aws_region_facts.py
# pythonvp\train_val\clean\aws_s3_bucket_facts.py
# pythonvp\train_val\clean\azure-requirements.py
# pythonvp\train_val\clean\azure_rm_availabilityset_facts.py
# pythonvp\train_val\clean\azure_rm_dnsrecordset_facts.py
# pythonvp\train_val\clean\azure_rm_dnszone.py
# pythonvp\train_val\clean\azure_rm_managed_disk_facts.py
# pythonvp\train_val\clean\azure_rm_resourcegroup_facts.py
# pythonvp\train_val\clean\azure_rm_sqlserver_facts.py
# pythonvp\train_val\clean\azure_rm_storageaccount_facts.py
# pythonvp\train_val\clean\azure_rm_virtualmachineimage_facts.py
# pythonvp\train_val\clean\azure_rm_virtualmachine_scaleset_facts.py
# pythonvp\train_val\clean\b27228471604_index_fk_columns__registrering_id.py
# pythonvp\train_val\clean\backend_alias.py
# pythonvp\train_val\clean\backup.py
# pythonvp\train_val\clean\bacon.py
# pythonvp\train_val\clean\BadDevice.py
# pythonvp\train_val\clean\badge_name_importer_html.py
# pythonvp\train_val\clean\badge_name_importer_minami_api.py
# pythonvp\train_val\clean\bad_tag.py
# pythonvp\train_val\clean\banner.py
# pythonvp\train_val\clean\barracuda.py
# pythonvp\train_val\clean\bart_base.py
# pythonvp\train_val\clean\bart_fid_rag_dpr_poly.py
# pythonvp\train_val\clean\bart_rag_dpr_poly.py
# pythonvp\train_val\clean\bart_rag_turn_do.py
# pythonvp\train_val\clean\base.py
# pythonvp\train_val\clean\basehttp.py
# pythonvp\train_val\clean\BaseKvmCPU.py
# pythonvp\train_val\clean\BaseSimpleCPU.py
# pythonvp\train_val\clean\BaseTopology.py
# pythonvp\train_val\clean\BaseTrafficGen.py
# pythonvp\train_val\clean\base_export_language.py
# pythonvp\train_val\clean\base_iban.py
# pythonvp\train_val\clean\base_import_language.py
# pythonvp\train_val\clean\base_module_configuration.py
# pythonvp\train_val\clean\base_module_import.py
# pythonvp\train_val\clean\base_report_designer.py
# pythonvp\train_val\clean\base_report_designer_modify.py
# pythonvp\train_val\clean\base_session.py
# pythonvp\train_val\clean\base_update_translations.py
# pythonvp\train_val\clean\base_user.py
# pythonvp\train_val\clean\basicauthhandler.py
# pythonvp\train_val\clean\basiclex.py
# pythonvp\train_val\clean\BasicLink.py
# pythonvp\train_val\clean\BasicModuleUsage.py
# pythonvp\train_val\clean\BasicRouter.py
# pythonvp\train_val\clean\bbox.py
# pythonvp\train_val\clean\bcd_adjust.py
# pythonvp\train_val\clean\beginning_with_slash.py
# pythonvp\train_val\clean\bert_classifier.py
# pythonvp\train_val\clean\bh1750.py
# pythonvp\train_val\clean\bigfile.py
# pythonvp\train_val\clean\bigiq.py
# pythonvp\train_val\clean\bigpanda.py
# pythonvp\train_val\clean\bigswitch.py
# pythonvp\train_val\clean\bilan_report.py
# pythonvp\train_val\clean\biranker_dialogue.py
# pythonvp\train_val\clean\bitcoin.py
# pythonvp\train_val\clean\blender_1Bdistill.py
# pythonvp\train_val\clean\blender_90M.py
# pythonvp\train_val\clean\blender_9B.py
# pythonvp\train_val\clean\blinksticklight.py
# pythonvp\train_val\clean\bloomsky.py
# pythonvp\train_val\clean\bluecoat.py
# pythonvp\train_val\clean\bluetooth_tracker.py
# pythonvp\train_val\clean\board.py
# pythonvp\train_val\clean\bootstrap_extras.py
# pythonvp\train_val\clean\bootstrap_test.py
# pythonvp\train_val\clean\bounds.py
# pythonvp\train_val\clean\breadcrumbs.py
# pythonvp\train_val\clean\bridge.py
# pythonvp\train_val\clean\broadlink.py
# pythonvp\train_val\clean\broken_tag.py
# pythonvp\train_val\clean\broken_tags.py
# pythonvp\train_val\clean\browser.py
# pythonvp\train_val\clean\brunt.py
# pythonvp\train_val\clean\bt_smarthub.py
# pythonvp\train_val\clean\buildah.py
# pythonvp\train_val\clean\build_2014.py
# pythonvp\train_val\clean\build_2015.py
# pythonvp\train_val\clean\build_dict.py
# pythonvp\train_val\clean\build_tfidf.py
# pythonvp\train_val\clean\c75_labeled_dialogue_generator.py
# pythonvp\train_val\clean\CacheConfig.py
# pythonvp\train_val\clean\calc.py
# pythonvp\train_val\clean\calclex.py
# pythonvp\train_val\clean\callbacks.py
# pythonvp\train_val\clean\campaign_analysis.py
# pythonvp\train_val\clean\campfire.py
# pythonvp\train_val\clean\cancel_repair.py
# pythonvp\train_val\clean\caps.py
# pythonvp\train_val\clean\captcha.py
# pythonvp\train_val\clean\cartesian.py
# pythonvp\train_val\clean\cases.py
# pythonvp\train_val\clean\catapult.py
# pythonvp\train_val\clean\categories.py
# pythonvp\train_val\clean\certs.py
# pythonvp\train_val\clean\ce_evpn_global.py
# pythonvp\train_val\clean\ce_netconf.py
# pythonvp\train_val\clean\ce_reboot.py
# pythonvp\train_val\clean\ce_template.py
# pythonvp\train_val\clean\Change.py
# pythonvp\train_val\clean\changes.py
# pythonvp\train_val\clean\change_password_wizard.py
# pythonvp\train_val\clean\change_sign.py
# pythonvp\train_val\clean\charsetgroupprober.py
# pythonvp\train_val\clean\chart.py
# pythonvp\train_val\clean\charunicodeencode.py
# pythonvp\train_val\clean\chat.py
# pythonvp\train_val\clean\check.py
# pythonvp\train_val\clean\checkHistory.py
# pythonvp\train_val\clean\checkouts.py
# pythonvp\train_val\clean\checkpoint.py
# pythonvp\train_val\clean\checkpoints.py
# pythonvp\train_val\clean\checkpoint_aggregator.py
# pythonvp\train_val\clean\check_print.py
# pythonvp\train_val\clean\check_profile_l10n_all.py
# pythonvp\train_val\clean\cherrypick.py
# pythonvp\train_val\clean\child1.py
# pythonvp\train_val\clean\child2.py
# pythonvp\train_val\clean\chroot.py
# pythonvp\train_val\clean\cipdserver_fake.py
# pythonvp\train_val\clean\ciscospark.py
# pythonvp\train_val\clean\cisco_ios.py
# pythonvp\train_val\clean\city.py
# pythonvp\train_val\clean\classifier_gpt2_reranker.py
# pythonvp\train_val\clean\cleanup_azure.py
# pythonvp\train_val\clean\cleanup_media.py
# pythonvp\train_val\clean\cleanup_rax.py
# pythonvp\train_val\clean\clean_tags.py
# pythonvp\train_val\clean\clear_state.py
# pythonvp\train_val\clean\clex.py
# pythonvp\train_val\clean\cli.py
# pythonvp\train_val\clean\clickatell.py
# pythonvp\train_val\clean\clickjacking.py
# pythonvp\train_val\clean\clientsecrets.py
# pythonvp\train_val\clean\ClockDomain.py
# pythonvp\train_val\clean\ClockedObject.py
# pythonvp\train_val\clean\cloudscale.py
# pythonvp\train_val\clean\cloudwatchlogs_log_group_facts.py
# pythonvp\train_val\clean\Cmos.py
# pythonvp\train_val\clean\cnos_command.py
# pythonvp\train_val\clean\cnos_factory.py
# pythonvp\train_val\clean\cnos_save.py
# pythonvp\train_val\clean\cnos_showrun.py
# pythonvp\train_val\clean\CntrlBase.py
# pythonvp\train_val\clean\codingstatemachine.py
# pythonvp\train_val\clean\coinmarketcap.py
# pythonvp\train_val\clean\collections.py
# pythonvp\train_val\clean\colors.py
# pythonvp\train_val\clean\colours.py
# pythonvp\train_val\clean\commalesslimit.py
# pythonvp\train_val\clean\comment.py
# pythonvp\train_val\clean\common.py
# pythonvp\train_val\clean\community_login.py
# pythonvp\train_val\clean\community_users.py
# pythonvp\train_val\clean\compare_and_write_mask.py
# pythonvp\train_val\clean\compare_and_write_minimum_or_maximum.py
# pythonvp\train_val\clean\compat.py
# pythonvp\train_val\clean\compilemessages.py
# pythonvp\train_val\clean\Composition.py
# pythonvp\train_val\clean\compute_resultant_report.py
# pythonvp\train_val\clean\concord232.py
# pythonvp\train_val\clean\conditional.py
# pythonvp\train_val\clean\conditional_jump.py
# pythonvp\train_val\clean\conf.py
# pythonvp\train_val\clean\configfile.py
# pythonvp\train_val\clean\configuration.py
# pythonvp\train_val\clean\configurator.py
# pythonvp\train_val\clean\config_entries.py
# pythonvp\train_val\clean\config_entry_flow.py
# pythonvp\train_val\clean\config_flow.py
# pythonvp\train_val\clean\confirm_statement_line.py
# pythonvp\train_val\clean\conjur_variable.py
# pythonvp\train_val\clean\connector.py
# pythonvp\train_val\clean\constructor.py
# pythonvp\train_val\clean\consul_running.py
# pythonvp\train_val\clean\contact_owners.py
# pythonvp\train_val\clean\contains_tuple.py
# pythonvp\train_val\clean\ContentConverter.py
# pythonvp\train_val\clean\content_index.py
# pythonvp\train_val\clean\context.py
# pythonvp\train_val\clean\contextmanagers.py
# pythonvp\train_val\clean\context_demo.py
# pythonvp\train_val\clean\context_shuffle.py
# pythonvp\train_val\clean\controllers.py
# pythonvp\train_val\clean\control_registers.py
# pythonvp\train_val\clean\convai2_ft.py
# pythonvp\train_val\clean\conversion_utils.py
# pythonvp\train_val\clean\convert.py
# pythonvp\train_val\clean\convert_and_load_or_store_bcd.py
# pythonvp\train_val\clean\convert_bool.py
# pythonvp\train_val\clean\convert_db_01.py
# pythonvp\train_val\clean\convert_floating_point_to_floating_point.py
# pythonvp\train_val\clean\convert_floating_point_to_gpr_integer.py
# pythonvp\train_val\clean\convert_floating_point_to_mmx_integer.py
# pythonvp\train_val\clean\convert_mmx_integer_to_floating_point.py
# pythonvp\train_val\clean\cookie.py
# pythonvp\train_val\clean\coordseq.py
# pythonvp\train_val\clean\core_tags.py
# pythonvp\train_val\clean\counter.py
# pythonvp\train_val\clean\count_all_persons.py
# pythonvp\train_val\clean\CPA.py
# pythonvp\train_val\clean\cpp_message.py
# pythonvp\train_val\clean\cpu-pid.py
# pythonvp\train_val\clean\cpuspeed.py
# pythonvp\train_val\clean\CPUTracers.py
# pythonvp\train_val\clean\CR.py
# pythonvp\train_val\clean\create_repo.py
# pythonvp\train_val\clean\credentials.py
# pythonvp\train_val\clean\credstash.py
# pythonvp\train_val\clean\crm_helpdesk.py
# pythonvp\train_val\clean\crm_lead_report.py
# pythonvp\train_val\clean\crm_partner_binding.py
# pythonvp\train_val\clean\crm_phonecall_to_opportunity.py
# pythonvp\train_val\clean\crm_phonecall_to_phonecall.py
# pythonvp\train_val\clean\crm_todo.py
# pythonvp\train_val\clean\crossovered_budget_report.py
# pythonvp\train_val\clean\cross_model_huge_reddit.py
# pythonvp\train_val\clean\cscope-index.py
# pythonvp\train_val\clean\csh.py
# pythonvp\train_val\clean\csrf.py
# pythonvp\train_val\clean\css.py
# pythonvp\train_val\clean\cs_facts.py
# pythonvp\train_val\clean\cs_instancegroup.py
# pythonvp\train_val\clean\cs_network_acl.py
# pythonvp\train_val\clean\cs_role.py
# pythonvp\train_val\clean\cs_securitygroup.py
# pythonvp\train_val\clean\cs_vpn_gateway.py
# pythonvp\train_val\clean\cs_zone_facts.py
# pythonvp\train_val\clean\cups.py
# pythonvp\train_val\clean\curated_response.py
# pythonvp\train_val\clean\currencylayer.py
# pythonvp\train_val\clean\custom.py
# pythonvp\train_val\clean\custombackend.py
# pythonvp\train_val\clean\customers.py
# pythonvp\train_val\clean\customfonts.py
# pythonvp\train_val\clean\custom_has_permission_admin.py
# pythonvp\train_val\clean\custom_startproject.py
# pythonvp\train_val\clean\custom_user.py
# pythonvp\train_val\clean\daily_dialog_ft.py
# pythonvp\train_val\clean\database.py
# pythonvp\train_val\clean\datadog.py
# pythonvp\train_val\clean\datadog_event.py
# pythonvp\train_val\clean\dataforge.py
# pythonvp\train_val\clean\datapower.py
# pythonvp\train_val\clean\datatype.py
# pythonvp\train_val\clean\data_entry_flow.py
# pythonvp\train_val\clean\data_generator.py
# pythonvp\train_val\clean\data_stats.py
# pythonvp\train_val\clean\data_store.py
# pythonvp\train_val\clean\data_validator.py
# pythonvp\train_val\clean\dateandtime.py
# pythonvp\train_val\clean\date_time.py
# pythonvp\train_val\clean\db.py
# pythonvp\train_val\clean\dbgtool.py
# pythonvp\train_val\clean\dbinit.py
# pythonvp\train_val\clean\dbshell.py
# pythonvp\train_val\clean\db_templating.py
# pythonvp\train_val\clean\db_url.py
# pythonvp\train_val\clean\dci_callback_plugin.py
# pythonvp\train_val\clean\debian.py
# pythonvp\train_val\clean\debug.py
# pythonvp\train_val\clean\debug_task.py
# pythonvp\train_val\clean\decimal_precision.py
# pythonvp\train_val\clean\decode_inst_dep_trace.py
# pythonvp\train_val\clean\decode_packet_trace.py
# pythonvp\train_val\clean\deconstruct.py
# pythonvp\train_val\clean\deconz.py
# pythonvp\train_val\clean\decora.py
# pythonvp\train_val\clean\decorator.py
# pythonvp\train_val\clean\decora_wifi.py
# pythonvp\train_val\clean\decrypt.py
# pythonvp\train_val\clean\defaults.py
# pythonvp\train_val\clean\default_callback.py
# pythonvp\train_val\clean\default_related_name.py
# pythonvp\train_val\clean\definition.py
# pythonvp\train_val\clean\delete.py
# pythonvp\train_val\clean\delete_old_entries.py
# pythonvp\train_val\clean\delete_record.py
# pythonvp\train_val\clean\dellos10_module.py
# pythonvp\train_val\clean\dellos9.py
# pythonvp\train_val\clean\dellos9_module.py
# pythonvp\train_val\clean\detect_offensive_language.py
# pythonvp\train_val\clean\deutsche_bahn.py
# pythonvp\train_val\clean\dev.py
# pythonvp\train_val\clean\dht.py
# pythonvp\train_val\clean\dialogpt.py
# pythonvp\train_val\clean\dicts.py
# pythonvp\train_val\clean\dict_90M.py
# pythonvp\train_val\clean\diff_isolates.py
# pythonvp\train_val\clean\digitalloggers.py
# pythonvp\train_val\clean\digital_ocean_account_facts.py
# pythonvp\train_val\clean\digital_ocean_domain_facts.py
# pythonvp\train_val\clean\digital_ocean_image_facts.py
# pythonvp\train_val\clean\digital_ocean_load_balancer_facts.py
# pythonvp\train_val\clean\digital_ocean_region_facts.py
# pythonvp\train_val\clean\digital_ocean_snapshot_facts.py
# pythonvp\train_val\clean\digital_ocean_volume_facts.py
# pythonvp\train_val\clean\dimensiondata_wait.py
# pythonvp\train_val\clean\DirectoryMemory.py
# pythonvp\train_val\clean\direct_connect.py
# pythonvp\train_val\clean\discogs.py
# pythonvp\train_val\clean\discord.py
# pythonvp\train_val\clean\DiskImage.py
# pythonvp\train_val\clean\display_data.py
# pythonvp\train_val\clean\display_model.py
# pythonvp\train_val\clean\distance.py
# pythonvp\train_val\clean\distributed_eval.py
# pythonvp\train_val\clean\dist_bigLITTLE.py
# pythonvp\train_val\clean\division.py
# pythonvp\train_val\clean\django_1_10.py
# pythonvp\train_val\clean\django_setup.py
# pythonvp\train_val\clean\dlib_face_detect.py
# pythonvp\train_val\clean\dlib_face_identify.py
# pythonvp\train_val\clean\dlink.py
# pythonvp\train_val\clean\dns.py
# pythonvp\train_val\clean\dnstxt.py
# pythonvp\train_val\clean\docker_compose.py
# pythonvp\train_val\clean\docs-build.py
# pythonvp\train_val\clean\docs.py
# pythonvp\train_val\clean\document_page_create_menu.py
# pythonvp\train_val\clean\document_report.py
# pythonvp\train_val\clean\document_webdav.py
# pythonvp\train_val\clean\doc_extensions.py
# pythonvp\train_val\clean\dominos.py
# pythonvp\train_val\clean\dot.py
# pythonvp\train_val\clean\dot_writer_ruby.py
# pythonvp\train_val\clean\download_feed_tests.py
# pythonvp\train_val\clean\download_images.py
# pythonvp\train_val\clean\dpkg_selections.py
# pythonvp\train_val\clean\DRAMSim2.py
# pythonvp\train_val\clean\dropbox.py
# pythonvp\train_val\clean\dropout_poly.py
# pythonvp\train_val\clean\ds.py
# pythonvp\train_val\clean\dte_energy_bridge.py
# pythonvp\train_val\clean\dummy.py
# pythonvp\train_val\clean\dummy_subj.py
# pythonvp\train_val\clean\dumpdata.py
# pythonvp\train_val\clean\dumper.py
# pythonvp\train_val\clean\dump_keywords.py
# pythonvp\train_val\clean\dump_task_to_acute_format.py
# pythonvp\train_val\clean\dunehd.py
# pythonvp\train_val\clean\duplicates.py
# pythonvp\train_val\clean\dvfs-perflevel.py
# pythonvp\train_val\clean\DVFSHandler.py
# pythonvp\train_val\clean\dweet.py
# pythonvp\train_val\clean\dyson.py
# pythonvp\train_val\clean\ec2_customer_gateway_facts.py
# pythonvp\train_val\clean\ec2_group_facts.py
# pythonvp\train_val\clean\ec2_placement_group.py
# pythonvp\train_val\clean\ec2_vol_facts.py
# pythonvp\train_val\clean\ec2_vpc_dhcp_option_facts.py
# pythonvp\train_val\clean\ec2_vpc_egress_igw.py
# pythonvp\train_val\clean\ec2_vpc_endpoint_facts.py
# pythonvp\train_val\clean\ec2_vpc_igw_facts.py
# pythonvp\train_val\clean\ec2_vpc_peering_facts.py
# pythonvp\train_val\clean\ec2_vpc_route_table_facts.py
# pythonvp\train_val\clean\echo.py
# pythonvp\train_val\clean\ecobee.py
# pythonvp\train_val\clean\econet.py
# pythonvp\train_val\clean\ecovacs.py
# pythonvp\train_val\clean\edgeos.py
# pythonvp\train_val\clean\edgeos_module.py
# pythonvp\train_val\clean\edimax.py
# pythonvp\train_val\clean\edit_post.py
# pythonvp\train_val\clean\edit_reservation.py
# pythonvp\train_val\clean\edp_redy.py
# pythonvp\train_val\clean\efergy.py
# pythonvp\train_val\clean\EGA.py
# pythonvp\train_val\clean\egardia.py
# pythonvp\train_val\clean\eggs.py
# pythonvp\train_val\clean\ElasticTrace.py
# pythonvp\train_val\clean\eli5_ft.py
# pythonvp\train_val\clean\eliqonline.py
# pythonvp\train_val\clean\elkm1.py
# pythonvp\train_val\clean\empty.py
# pythonvp\train_val\clean\empty_join.py
# pythonvp\train_val\clean\empty_pb2.py
# pythonvp\train_val\clean\encode_inst_dep_trace.py
# pythonvp\train_val\clean\end2end_generator.py
# pythonvp\train_val\clean\endian_conversion.py
# pythonvp\train_val\clean\engine.py
# pythonvp\train_val\clean\enocean.py
# pythonvp\train_val\clean\EnqueueStatementAST.py
# pythonvp\train_val\clean\ensure_config.py
# pythonvp\train_val\clean\entities.py
# pythonvp\train_val\clean\entity_values.py
# pythonvp\train_val\clean\enumeration.py
# pythonvp\train_val\clean\EnumExprAST.py
# pythonvp\train_val\clean\enums.py
# pythonvp\train_val\clean\env.py
# pythonvp\train_val\clean\environment_vars.py
# pythonvp\train_val\clean\eos_banner.py
# pythonvp\train_val\clean\equaltolike.py
# pythonvp\train_val\clean\ER.py
# pythonvp\train_val\clean\err.py
# pythonvp\train_val\clean\errors.py
# pythonvp\train_val\clean\escapequotes.py
# pythonvp\train_val\clean\escprober.py
# pythonvp\train_val\clean\etcd.py
# pythonvp\train_val\clean\etherscan.py
# pythonvp\train_val\clean\etrace_replay.py
# pythonvp\train_val\clean\eucjpprober.py
# pythonvp\train_val\clean\euckrprober.py
# pythonvp\train_val\clean\euctwprober.py
# pythonvp\train_val\clean\eval_retrieval_model.py
# pythonvp\train_val\clean\event_sale.py
# pythonvp\train_val\clean\exceptions.py
# pythonvp\train_val\clean\exclusive_or.py
# pythonvp\train_val\clean\exoscale.py
# pythonvp\train_val\clean\expense.py
# pythonvp\train_val\clean\experiments.py
# pythonvp\train_val\clean\ExportToRML.py
# pythonvp\train_val\clean\export_db.py
# pythonvp\train_val\clean\export_track_data.py
# pythonvp\train_val\clean\Expression.py
# pythonvp\train_val\clean\ExprStatementAST.py
# pythonvp\train_val\clean\extend-urls.py
# pythonvp\train_val\clean\extend.py
# pythonvp\train_val\clean\extract.py
# pythonvp\train_val\clean\extract_sign_mask.py
# pythonvp\train_val\clean\extra_urls.py
# pythonvp\train_val\clean\f5.py
# pythonvp\train_val\clean\fabfile.py
# pythonvp\train_val\clean\facter.py
# pythonvp\train_val\clean\factory_test1_pb2.py
# pythonvp\train_val\clean\fail.py
# pythonvp\train_val\clean\fallback.py
# pythonvp\train_val\clean\familyhub.py
# pythonvp\train_val\clean\fastdotcom.py
# pythonvp\train_val\clean\faux-editor.py
# pythonvp\train_val\clean\fedex.py
# pythonvp\train_val\clean\feedreader.py
# pythonvp\train_val\clean\feeds.py
# pythonvp\train_val\clean\fetch.py
# pythonvp\train_val\clean\ffmpeg_motion.py
# pythonvp\train_val\clean\fib.py
# pythonvp\train_val\clean\fido.py
# pythonvp\train_val\clean\field.py
# pythonvp\train_val\clean\fileglob.py
# pythonvp\train_val\clean\fileset_change_monitor.py
# pythonvp\train_val\clean\filespace_test.py
# pythonvp\train_val\clean\filesystem.py
# pythonvp\train_val\clean\filetree.py
# pythonvp\train_val\clean\file_cache.py
# pythonvp\train_val\clean\file_test.py
# pythonvp\train_val\clean\finalize_qda.py
# pythonvp\train_val\clean\findstatic.py
# pythonvp\train_val\clean\fips.py
# pythonvp\train_val\clean\first_found.py
# pythonvp\train_val\clean\fish.py
# pythonvp\train_val\clean\fixer.py
# pythonvp\train_val\clean\fixture.py
# pythonvp\train_val\clean\fix_test_syntax.py
# pythonvp\train_val\clean\flag_note.py
# pythonvp\train_val\clean\flake8.py
# pythonvp\train_val\clean\flask.py
# pythonvp\train_val\clean\flatpages.py
# pythonvp\train_val\clean\flatten.py
# pythonvp\train_val\clean\flowdock.py
# pythonvp\train_val\clean\folder.py
# pythonvp\train_val\clean\foo2.py
# pythonvp\train_val\clean\foobot.py
# pythonvp\train_val\clean\FormalParamAST.py
# pythonvp\train_val\clean\format_safety_ready.py
# pythonvp\train_val\clean\forms.py
# pythonvp\train_val\clean\fortiweb.py
# pythonvp\train_val\clean\foursquare.py
# pythonvp\train_val\clean\freebsd.py
# pythonvp\train_val\clean\freedns.py
# pythonvp\train_val\clean\freeipa.py
# pythonvp\train_val\clean\fritz.py
# pythonvp\train_val\clean\fritzbox.py
# pythonvp\train_val\clean\fritzdect.py
# pythonvp\train_val\clean\fsdp.py
# pythonvp\train_val\clean\fs_power.py
# pythonvp\train_val\clean\ftp_browse.py
# pythonvp\train_val\clean\full_skip.py
# pythonvp\train_val\clean\func.py
# pythonvp\train_val\clean\FuncCallExprAST.py
# pythonvp\train_val\clean\funcd.py
# pythonvp\train_val\clean\FuncDeclAST.py
# pythonvp\train_val\clean\FuncUnitConfig.py
# pythonvp\train_val\clean\funpedia.py
# pythonvp\train_val\clean\FUPool.py
# pythonvp\train_val\clean\fuse_gmock_files.py
# pythonvp\train_val\clean\fuse_gtest_files.py
# pythonvp\train_val\clean\GarnetLink.py
# pythonvp\train_val\clean\Garnet_standalone.py
# pythonvp\train_val\clean\gateway.py
# pythonvp\train_val\clean\gb2312prober.py
# pythonvp\train_val\clean\gce_eip.py
# pythonvp\train_val\clean\gcpubsub_facts.py
# pythonvp\train_val\clean\gender__ctrl_gen_tokens.py
# pythonvp\train_val\clean\gender__unlikelihood_sequence_level.py
# pythonvp\train_val\clean\general.py
# pythonvp\train_val\clean\general_io.py
# pythonvp\train_val\clean\generate_agent_list.py
# pythonvp\train_val\clean\generate_cli.py
# pythonvp\train_val\clean\generate_mutator_list.py
# pythonvp\train_val\clean\generate_names.py
# pythonvp\train_val\clean\generate_offensive_language_test.py
# pythonvp\train_val\clean\generate_opt_presets.py
# pythonvp\train_val\clean\generate_task_list.py
# pythonvp\train_val\clean\generate_zoo_list.py
# pythonvp\train_val\clean\gen_arm_fs_files.py
# pythonvp\train_val\clean\geojson.py
# pythonvp\train_val\clean\geom.py
# pythonvp\train_val\clean\geomtype.py
# pythonvp\train_val\clean\geos.py
# pythonvp\train_val\clean\geo_rss_events.py
# pythonvp\train_val\clean\getent.py
# pythonvp\train_val\clean\get_al_samples_for_gsgd.py
# pythonvp\train_val\clean\get_api_data.py
# pythonvp\train_val\clean\get_interdistinct_on_conversations.py
# pythonvp\train_val\clean\get_library.py
# pythonvp\train_val\clean\get_quick_eval_stats.py
# pythonvp\train_val\clean\gfal.py
# pythonvp\train_val\clean\Gic.py
# pythonvp\train_val\clean\github_release.py
# pythonvp\train_val\clean\gitter.py
# pythonvp\train_val\clean\global_index.py
# pythonvp\train_val\clean\gmap.py
# pythonvp\train_val\clean\gmock_leak_test.py
# pythonvp\train_val\clean\gmock_output_test.py
# pythonvp\train_val\clean\gmock_test_utils.py
# pythonvp\train_val\clean\goalfeed.py
# pythonvp\train_val\clean\google_maps.py
# pythonvp\train_val\clean\google_wifi.py
# pythonvp\train_val\clean\gpslogger.py
# pythonvp\train_val\clean\gpu-randomtest-ruby.py
# pythonvp\train_val\clean\GPUCoalescer.py
# pythonvp\train_val\clean\GPUStaticInstFlags.py
# pythonvp\train_val\clean\GPUTLBConfig.py
# pythonvp\train_val\clean\grammar.py
# pythonvp\train_val\clean\Graphics.py
# pythonvp\train_val\clean\graphite.py
# pythonvp\train_val\clean\gridftp.py
# pythonvp\train_val\clean\grouparticlesadd.py
# pythonvp\train_val\clean\group_by.py
# pythonvp\train_val\clean\grpc.py
# pythonvp\train_val\clean\gstreamer.py
# pythonvp\train_val\clean\gtest_throw_on_failure_test.py
# pythonvp\train_val\clean\gtest_xml_outfiles_test.py
# pythonvp\train_val\clean\gunicorn-settings.py
# pythonvp\train_val\clean\gzip.py
# pythonvp\train_val\clean\hack_1.py
# pythonvp\train_val\clean\hal.py
# pythonvp\train_val\clean\halfversionedmorekeywords.py
# pythonvp\train_val\clean\halt.py
# pythonvp\train_val\clean\handler.py
# pythonvp\train_val\clean\handlers.py
# pythonvp\train_val\clean\handler_404_urls.py
# pythonvp\train_val\clean\handler_task_include.py
# pythonvp\train_val\clean\hangouts.py
# pythonvp\train_val\clean\hashdb.py
# pythonvp\train_val\clean\hashing.py
# pythonvp\train_val\clean\hassbian.py
# pythonvp\train_val\clean\haveibeenpwned.py
# pythonvp\train_val\clean\hddtemp.py
# pythonvp\train_val\clean\header.py
# pythonvp\train_val\clean\heatmiser.py
# pythonvp\train_val\clean\hebrewprober.py
# pythonvp\train_val\clean\HelloObject.py
# pythonvp\train_val\clean\hello_world.py
# pythonvp\train_val\clean\helm.py
# pythonvp\train_val\clean\hgstyle.py
# pythonvp\train_val\clean\hiera.py
# pythonvp\train_val\clean\hipchat.py
# pythonvp\train_val\clean\hive.py
# pythonvp\train_val\clean\HMCController.py
# pythonvp\train_val\clean\hmc_hello.py
# pythonvp\train_val\clean\homekit_controller.py
# pythonvp\train_val\clean\homematic.py
# pythonvp\train_val\clean\horizontal_addition.py
# pythonvp\train_val\clean\hpe_test_utils.py
# pythonvp\train_val\clean\hponcfg.py
# pythonvp\train_val\clean\hr_attendance_bymonth.py
# pythonvp\train_val\clean\hr_department.py
# pythonvp\train_val\clean\hr_expense_report.py
# pythonvp\train_val\clean\hr_holidays_report.py
# pythonvp\train_val\clean\hr_payroll_payslips_by_employees.py
# pythonvp\train_val\clean\hr_recruitment_employee_hired.py
# pythonvp\train_val\clean\hr_recruitment_report.py
# pythonvp\train_val\clean\hr_timesheet_final_invoice_create.py
# pythonvp\train_val\clean\hr_timesheet_print_users.py
# pythonvp\train_val\clean\hr_timesheet_report.py
# pythonvp\train_val\clean\html_parser.py
# pythonvp\train_val\clean\HTTP.py
# pythonvp\train_val\clean\httpshandler.py
# pythonvp\train_val\clean\huawei_lte.py
# pythonvp\train_val\clean\hugging_face.py
# pythonvp\train_val\clean\hunterdouglas_powerview.py
# pythonvp\train_val\clean\hurd.py
# pythonvp\train_val\clean\hydroquebec.py
# pythonvp\train_val\clean\hyperguard.py
# pythonvp\train_val\clean\I2C.py
# pythonvp\train_val\clean\I82094AA.py
# pythonvp\train_val\clean\I8237.py
# pythonvp\train_val\clean\I8259.py
# pythonvp\train_val\clean\ialarm.py
# pythonvp\train_val\clean\iam_server_certificate_facts.py
# pythonvp\train_val\clean\idea.py
# pythonvp\train_val\clean\id_token.py
# pythonvp\train_val\clean\ifttt.py
# pythonvp\train_val\clean\igc_ft.py
# pythonvp\train_val\clean\ihc.py
# pythonvp\train_val\clean\ihcdevice.py
# pythonvp\train_val\clean\image.py
# pythonvp\train_val\clean\image_upload.py
# pythonvp\train_val\clean\imap.py
# pythonvp\train_val\clean\impl.py
# pythonvp\train_val\clean\import_email.py
# pythonvp\train_val\clean\import_fixture.py
# pythonvp\train_val\clean\import_playbook.py
# pythonvp\train_val\clean\included.py
# pythonvp\train_val\clean\included_app_urls.py
# pythonvp\train_val\clean\included_no_kwargs_urls.py
# pythonvp\train_val\clean\included_urls.py
# pythonvp\train_val\clean\include_role.py
# pythonvp\train_val\clean\include_tasks.py
# pythonvp\train_val\clean\include_vars.py
# pythonvp\train_val\clean\include_with_dollar.py
# pythonvp\train_val\clean\inclusion.py
# pythonvp\train_val\clean\increment_and_decrement.py
# pythonvp\train_val\clean\indexed_items.py
# pythonvp\train_val\clean\indexing.py
# pythonvp\train_val\clean\index_dense_embeddings.py
# pythonvp\train_val\clean\indieauth.py
# pythonvp\train_val\clean\infinibox.py
# pythonvp\train_val\clean\infini_export_client.py
# pythonvp\train_val\clean\infini_pool.py
# pythonvp\train_val\clean\influxdb.py
# pythonvp\train_val\clean\influxdb_migrator.py
# pythonvp\train_val\clean\influxdb_user.py
# pythonvp\train_val\clean\influxdb_write.py
# pythonvp\train_val\clean\infoblox.py
# pythonvp\train_val\clean\infra_types.py
# pythonvp\train_val\clean\initial.py
# pythonvp\train_val\clean\initialise.py
# pythonvp\train_val\clean\init_data.py
# pythonvp\train_val\clean\inner_pb2.py
# pythonvp\train_val\clean\InPortDeclAST.py
# pythonvp\train_val\clean\input_boolean.py
# pythonvp\train_val\clean\input_datetime.py
# pythonvp\train_val\clean\input_number.py
# pythonvp\train_val\clean\input_select.py
# pythonvp\train_val\clean\input_text.py
# pythonvp\train_val\clean\inspect.py
# pythonvp\train_val\clean\inspectdb.py
# pythonvp\train_val\clean\install.py
# pythonvp\train_val\clean\instapush.py
# pythonvp\train_val\clean\insteon.py
# pythonvp\train_val\clean\insteon_plm.py
# pythonvp\train_val\clean\InstPBTrace.py
# pythonvp\train_val\clean\instrumented_requests.py
# pythonvp\train_val\clean\integer.py
# pythonvp\train_val\clean\integration_aliases.py
# pythonvp\train_val\clean\IntelMP.py
# pythonvp\train_val\clean\interactive.py
# pythonvp\train_val\clean\interactive_retrieval_model.py
# pythonvp\train_val\clean\interrupts_and_exceptions.py
# pythonvp\train_val\clean\IntrControl.py
# pythonvp\train_val\clean\introduction.py
# pythonvp\train_val\clean\introspection.py
# pythonvp\train_val\clean\invalid_models.py
# pythonvp\train_val\clean\invite.py
# pythonvp\train_val\clean\invlpg.py
# pythonvp\train_val\clean\ios.py
# pythonvp\train_val\clean\ios_lldp.py
# pythonvp\train_val\clean\ipa.py
# pythonvp\train_val\clean\ipa_sudocmdgroup.py
# pythonvp\train_val\clean\iperf3.py
# pythonvp\train_val\clean\ipify_facts.py
# pythonvp\train_val\clean\ipma.py
# pythonvp\train_val\clean\ipmi_boot.py
# pythonvp\train_val\clean\ipmi_power.py
# pythonvp\train_val\clean\ip_netns.py
# pythonvp\train_val\clean\iri2uri.py
# pythonvp\train_val\clean\ironware_command.py
# pythonvp\train_val\clean\ir_config_parameter.py
# pythonvp\train_val\clean\ir_default.py
# pythonvp\train_val\clean\ir_exports.py
# pythonvp\train_val\clean\ir_filters.py
# pythonvp\train_val\clean\ir_report.py
# pythonvp\train_val\clean\ISACommon.py
# pythonvp\train_val\clean\iss.py
# pythonvp\train_val\clean\is_active.py
# pythonvp\train_val\clean\itach.py
# pythonvp\train_val\clean\jail.py
# pythonvp\train_val\clean\jbon.py
# pythonvp\train_val\clean\jboss.py
# pythonvp\train_val\clean\jiasule.py
# pythonvp\train_val\clean\jinja2.py
# pythonvp\train_val\clean\jslex.py
# pythonvp\train_val\clean\json.py
# pythonvp\train_val\clean\jsonb.py
# pythonvp\train_val\clean\jsonify.py
# pythonvp\train_val\clean\json_query.py
# pythonvp\train_val\clean\junos_module.py
# pythonvp\train_val\clean\junos_scp.py
# pythonvp\train_val\clean\k8s_auth_options.py
# pythonvp\train_val\clean\k8s_name_options.py
# pythonvp\train_val\clean\k8s_resource_options.py
# pythonvp\train_val\clean\k8s_scale_options.py
# pythonvp\train_val\clean\kernel_blacklist.py
# pythonvp\train_val\clean\keyboard.py
# pythonvp\train_val\clean\keyboard_remote.py
# pythonvp\train_val\clean\keyring_storage.py
# pythonvp\train_val\clean\keywords.py
# pythonvp\train_val\clean\kira.py
# pythonvp\train_val\clean\kml.py
# pythonvp\train_val\clean\knownsec.py
# pythonvp\train_val\clean\known_hosts.py
# pythonvp\train_val\clean\kona.py
# pythonvp\train_val\clean\kv.py
# pythonvp\train_val\clean\KvmGic.py
# pythonvp\train_val\clean\KvmVM.py
# pythonvp\train_val\clean\l10n.py
# pythonvp\train_val\clean\l10n_be_coda.py
# pythonvp\train_val\clean\l10n_fr_hr_payroll.py
# pythonvp\train_val\clean\l10n_ma.py
# pythonvp\train_val\clean\lametric.py
# pythonvp\train_val\clean\large_test.py
# pythonvp\train_val\clean\last_turn.py
# pythonvp\train_val\clean\latin1prober.py
# pythonvp\train_val\clean\lat_mem_rd.py
# pythonvp\train_val\clean\lazy.py
# pythonvp\train_val\clean\LdsState.py
# pythonvp\train_val\clean\left_logical_shift.py
# pythonvp\train_val\clean\legacy_api_password.py
# pythonvp\train_val\clean\lex_closure.py
# pythonvp\train_val\clean\lex_dup2.py
# pythonvp\train_val\clean\lex_dup3.py
# pythonvp\train_val\clean\lex_empty.py
# pythonvp\train_val\clean\lex_error1.py
# pythonvp\train_val\clean\lex_error3.py
# pythonvp\train_val\clean\lex_error4.py
# pythonvp\train_val\clean\lex_hedit.py
# pythonvp\train_val\clean\lex_ignore2.py
# pythonvp\train_val\clean\lex_literal2.py
# pythonvp\train_val\clean\lex_many_tokens.py
# pythonvp\train_val\clean\lex_module_import.py
# pythonvp\train_val\clean\lex_optimize2.py
# pythonvp\train_val\clean\lex_re1.py
# pythonvp\train_val\clean\lex_state1.py
# pythonvp\train_val\clean\lex_state3.py
# pythonvp\train_val\clean\lex_state5.py
# pythonvp\train_val\clean\lex_state_noerror.py
# pythonvp\train_val\clean\lex_state_norule.py
# pythonvp\train_val\clean\lex_token3.py
# pythonvp\train_val\clean\lex_token4.py
# pythonvp\train_val\clean\lex_token_dup.py
# pythonvp\train_val\clean\libgeos.py
# pythonvp\train_val\clean\librato_annotation.py
# pythonvp\train_val\clean\libsize.py
# pythonvp\train_val\clean\libvirt_lxc.py
# pythonvp\train_val\clean\lifx_cloud.py
# pythonvp\train_val\clean\linksys_ap.py
# pythonvp\train_val\clean\linux_battery.py
# pythonvp\train_val\clean\lirc.py
# ...
# pythonvp\test\clean\articleurls.py
# pythonvp\test\clean\attrdict.py
# pythonvp\test\clean\auth_crypt.py
# pythonvp\test\clean\auth_provider_homeassistant.py
# pythonvp\test\clean\avi_applicationpersistenceprofile.py
# pythonvp\test\clean\avi_ipamdnsproviderprofile.py
# pythonvp\test\clean\avi_poolgroupdeploymentpolicy.py
# pythonvp\test\clean\avi_role.py
# pythonvp\test\clean\avi_sslkeyandcertificate.py
# pythonvp\test\clean\aws_service_ip_ranges.py
# pythonvp\test\clean\axis.py
# pythonvp\test\clean\azure_rm_dnszone_facts.py
# pythonvp\test\clean\azure_rm_publicipaddress_facts.py
# pythonvp\test\clean\azure_rm_virtualnetwork_facts.py
# pythonvp\test\clean\bart_fid_dpr.py
# pythonvp\test\clean\bart_fid_rag.py
# pythonvp\test\clean\bart_rag_sequence.py
# pythonvp\test\clean\bart_rag_turn_dtt.py
# pythonvp\test\clean\BaseArmKvmCPU.py
# pythonvp\test\clean\base_tests.py
# pythonvp\test\clean\basiclog.py
# pythonvp\test\clean\bbb_gpio.py
# pythonvp\test\clean\bert_dictionary.py
# pythonvp\test\clean\bert_ranker.py
# pythonvp\test\clean\biencoder.py
# pythonvp\test\clean\big5prober.py
# pythonvp\test\clean\binarysec.py
# pythonvp\test\clean\bi_encoder_ranker.py
# pythonvp\test\clean\blackbird.py
# pythonvp\test\clean\blender_3B.py
# pythonvp\test\clean\blockdos.py
# pythonvp\test\clean\BPConfig.py
# pythonvp\test\clean\build_sha_check_script.py
# pythonvp\test\clean\cancel_statement_line.py
# pythonvp\test\clean\cert_expiry.py
# pythonvp\test\clean\CheckAllocateStatementAST.py
# pythonvp\test\clean\classifier.py
# pythonvp\test\clean\classify.py
# pythonvp\test\clean\comed_hourly_pricing.py
# pythonvp\test\clean\commalessmid.py
# pythonvp\test\clean\company.py
# pythonvp\test\clean\compare_and_write_rflags.py
# pythonvp\test\clean\compress.py
# pythonvp\test\clean\convert_data_to_json_format.py
# pythonvp\test\clean\createcachetable.py
# pythonvp\test\clean\createsuperuser.py
# pythonvp\test\clean\crimereports.py
# pythonvp\test\clean\crossencoder.py
# pythonvp\test\clean\curr_only_classifier.py
# pythonvp\test\clean\customize.py
# pythonvp\test\clean\dashboard.py
# pythonvp\test\clean\datasource.py
# pythonvp\test\clean\dateparse.py
# pythonvp\test\clean\db_migrator.py
# pythonvp\test\clean\detect_spam.py
# pythonvp\test\clean\disabled.py
# pythonvp\test\clean\distributed_train.py
# pythonvp\test\clean\dladm_etherstub.py
# pythonvp\test\clean\document_configuration.py
# pythonvp\test\clean\document_page.py
# pythonvp\test\clean\dram_lat_mem_rd_plot.py
# pythonvp\test\clean\dram_sweep_plot.py
# pythonvp\test\clean\DummyChecker.py
# pythonvp\test\clean\dummy_data.py
# pythonvp\test\clean\dump_project_remote_repo_relation.py
# pythonvp\test\clean\dynamodb_ttl.py
# pythonvp\test\clean\ebox.py
# pythonvp\test\clean\ec2_vpc_vgw_facts.py
# pythonvp\test\clean\eddystone_temperature.py
# pythonvp\test\clean\edit_settings.py
# pythonvp\test\clean\elb_classic_lb_facts.py
# pythonvp\test\clean\emit_notices.py
# pythonvp\test\clean\empathetic_dialogues_ft.py
# pythonvp\test\clean\encrypt.py
# pythonvp\test\clean\enphase_envoy.py
# pythonvp\test\clean\entityfilter.py
# pythonvp\test\clean\envirophat.py
# pythonvp\test\clean\etcd3.py
# pythonvp\test\clean\Ethernet.py
# pythonvp\test\clean\event_handlers.py
# pythonvp\test\clean\example_wrapper.py
# pythonvp\test\clean\exit_media_state.py
# pythonvp\test\clean\exo_dns_domain.py
# pythonvp\test\clean\expanded_and_multiobjective_1024.py
# pythonvp\test\clean\ExternalSlave.py
# pythonvp\test\clean\factory.py
# pythonvp\test\clean\facts.py
# pythonvp\test\clean\ffmpeg.py
# pythonvp\test\clean\fiche_paye.py
# pythonvp\test\clean\FLAG.py
# pythonvp\test\clean\frontend.py
# pythonvp\test\clean\generate_dense_embeddings.py
# pythonvp\test\clean\generic_urls.py
# pythonvp\test\clean\genini.py
# pythonvp\test\clean\gpsd.py
# pythonvp\test\clean\GS.py
# pythonvp\test\clean\guest_auth.py
# pythonvp\test\clean\headerfunctions.py
# pythonvp\test\clean\headers.py
# pythonvp\test\clean\hgfilesize.py
# pythonvp\test\clean\honeybadger_deployment.py
# pythonvp\test\clean\host.py
# pythonvp\test\clean\hp_ilo.py
# pythonvp\test\clean\hr_salary_employee_bymonth.py
# pythonvp\test\clean\hr_timesheet_invoice_create.py
# pythonvp\test\clean\http_server.py
# pythonvp\test\clean\hydrawise.py
# pythonvp\test\clean\incapsula.py
# pythonvp\test\clean\influxdb_retention_policy.py
# pythonvp\test\clean\initialize.py
# pythonvp\test\clean\int_to_text.py
# pythonvp\test\clean\ipinfoio_facts.py
# pythonvp\test\clean\ir_needaction.py
# pythonvp\test\clean\IsValidPtrExprAST.py
# pythonvp\test\clean\items.py
# pythonvp\test\clean\iterate.py
# pythonvp\test\clean\itercompat.py
# pythonvp\test\clean\jabber.py
# pythonvp\test\clean\juicenet.py
# pythonvp\test\clean\junos_lldp_interface.py
# pythonvp\test\clean\k8s_scale.py
# pythonvp\test\clean\keenetic_ndms2.py
# pythonvp\test\clean\keycloak_client_secret.py
# pythonvp\test\clean\landscape.py
# pythonvp\test\clean\lastpass.py
# pythonvp\test\clean\ldap_auth.py
# pythonvp\test\clean\leave_locale_alone_false.py
# pythonvp\test\clean\leave_locale_alone_true.py
# pythonvp\test\clean\lex_error2.py
# pythonvp\test\clean\lex_module.py
# pythonvp\test\clean\lex_token5.py
# pythonvp\test\clean\listener.py
# pythonvp\test\clean\localserver.py
# pythonvp\test\clean\log.py
# pythonvp\test\clean\logentries.py
# pythonvp\test\clean\logging_utils_test.py
# pythonvp\test\clean\logstash.py
# pythonvp\test\clean\long_rag.py
# pythonvp\test\clean\luftdaten.py
# pythonvp\test\clean\lw12wifi.py
# pythonvp\test\clean\mailgun.py
# pythonvp\test\clean\make_invoice.py
# pythonvp\test\clean\MathExprPowerModel.py
# pythonvp\test\clean\memtest-run.py
# pythonvp\test\clean\meraki.py
# pythonvp\test\clean\mikrotik.py
# pythonvp\test\clean\MipsTLB.py
# pythonvp\test\clean\models_other.py
# pythonvp\test\clean\model_checks.py
# pythonvp\test\clean\module_graph.py
# pythonvp\test\clean\mopar.py
# pythonvp\test\clean\mrp_code_barcode.py
# pythonvp\test\clean\multi_connection_proxy.py
# pythonvp\test\clean\netconf.py
# pythonvp\test\clean\net_ping.py
# pythonvp\test\clean\nmap_tracker.py
# pythonvp\test\clean\no-basestring.py
# pythonvp\test\clean\notes_for_all_persons.py
# pythonvp\test\clean\no_ip.py
# pythonvp\test\clean\nso_verify.py
# pythonvp\test\clean\nx584.py
# pythonvp\test\clean\nxos_ospf.py
# pythonvp\test\clean\nxos_vtp_domain.py
# pythonvp\test\clean\nzbget.py
# pythonvp\test\clean\oc.py
# pythonvp\test\clean\ohai.py
# pythonvp\test\clean\oneline.py
# pythonvp\test\clean\oneview_logical_interconnect_group.py
# pythonvp\test\clean\openevse.py
# pythonvp\test\clean\opengarage.py
# pythonvp\test\clean\openhardwaremonitor.py
# pythonvp\test\clean\opentype.py
# pythonvp\test\clean\os_keystone_endpoint.py
# pythonvp\test\clean\os_networks_facts.py
# pythonvp\test\clean\os_security_group.py
# pythonvp\test\clean\ovirt_group.py
# pythonvp\test\clean\ovirt_networks_facts.py
# pythonvp\test\clean\ovirt_quotas_facts.py
# pythonvp\test\clean\ovirt_snapshots_facts.py
# pythonvp\test\clean\paginator.py
# pythonvp\test\clean\panos_admpwd.py
# pythonvp\test\clean\parrot.py
# pythonvp\test\clean\parse_version.py
# pythonvp\test\clean\payment_advice_report.py
# pythonvp\test\clean\perspective_api.py
# pythonvp\test\clean\picotts.py
# pythonvp\test\clean\pioneer.py
# pythonvp\test\clean\pkg5.py
# pythonvp\test\clean\postgresql_ext.py
# pythonvp\test\clean\posturls.py
# pythonvp\test\clean\pos_invoice.py
# pythonvp\test\clean\pre.py
# pythonvp\test\clean\prepare_integration_tests.py
# pythonvp\test\clean\procenv.py
# pythonvp\test\clean\processingnode_extras.py
# pythonvp\test\clean\profile_expanded_attention_128.py
# pythonvp\test\clean\project_account_analytic_line.py
# pythonvp\test\clean\project_compute_tasks.py
# pythonvp\test\clean\project_gtd_empty.py
# pythonvp\test\clean\project_mrp.py
# pythonvp\test\clean\project_task_delegate.py
# pythonvp\test\clean\prowl.py
# pythonvp\test\clean\proxysql.py
# pythonvp\test\clean\pycompat24.py
# pythonvp\test\clean\query.py
# pythonvp\test\clean\queue_settings.py
# pythonvp\test\clean\quuz.py
# pythonvp\test\clean\r2c2_blenderbot_400M.py
# pythonvp\test\clean\rabbitmq_policy.py
# pythonvp\test\clean\randomcase.py
# pythonvp\test\clean\rax_meta.py
# pythonvp\test\clean\realview-switcheroo-full.py
# pythonvp\test\clean\realview64-simple-atomic.py
# pythonvp\test\clean\reciprocal_square_root.py
# pythonvp\test\clean\reconnect_remoterepositories.py
# pythonvp\test\clean\RedirectPath.py
# pythonvp\test\clean\regex.py
# pythonvp\test\clean\registration.py
# pythonvp\test\clean\related_lookups.py
# pythonvp\test\clean\ReplacementPolicy.py
# pythonvp\test\clean\report_contribution_register.py
# pythonvp\test\clean\report_intrastat.py
# pythonvp\test\clean\report_stock.py
# pythonvp\test\clean\res_partner.py
# pythonvp\test\clean\reveal.py
# pythonvp\test\clean\rfc3279.py
# pythonvp\test\clean\rfc3414.py
# pythonvp\test\clean\rpi_camera.py
# pythonvp\test\clean\rpm_key.py
# pythonvp\test\clean\ruby-block-size-bytes.py
# pythonvp\test\clean\Ruby.py
# pythonvp\test\clean\runserver.py
# pythonvp\test\clean\run_simple.py
# pythonvp\test\clean\run_unit_tests.py
# pythonvp\test\clean\save_and_restore_state.py
# pythonvp\test\clean\scsgate.py
# pythonvp\test\clean\selenium.py
# pythonvp\test\clean\semaphores.py
# pythonvp\test\clean\session.py
# pythonvp\test\clean\settings_page.py
# pythonvp\test\clean\set_and_clear.py
# pythonvp\test\clean\sign_extension.py
# pythonvp\test\clean\simple-atomic-dummychecker.py
# pythonvp\test\clean\SimpleDisk.py
# pythonvp\test\clean\SimpleTrace.py
# pythonvp\test\clean\single_turn.py
# pythonvp\test\clean\site_init.py
# pythonvp\test\clean\skippy.py
# pythonvp\test\clean\slxos.py
# pythonvp\test\clean\spacy_tokenizer.py
# pythonvp\test\clean\ssh_pub_keys.py
# pythonvp\test\clean\startplugin.py
# pythonvp\test\clean\StateDeclAST.py
# pythonvp\test\clean\status_pb2.py
# pythonvp\test\clean\stock_inventory_merge.py
# pythonvp\test\clean\stock_invoice.py
# pythonvp\test\clean\streamname_test.py
# pythonvp\test\clean\subjecterror.py
# pythonvp\test\clean\summsc_fidrag3B.py
# pythonvp\test\clean\summsc_rag3B.py
# pythonvp\test\clean\survey_selection.py
# pythonvp\test\clean\switcheroo.py
# pythonvp\test\clean\sysctl.py
# pythonvp\test\clean\sytadin.py
# pythonvp\test\clean\teksavvy.py
# pythonvp\test\clean\test_admin_dashboard.py
# pythonvp\test\clean\test_agents.py
# pythonvp\test\clean\test_autoescape.py
# pythonvp\test\clean\test_aws_module.py
# pythonvp\test\clean\test_bad_identifiers_pb2.py
# pythonvp\test\clean\test_bigip_hostname.py
# pythonvp\test\clean\test_bigip_policy.py
# pythonvp\test\clean\test_bigip_policy_rule.py
# pythonvp\test\clean\test_bigip_ssl_key.py
# pythonvp\test\clean\test_bigip_sys_db.py
# pythonvp\test\clean\test_bigiq_regkey_license.py
# pythonvp\test\clean\test_bigiq_regkey_pool.py
# pythonvp\test\clean\test_blended_skill_talk_gpu.py
# pythonvp\test\clean\test_choicefield.py
# pythonvp\test\clean\test_cindex.py
# pythonvp\test\clean\test_clearablefileinput.py
# pythonvp\test\clean\test_coinmarketcap.py
# pythonvp\test\clean\test_configurator.py
# pythonvp\test\clean\test_crypto.py
# pythonvp\test\clean\test_csrf.py
# pythonvp\test\clean\test_cycle.py
# pythonvp\test\clean\test_data.py
# pythonvp\test\clean\test_dellos10_facts.py
# pythonvp\test\clean\test_deprecation.py
# pythonvp\test\clean\test_device_registry.py
# pythonvp\test\clean\test_dynamicbatching.py
# pythonvp\test\clean\test_engine.py
# pythonvp\test\clean\test_entityfilter.py
# pythonvp\test\clean\test_entity_registry.py
# pythonvp\test\clean\test_estimators.py
# pythonvp\test\clean\test_functional.py
# pythonvp\test\clean\test_generic.py
# pythonvp\test\clean\test_geos_mutation.py
# pythonvp\test\clean\test_gitmate_approver.py
# pythonvp\test\clean\test_hap.py
# pythonvp\test\clean\test_hassbian.py
# pythonvp\test\clean\test_hello_se.py
# pythonvp\test\clean\test_history_graph.py
# pythonvp\test\clean\test_host.py
# pythonvp\test\clean\test_imagefield.py
# pythonvp\test\clean\test_installation.py
# pythonvp\test\clean\test_integration_klassifikation.py
# pythonvp\test\clean\test_ios_banner.py
# pythonvp\test\clean\test_ios_ping.py
# pythonvp\test\clean\test_ios_system.py
# pythonvp\test\clean\test_ir_baseline.py
# pythonvp\test\clean\test_metaviewer.py
# pythonvp\test\clean\test_meta_static_pages.py
# pythonvp\test\clean\test_model_chat_analysis.py
# pythonvp\test\clean\test_modules.py
# pythonvp\test\clean\test_multiplechoicefield.py
# pythonvp\test\clean\test_multiplehiddeninput.py
# pythonvp\test\clean\test_named_endblock.py
# pythonvp\test\clean\test_netscaler_save_config.py
# pythonvp\test\clean\test_nso_query.py
# pythonvp\test\clean\test_nxos_ip_interface.py
# pythonvp\test\clean\test_nxos_overlay_global.py
# pythonvp\test\clean\test_oneview_ethernet_network_facts.py
# pythonvp\test\clean\test_onyx_interface.py
# pythonvp\test\clean\test_onyx_l3_interface.py
# pythonvp\test\clean\test_onyx_linkagg.py
# pythonvp\test\clean\test_onyx_lldp.py
# pythonvp\test\clean\test_onyx_lldp_interface.py
# pythonvp\test\clean\test_onyx_magp.py
# pythonvp\test\clean\test_openalpr_cloud.py
# pythonvp\test\clean\test_opt.py
# pythonvp\test\clean\test_panel_iframe.py
# pythonvp\test\clean\test_phone2numeric.py
# pythonvp\test\clean\test_platform_distribution.py
# pythonvp\test\clean\test_play.py
# pythonvp\test\clean\test_plugins.py
# pythonvp\test\clean\test_prefetch_related_objects.py
# pythonvp\test\clean\test_prefix.py
# pythonvp\test\clean\test_promises.py
# pythonvp\test\clean\test_purge.py
# pythonvp\test\clean\test_queue_random_images.py
# pythonvp\test\clean\test_requirements.py
# pythonvp\test\clean\test_results_view.py
# pythonvp\test\clean\test_rflink.py
# pythonvp\test\clean\test_rjust.py
# pythonvp\test\clean\test_server.py
# pythonvp\test\clean\test_session.py
# pythonvp\test\clean\test_set_mode_if_different.py
# pythonvp\test\clean\test_simple_tag.py
# pythonvp\test\clean\test_smtp.py
# pythonvp\test\clean\test_style_gen_teachers.py
# pythonvp\test\clean\test_task_result.py
# pythonvp\test\clean\test_tcp.py
# pythonvp\test\clean\test_translate.py
# pythonvp\test\clean\test_truncatechars_html.py
# pythonvp\test\clean\test_type_locks.py
# pythonvp\test\clean\test_validators.py
# pythonvp\test\clean\test_vultr.py
# pythonvp\test\clean\ThermalDomain.py
# pythonvp\test\clean\ticket_role.py
# pythonvp\test\clean\tile.py
# pythonvp\test\clean\timezone_utils.py
# pythonvp\test\clean\tod_base_no_api.py
# pythonvp\test\clean\toon.py
# pythonvp\test\clean\topological_sort.py
# pythonvp\test\clean\totalconnect.py
# pythonvp\test\clean\tower_job_launch.py
# pythonvp\test\clean\tra.py
# pythonvp\test\clean\tracks_random.py
# pythonvp\test\clean\TrafficGen.py
# pythonvp\test\clean\Transition.py
# pythonvp\test\clean\tsunami-o3.py
# pythonvp\test\clean\TypeDeclAST.py
# pythonvp\test\clean\TypeFieldEnumAST.py
# pythonvp\test\clean\Uart.py
# pythonvp\test\clean\ulog.py
# pythonvp\test\clean\unittest_arena_pb2.py
# pythonvp\test\clean\update_bundled.py
# pythonvp\test\clean\uptimerobot.py
# pythonvp\test\clean\urls_without_full_import.py
# pythonvp\test\clean\user_agents.py
# pythonvp\test\clean\utils.py
# pythonvp\test\clean\uvc.py
# pythonvp\test\clean\uwsgi.py
# pythonvp\test\clean\varblock.py
# pythonvp\test\clean\vault-keyring.py
# pythonvp\test\clean\vca_nat.py
# pythonvp\test\clean\VirtIO.py
# pythonvp\test\clean\vmware_cluster_facts.py
# pythonvp\test\clean\vmware_host_firewall_facts.py
# pythonvp\test\clean\vmware_host_package_facts.py
# pythonvp\test\clean\vmware_host_service_facts.py
# pythonvp\test\clean\vmware_vm_vss_dvs_migrate.py
# pythonvp\test\clean\wait_for_connection.py
# pythonvp\test\clean\wake_on_lan.py
# pythonvp\test\clean\weakref_backports.py
# pythonvp\test\clean\wiki_index_exact.py
# pythonvp\test\clean\win_file.py
# pythonvp\test\clean\win_file_version.py
# pythonvp\test\clean\win_psmodule.py
# pythonvp\test\clean\win_tempfile.py
# pythonvp\test\clean\win_template.py
# pythonvp\test\clean\win_wakeonlan.py
# pythonvp\test\clean\workday.py
# pythonvp\test\clean\worlds.py
# pythonvp\test\clean\world_metrics_handlers.py
# pythonvp\test\clean\X86KvmCPU.py
# pythonvp\test\clean\xgboost.py
# pythonvp\test\clean\yacc_badargs.py
# pythonvp\test\clean\yacc_badrule.py
# pythonvp\test\clean\yacc_misplaced.py
# pythonvp\test\clean\yacc_rr.py
# pythonvp\test\clean\yacc_simple.py
# pythonvp\test\clean\yacc_term1.py
# pythonvp\test\clean\yacc_unused.py
# pythonvp\test\clean\yaml.py
# pythonvp\test\clean\yamllint.py
# pythonvp\test\clean\yandextts.py
# pythonvp\test\clean\yply.py
# pythonvp\test\clean\zhong_hong.py
# pythonvp\test\clean\zigbee.py
# pythonvp\test\clean\zulu.py
# pythonvp\test\clean\_cl_img_install.py
# pythonvp\test\clean\_os.py

# %%
count = 0
for i in range(0, len(all_data)):
    if len(all_data[i]) > 120:
        count+=1
print(count)
# Out:
# 2603

# %%
# def getVocab(sequences):
#     vocab = []
#     for i in range(len(sequences)):
#         for j in range(len(sequences[i][0])):
#             if sequences[i][0][j] not in vocab:
#                 vocab.append(sequences[i][0][j])
#     return vocab

# %%
# # w2v embeddings

# dim = 200

# fileEmb = 'w2v_embeddingsIters.txt'
# embeddings_index = {}
# f = open(os.path.join('', fileEmb), encoding="utf-8")
# for line in f:    
#     values = line.split()
#     word = values[0]
#     coefs = np.asarray(values[1:])
#     embeddings_index[word] = coefs   
# f.close()

# tokenizer_obj = Tokenizer()
# tokenizer_obj.fit_on_texts(lines)
# sequences = tokenizer_obj.texts_to_sequences(lines)
# tokenizer_json = tokenizer_obj.to_json()
# with io.open('tokenizer.json', 'w', encoding='utf-8') as f:
#     f.write(json.dumps(tokenizer_json, ensure_ascii=False))
    
# #pad sequences
# word_index = tokenizer_obj.word_index
# lines_pad = pad_sequences(sequences, padding = 'post', maxlen = max_len)
# sentiment = labels.iloc[:,0].values

# num_words = len(word_index) + 1
# embedding_matrix = np.zeros((num_words, dim))
# for word, i in word_index.items():
#     if i > num_words:
#         continue
#     embedding_vector = embeddings_index.get(word)
#     if embedding_vector is not None:
#         embedding_matrix[i] = embedding_vector

# %%
# # gpt-based embeddings

# # Load the GPT-2 model and tokenizer
# model_name = "gpt2"  # 'gpt2' './model_logs_fromScratch', './model_logs/checkpoint-30000'
# tokenizer = GPT2Tokenizer.from_pretrained(model_name)
# model = GPT2LMHeadModel.from_pretrained(model_name)

# embedding_matrix = model.transformer.wte.weight
# num_words = embedding_matrix.size(0)
# dim = embedding_matrix.size(1)

# sentences = [' '.join(line) for line in lines] # Combine tokens in each inner list into complete sentences
# sequences = [tokenizer.encode(sente, add_special_tokens=False, truncation=True, max_length=1024, return_tensors="tf").numpy() for sente in sentences] # Tokenize the complete sentences

# sentiment = labels.iloc[:,0].values

# indexed_lines = []
# for seq in sequences:
#     indexed_lines.append(seq[0])
    
# #pad sequences
# lines_pad = pad_sequences(indexed_lines, padding = 'post', maxlen = max_len)

# %%
# # bert-based embeddings

# model_name = "roberta-base" # "bert-base-uncased"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = TFAutoModel.from_pretrained(model_name)

# bert_embeddings = model.get_input_embeddings()
# embedding_matrix = bert_embeddings.weights[0].numpy()
# num_words = len(embedding_matrix)
# dim = len(embedding_matrix[0])

# sentences = [' '.join(line) for line in lines] # Combine tokens in each inner list into complete sentences
# sequences = [tokenizer.encode(sente, add_special_tokens=False, truncation=True, max_length=1024, return_tensors="tf").numpy() for sente in sentences] # Tokenize the complete sentences

# sentiment = labels.iloc[:,0].values

# indexed_lines = []
# for seq in sequences:
#     indexed_lines.append(seq[0])
    
# #pad sequences
# lines_pad = pad_sequences(indexed_lines, padding = 'post', maxlen = max_len)

# %%
# codebert-based embeddings

model_name = "microsoft/codebert-base" #"microsoft/graphcodebert-base"
tokenizer = AutoTokenizer.from_pretrained(model_name, do_lower_case=True)
model = TFAutoModel.from_pretrained(model_name)

codebert_embeddings = model.get_input_embeddings()
embedding_matrix = codebert_embeddings.weights[0].numpy()
num_words = len(embedding_matrix)
dim = len(embedding_matrix[0])

sentences = [' '.join(line) for line in lines]
sequences = [tokenizer(sente, return_tensors="tf", truncation=True, add_special_tokens=False) for sente in sentences]

sentiment = labels.iloc[:,0].values

#lines_pad = pad_sequences(sequences, padding = 'post', maxlen = max_len)

def padSequences(sequences, max_len):
    lines_pad = []
    for sequence in sequences:
        seq = sequence['input_ids'].numpy()[0]
        if len(seq) < 512:
            for i in range(len(seq), 512):
                seq = np.append(seq, 0)
        lines_pad.append(seq)
    return lines_pad

lines_pad = padSequences(sequences, max_len)
lines_pad = [arr.tolist() for arr in lines_pad]
lines_pad = np.array(lines_pad)
# Out:
# All model checkpoint layers were used when initializing TFRobertaModel.
#
# All the layers of TFRobertaModel were initialized from the model checkpoint at microsoft/codebert-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.

# %%
train_x = lines_pad[0:train_len]
train_y = sentiment[0:train_len]

test_x = lines_pad[train_len:]
test_y = sentiment[train_len:]
    

avg_acc = []
avg_prec = []
avg_rec = []
avg_f1 = []
avg_f2 = []
num_loops = 5
for i in range(0, num_loops):
    print(i)
    #shuffle train data
    indices = np.arange(train_x.shape[0])
    np.random.shuffle(indices)
    train_x = train_x[indices]
    train_y = train_y[indices]

    #shuffle test data
    indices = np.arange(test_x.shape[0])
    np.random.shuffle(indices)
    test_x = test_x[indices]
    test_y = test_y[indices]
    
    #percentage train data
    pososto = 1 # 0.125  0.0625
    train_x = train_x[0:int(pososto*train_len)]
    train_y = train_y[0:int(pososto*train_len)]

    nb_epoch = 100
    BS = 64

    #myModel = buildCnn(max_len, num_words, dim, seed, embedding_matrix.detach().numpy()) # buildLstm # buildCnn # buildBiLstm
    myModel = buildCnn(max_len, num_words, dim, seed, embedding_matrix)
    print("model summary\m",myModel.summary())
    csv_logger = CSVLogger('log.csv', append=True, separator=',')
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
    mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
    milli_sec1 = int(round(time.time() * 1000))
    history = myModel.fit(train_x, train_y, validation_data=(test_x, test_y), epochs = nb_epoch, batch_size = BS, shuffle=False, verbose=1, callbacks=[csv_logger,es,mc])
    milli_sec2 = int(round(time.time() * 1000))
    print("Training is completed after", milli_sec2-milli_sec1)

    myModel.load_weights("best_model.h5")
    predictions = (myModel.predict(test_x) > 0.5).astype("int32")
    predScores = myModel.predict(test_x)

    cm = confusion_matrix(test_y, predictions, labels=[0, 1])
    tn, fp, fn, tp = confusion_matrix(test_y, predictions).ravel()
    (tn, fp, fn, tp)

    acc=(tp+tn)/(tp+tn+fp+fn)
    prec=tp/(tp+fp)
    rec=tp/(tp+fn)
    f1=2*prec*rec / (prec+rec)
    f2=5*prec*rec / (4*prec+rec)
    print("Accuracy: ", acc)
    print("Precision: ", prec)
    print("Recall: ", rec)
    print("F1-score: ", f1)
    print("F2-score: ", f2)
    
    avg_acc.append(acc)
    avg_prec.append(prec)
    avg_rec.append(rec)
    avg_f1.append(f1)
    avg_f2.append(f2)

print("\n")
print("AVG Accuracy: ", sum(avg_acc)/5)
print("AVG Precision: ", sum(avg_prec)/5)
print("AVG Recall: ", sum(avg_rec)/5)
print("AVG F1-score: ", sum(avg_f1)/5)
print("AVG F2-score: ", sum(avg_f2)/5)
# Out:
# 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 768)         38603520
#
#  conv1d (Conv1D)             (None, None, 128)         491648
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 39,095,297
# Trainable params: 491,777
# Non-trainable params: 38,603,520
# _________________________________________________________________
# model summary\m None
# Epoch 1/100
# 56/56 [==============================] - ETA: 0s - loss: 0.3555
# Epoch 1: val_loss improved from inf to 0.26431, saving model to best_model.h5
# 56/56 [==============================] - 4s 26ms/step - loss: 0.3555 - val_loss: 0.2643
# Epoch 2/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.1898
# Epoch 2: val_loss improved from 0.26431 to 0.21095, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1896 - val_loss: 0.2110
# Epoch 3/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.1135
# Epoch 3: val_loss improved from 0.21095 to 0.17890, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1133 - val_loss: 0.1789
# Epoch 4/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0712
# Epoch 4: val_loss improved from 0.17890 to 0.16824, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0710 - val_loss: 0.1682
# Epoch 5/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0503
# Epoch 5: val_loss did not improve from 0.16824
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0497 - val_loss: 0.1685
# Epoch 6/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0394
# Epoch 6: val_loss did not improve from 0.16824
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0399 - val_loss: 0.1859
# Epoch 7/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0384
# Epoch 7: val_loss did not improve from 0.16824
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0382 - val_loss: 0.2154
# Epoch 8/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0430
# Epoch 8: val_loss did not improve from 0.16824
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0421 - val_loss: 0.1708
# Epoch 9/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0308
# Epoch 9: val_loss did not improve from 0.16824
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0299 - val_loss: 0.1691
# Epoch 10/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0184
# Epoch 10: val_loss improved from 0.16824 to 0.16649, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0178 - val_loss: 0.1665
# Epoch 11/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0159
# Epoch 11: val_loss did not improve from 0.16649
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0158 - val_loss: 0.2093
# Epoch 12/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0148
# Epoch 12: val_loss did not improve from 0.16649
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0143 - val_loss: 0.2038
# Epoch 13/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0143
# Epoch 13: val_loss did not improve from 0.16649
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0139 - val_loss: 0.2542
# Epoch 14/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0137
# Epoch 14: val_loss did not improve from 0.16649
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0136 - val_loss: 0.2010
# Epoch 15/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0140
# Epoch 15: val_loss did not improve from 0.16649
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0139 - val_loss: 0.2718
# Epoch 16/100
# 54/56 [===========================>..] - ETA: 0s - loss: 0.0146
# Epoch 16: val_loss did not improve from 0.16649
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0142 - val_loss: 0.2079
# Epoch 17/100
# 56/56 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 17: val_loss did not improve from 0.16649
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0140 - val_loss: 0.2828
# Epoch 18/100
# 54/56 [===========================>..] - ETA: 0s - loss: 0.0134
# Epoch 18: val_loss did not improve from 0.16649
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0130 - val_loss: 0.2031
# Epoch 19/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0130
# Epoch 19: val_loss did not improve from 0.16649
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0129 - val_loss: 0.2862
# Epoch 20/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0130
# Epoch 20: val_loss did not improve from 0.16649
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0128 - val_loss: 0.2041
# Epoch 20: early stopping
# Training is completed after 24754
# 20/20 [==============================] - 0s 5ms/step
# 20/20 [==============================] - 0s 3ms/step
# Accuracy:  0.9315286624203821
# Precision:  0.8794326241134752
# Recall:  0.8266666666666667
# F1-score:  0.8522336769759451
# F2-score:  0.8367071524966262
# 1
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 768)         38603520
#
#  conv1d_1 (Conv1D)           (None, None, 128)         491648
#
#  global_max_pooling1d_1 (Glo  (None, 128)              0
#  balMaxPooling1D)
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 39,095,297
# Trainable params: 491,777
# Non-trainable params: 38,603,520
# _________________________________________________________________
# model summary\m None
# Epoch 1/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.3541
# Epoch 1: val_loss improved from inf to 0.26213, saving model to best_model.h5
# 56/56 [==============================] - 2s 23ms/step - loss: 0.3547 - val_loss: 0.2621
# Epoch 2/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.1920
# Epoch 2: val_loss improved from 0.26213 to 0.20757, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1921 - val_loss: 0.2076
# Epoch 3/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.1244
# Epoch 3: val_loss improved from 0.20757 to 0.17915, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1238 - val_loss: 0.1791
# Epoch 4/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0873
# Epoch 4: val_loss did not improve from 0.17915
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0874 - val_loss: 0.1979
# Epoch 5/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0579
# Epoch 5: val_loss improved from 0.17915 to 0.17804, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0575 - val_loss: 0.1780
# Epoch 6/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0376
# Epoch 6: val_loss improved from 0.17804 to 0.16158, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0377 - val_loss: 0.1616
# Epoch 7/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0285
# Epoch 7: val_loss did not improve from 0.16158
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0288 - val_loss: 0.1665
# Epoch 8/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0235
# Epoch 8: val_loss did not improve from 0.16158
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0234 - val_loss: 0.1623
# Epoch 9/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0211
# Epoch 9: val_loss improved from 0.16158 to 0.16098, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0210 - val_loss: 0.1610
# Epoch 10/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0193
# Epoch 10: val_loss did not improve from 0.16098
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0191 - val_loss: 0.1644
# Epoch 11/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0185
# Epoch 11: val_loss did not improve from 0.16098
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0183 - val_loss: 0.1637
# Epoch 12/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0178
# Epoch 12: val_loss did not improve from 0.16098
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0176 - val_loss: 0.1642
# Epoch 13/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0172
# Epoch 13: val_loss did not improve from 0.16098
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0169 - val_loss: 0.1662
# Epoch 14/100
# 54/56 [===========================>..] - ETA: 0s - loss: 0.0161
# Epoch 14: val_loss did not improve from 0.16098
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0158 - val_loss: 0.1729
# Epoch 15/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0151
# Epoch 15: val_loss did not improve from 0.16098
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0148 - val_loss: 0.1783
# Epoch 16/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0143
# Epoch 16: val_loss did not improve from 0.16098
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0140 - val_loss: 0.1846
# Epoch 17/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0132
# Epoch 17: val_loss did not improve from 0.16098
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0129 - val_loss: 0.1860
# Epoch 18/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0122
# Epoch 18: val_loss did not improve from 0.16098
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0121 - val_loss: 0.1833
# Epoch 19/100
# 54/56 [===========================>..] - ETA: 0s - loss: 0.0113
# Epoch 19: val_loss did not improve from 0.16098
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0110 - val_loss: 0.1830
# Epoch 19: early stopping
# Training is completed after 21128
# 20/20 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# Accuracy:  0.928343949044586
# Precision:  0.847682119205298
# Recall:  0.8533333333333334
# F1-score:  0.8504983388704319
# F2-score:  0.8521970705725701
# 2
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 768)         38603520
#
#  conv1d_2 (Conv1D)           (None, None, 128)         491648
#
#  global_max_pooling1d_2 (Glo  (None, 128)              0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 39,095,297
# Trainable params: 491,777
# Non-trainable params: 38,603,520
# _________________________________________________________________
# model summary\m None
# Epoch 1/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.3961
# Epoch 1: val_loss improved from inf to 0.28096, saving model to best_model.h5
# 56/56 [==============================] - 2s 23ms/step - loss: 0.3948 - val_loss: 0.2810
# Epoch 2/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.2148
# Epoch 2: val_loss improved from 0.28096 to 0.22684, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.2140 - val_loss: 0.2268
# Epoch 3/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.1379
# Epoch 3: val_loss improved from 0.22684 to 0.19884, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1372 - val_loss: 0.1988
# Epoch 4/100
# 54/56 [===========================>..] - ETA: 0s - loss: 0.0892
# Epoch 4: val_loss improved from 0.19884 to 0.17752, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0885 - val_loss: 0.1775
# Epoch 5/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0619
# Epoch 5: val_loss did not improve from 0.17752
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0612 - val_loss: 0.1862
# Epoch 6/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0521
# Epoch 6: val_loss did not improve from 0.17752
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0518 - val_loss: 0.1907
# Epoch 7/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0509
# Epoch 7: val_loss improved from 0.17752 to 0.16799, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0505 - val_loss: 0.1680
# Epoch 8/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0453
# Epoch 8: val_loss did not improve from 0.16799
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0453 - val_loss: 0.2444
# Epoch 9/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0342
# Epoch 9: val_loss did not improve from 0.16799
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0330 - val_loss: 0.1774
# Epoch 10/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0205
# Epoch 10: val_loss did not improve from 0.16799
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0198 - val_loss: 0.1724
# Epoch 11/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0166
# Epoch 11: val_loss did not improve from 0.16799
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0164 - val_loss: 0.1793
# Epoch 12/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0188
# Epoch 12: val_loss did not improve from 0.16799
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0187 - val_loss: 0.1752
# Epoch 13/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0138
# Epoch 13: val_loss did not improve from 0.16799
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0137 - val_loss: 0.1879
# Epoch 14/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0203
# Epoch 14: val_loss did not improve from 0.16799
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0195 - val_loss: 0.1791
# Epoch 15/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0129
# Epoch 15: val_loss did not improve from 0.16799
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0124 - val_loss: 0.1940
# Epoch 16/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0196
# Epoch 16: val_loss did not improve from 0.16799
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0195 - val_loss: 0.1816
# Epoch 17/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0118
# Epoch 17: val_loss did not improve from 0.16799
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0114 - val_loss: 0.1998
# Epoch 17: early stopping
# Training is completed after 19026
# 20/20 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# Accuracy:  0.9267515923566879
# Precision:  0.8661971830985915
# Recall:  0.82
# F1-score:  0.8424657534246575
# F2-score:  0.8288409703504043
# 3
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, None, 768)         38603520
#
#  conv1d_3 (Conv1D)           (None, None, 128)         491648
#
#  global_max_pooling1d_3 (Glo  (None, 128)              0
#  balMaxPooling1D)
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 39,095,297
# Trainable params: 491,777
# Non-trainable params: 38,603,520
# _________________________________________________________________
# model summary\m None
# Epoch 1/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.3813
# Epoch 1: val_loss improved from inf to 0.26455, saving model to best_model.h5
# 56/56 [==============================] - 2s 23ms/step - loss: 0.3812 - val_loss: 0.2646
# Epoch 2/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.2062
# Epoch 2: val_loss improved from 0.26455 to 0.21098, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.2057 - val_loss: 0.2110
# Epoch 3/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.1311
# Epoch 3: val_loss improved from 0.21098 to 0.18650, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1309 - val_loss: 0.1865
# Epoch 4/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0830
# Epoch 4: val_loss improved from 0.18650 to 0.17370, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0824 - val_loss: 0.1737
# Epoch 5/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0534
# Epoch 5: val_loss improved from 0.17370 to 0.16976, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0533 - val_loss: 0.1698
# Epoch 6/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0393
# Epoch 6: val_loss did not improve from 0.16976
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0392 - val_loss: 0.1828
# Epoch 7/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0316
# Epoch 7: val_loss did not improve from 0.16976
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0315 - val_loss: 0.1860
# Epoch 8/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0257
# Epoch 8: val_loss improved from 0.16976 to 0.16451, saving model to best_model.h5
# 56/56 [==============================] - 1s 23ms/step - loss: 0.0256 - val_loss: 0.1645
# Epoch 9/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0225
# Epoch 9: val_loss improved from 0.16451 to 0.16371, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0222 - val_loss: 0.1637
# Epoch 10/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0213
# Epoch 10: val_loss did not improve from 0.16371
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0212 - val_loss: 0.1662
# Epoch 11/100
# 54/56 [===========================>..] - ETA: 0s - loss: 0.0207
# Epoch 11: val_loss did not improve from 0.16371
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0205 - val_loss: 0.1688
# Epoch 12/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0206
# Epoch 12: val_loss did not improve from 0.16371
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0200 - val_loss: 0.1682
# Epoch 13/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0196
# Epoch 13: val_loss did not improve from 0.16371
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0195 - val_loss: 0.1682
# Epoch 14/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0183
# Epoch 14: val_loss did not improve from 0.16371
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0182 - val_loss: 0.1771
# Epoch 15/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0168
# Epoch 15: val_loss did not improve from 0.16371
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0167 - val_loss: 0.1950
# Epoch 16/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0154
# Epoch 16: val_loss did not improve from 0.16371
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0151 - val_loss: 0.2170
# Epoch 17/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0134
# Epoch 17: val_loss did not improve from 0.16371
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0134 - val_loss: 0.2320
# Epoch 18/100
# 56/56 [==============================] - ETA: 0s - loss: 0.0123
# Epoch 18: val_loss did not improve from 0.16371
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0123 - val_loss: 0.2372
# Epoch 19/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0118
# Epoch 19: val_loss did not improve from 0.16371
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0117 - val_loss: 0.2421
# Epoch 19: early stopping
# Training is completed after 21641
# 20/20 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# Accuracy:  0.9299363057324841
# Precision:  0.863013698630137
# Recall:  0.84
# F1-score:  0.8513513513513513
# F2-score:  0.8445040214477211
# 4
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, None, 768)         38603520
#
#  conv1d_4 (Conv1D)           (None, None, 128)         491648
#
#  global_max_pooling1d_4 (Glo  (None, 128)              0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 39,095,297
# Trainable params: 491,777
# Non-trainable params: 38,603,520
# _________________________________________________________________
# model summary\m None
# Epoch 1/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.3753
# Epoch 1: val_loss improved from inf to 0.26780, saving model to best_model.h5
# 56/56 [==============================] - 2s 24ms/step - loss: 0.3743 - val_loss: 0.2678
# Epoch 2/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.2111
# Epoch 2: val_loss improved from 0.26780 to 0.21004, saving model to best_model.h5
# 56/56 [==============================] - 1s 23ms/step - loss: 0.2103 - val_loss: 0.2100
# Epoch 3/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.1368
# Epoch 3: val_loss improved from 0.21004 to 0.18693, saving model to best_model.h5
# 56/56 [==============================] - 1s 23ms/step - loss: 0.1361 - val_loss: 0.1869
# Epoch 4/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0909
# Epoch 4: val_loss improved from 0.18693 to 0.17180, saving model to best_model.h5
# 56/56 [==============================] - 1s 23ms/step - loss: 0.0906 - val_loss: 0.1718
# Epoch 5/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0714
# Epoch 5: val_loss did not improve from 0.17180
# 56/56 [==============================] - 1s 18ms/step - loss: 0.0714 - val_loss: 0.2140
# Epoch 6/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0628
# Epoch 6: val_loss did not improve from 0.17180
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0629 - val_loss: 0.3115
# Epoch 7/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0593
# Epoch 7: val_loss did not improve from 0.17180
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0587 - val_loss: 0.1883
# Epoch 8/100
# 56/56 [==============================] - ETA: 0s - loss: 0.0322
# Epoch 8: val_loss improved from 0.17180 to 0.16492, saving model to best_model.h5
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0322 - val_loss: 0.1649
# Epoch 9/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0185
# Epoch 9: val_loss did not improve from 0.16492
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0185 - val_loss: 0.1686
# Epoch 10/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0166
# Epoch 10: val_loss did not improve from 0.16492
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0165 - val_loss: 0.1718
# Epoch 11/100
# 54/56 [===========================>..] - ETA: 0s - loss: 0.0155
# Epoch 11: val_loss did not improve from 0.16492
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0152 - val_loss: 0.1736
# Epoch 12/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0142
# Epoch 12: val_loss did not improve from 0.16492
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0141 - val_loss: 0.1749
# Epoch 13/100
# 53/56 [===========================>..] - ETA: 0s - loss: 0.0136
# Epoch 13: val_loss did not improve from 0.16492
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0133 - val_loss: 0.1745
# Epoch 14/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0128
# Epoch 14: val_loss did not improve from 0.16492
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0127 - val_loss: 0.1749
# Epoch 15/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0125
# Epoch 15: val_loss did not improve from 0.16492
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0124 - val_loss: 0.1767
# Epoch 16/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0122
# Epoch 16: val_loss did not improve from 0.16492
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0121 - val_loss: 0.1781
# Epoch 17/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0118
# Epoch 17: val_loss did not improve from 0.16492
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0118 - val_loss: 0.1791
# Epoch 18/100
# 55/56 [============================>.] - ETA: 0s - loss: 0.0116
# Epoch 18: val_loss did not improve from 0.16492
# 56/56 [==============================] - 1s 19ms/step - loss: 0.0115 - val_loss: 0.1799
# Epoch 18: early stopping
# Training is completed after 20309
# 20/20 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# Accuracy:  0.9267515923566879
# Precision:  0.8823529411764706
# Recall:  0.8
# F1-score:  0.8391608391608392
# F2-score:  0.815217391304348
#
#
# AVG Accuracy:  0.9286624203821656
# AVG Precision:  0.8677357132447945
# AVG Recall:  0.828
# AVG F1-score:  0.8471419919566451
# AVG F2-score:  0.8354933212343341

# %%
# #shuffle data
# indices = np.arange(lines_pad.shape[0])
# lines_pad = lines_pad[indices]
# sentiment = sentiment[indices]

# y = pd.DataFrame(sentiment)
# X = pd.DataFrame(lines_pad)

# ############## cross validation
# scores=['accuracy', 'precision', 'recall', 'f1', 'roc_auc', 'f2', 'fpr']
# values = [np.array([]) for i in range(0, len(scores))]
# score_dict = OrderedDict(zip(scores, values))
# k=10
# f=0
# kfold = StratifiedKFold(n_splits=k,shuffle=True,random_state=seed)

# nb_epoch = 100
# BS = 64
# print("Training...")
# milli_sec1 = int(round(time.time() * 1000))

# for train_index, test_index in kfold.split(X, y):
#     f = f + 1
#     print('fold number= ',f)
#     X_train, X_test = X.iloc[train_index], X.iloc[test_index]
#     Y_train, Y_test = y.iloc[train_index], y.iloc[test_index]
#     Y_train = np.array(Y_train)
#     Y_train = Y_train.ravel()
#     Y_test = np.array(Y_test)
#     Y_test = Y_test.ravel()
    
#     '''#sampling
#     X_res, Y_res = RandomOverSampler(random_state=seed, sampling_strategy=0.5).fit_resample(X_train, Y_train)
#     #X_res, Y_res = RandomUnderSampler(random_state=seed, sampling_strategy=0.5).fit_resample(X_train, Y_train)

#     #shuffle dataset
#     X_resampled=pd.DataFrame(X_res)
#     Y_resampled=pd.DataFrame(Y_res)
#     newTrain=X_resampled.assign(Label=Y_resampled.values)
#     newTrain = shuffle(newTrain,random_state=seed)
#     X_train=np.array(newTrain.iloc[:, 0:-1 ])
#     X_train=pd.DataFrame(X_train)
#     Y_train=np.array(newTrain.iloc[:, -1 ])
#     Y_train=pd.DataFrame(Y_train)'''
    
#     myModel = buildCnn(max_len, num_words, dim, seed, embedding_matrix) # buildLstm
#     print("model summary\m",myModel.summary())
#     csv_logger = CSVLogger('log.csv', append=True, separator=',')
#     es = EarlyStopping(monitor='val_f2_metric', mode='max', verbose=1, patience=10)
#     mc = ModelCheckpoint('best_model.h5', monitor='val_f2_metric', mode='max', verbose=1, save_best_only=True)
#     history = myModel.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs = nb_epoch, batch_size = BS, shuffle=False, verbose=1, callbacks=[csv_logger,es,mc])
    
#     #load best model
#     #model = load_model('best_model.h5')
#     myModel.load_weights("best_model.h5")
    
#     scores = myModel.evaluate(X_test, Y_test, verbose=0)
#     #predictions = myModel.predict_classes(X_test, verbose=0)
#     predictions = (myModel.predict(X_test) > 0.5).astype("int32")
#     predScores = myModel.predict(X_test)
#     accuracy=accuracy_score(Y_test, predictions)
#     precision=precision_score(Y_test, predictions)
#     recall=recall_score(Y_test, predictions)
#     f1=f1_score(Y_test, predictions)
#     roc_auc=roc_auc_score(Y_test, predictions)
#     f2=5*precision*recall / (4*precision+recall)
#     print(confusion_matrix(Y_test, predictions, labels=[0, 1]))
#     tn, fp, fn, tp = confusion_matrix(Y_test, predictions).ravel()
#     fpr = fp / (fp+tn)
#     acc = ((tp+tn)/(tp+tn+fp+fn))
#     print("Accuracy:%.2f%%"%(acc*100))
#     print("Precision:%.2f%%"%(precision*100))
#     print("Recall:%.2f%%"%(recall*100))
#     print("F1 score:%.2f%%"%(f1*100))
#     print("Roc_Auc score:%.2f%%"%(roc_auc*100))
#     print("F2 score:%.2f%%"%(f2*100))
#     print("FPR score:%.2f%%"%(fpr*100))
#     print(classification_report(Y_test, predictions))
#     del myModel
#     score_dict['accuracy'] = np.append(score_dict['accuracy'], accuracy)
#     score_dict['precision'] = np.append(score_dict['precision'], precision)
#     score_dict['recall'] = np.append(score_dict['recall'], recall)
#     score_dict['f1'] = np.append(score_dict['f1'], f1)
#     score_dict['roc_auc'] = np.append(score_dict['roc_auc'], roc_auc)
#     score_dict['f2'] = np.append(score_dict['f2'], f2)
#     score_dict['fpr'] = np.append(score_dict['fpr'], fpr)
    
# milli_sec2 = int(round(time.time() * 1000))
# print("Training is completed after", milli_sec2-milli_sec1)

# print("accuracy: %.2f%% (%.2f%%)" % (score_dict['accuracy'].mean()*100, score_dict['accuracy'].std()*100))
# print("precision: %.2f%% (%.2f%%)" % (score_dict['precision'].mean()*100, score_dict['precision'].std()*100))
# print("recall: %.2f%% (%.2f%%)" % (score_dict['recall'].mean()*100, score_dict['recall'].std()*100))
# print("f1: %.2f%% (%.2f%%)" % (score_dict['f1'].mean()*100, score_dict['f1'].std()*100))
# print("roc_auc: %.2f%% (%.2f%%)" % (score_dict['roc_auc'].mean()*100, score_dict['roc_auc'].std()*100))
# print("f2: %.2f%% (%.2f%%)" % (score_dict['f2'].mean()*100, score_dict['f2'].std()*100))
# print("fpr: %.2f%% (%.2f%%)" % (score_dict['fpr'].mean()*100, score_dict['fpr'].std()*100))
